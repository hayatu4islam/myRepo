# %% [markdown]
# ## Multivariate LSTM Forecast model for multiple outputs

# %% [markdown]
# ### Distribution of the variables

# %%
from matplotlib import pyplot
from pandas import read_csv
# load results file
# results = read_csv('phy_cps.csv', header=0)
results = read_csv('phy_att_test_processed.csv', header=0)
# descriptive stats
print(results.describe())
# box and whisker plot
results.boxplot(whiskerprops = dict(linestyle='-', linewidth=2))
pyplot.show()
# histogram
results.hist()
pyplot.show()
# Out:
#             Tank_1       Tank_2       Tank_3       Tank_4       Tank_5  \
# count  2420.000000  2420.000000  2420.000000  2420.000000  2420.000000
# mean    686.320661   714.946281   922.677686   362.064463   361.733058
# std     654.955181   656.051613   942.572849   366.970644   278.799110
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     5.000000    73.250000    27.000000    30.500000
# 50%     598.000000   639.500000   747.500000   231.000000   370.000000
# 75%    1244.000000  1293.250000  1226.250000   692.250000   605.250000
# max    1980.000000  1952.000000  3427.000000  1134.000000   835.000000
#
#             Tank_6       Tank_7       Tank_8       Pump_1       Pump_2  ...  \
# count  2420.000000  2420.000000  2420.000000  2420.000000  2420.000000  ...
# mean    198.284298   207.890083   163.835124     0.300000     0.243802  ...
# std     190.497343   216.415569   179.054521     0.458352     0.429463  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       3.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%     165.500000   144.000000    86.000000     0.000000     0.000000  ...
# 75%     380.250000   450.000000   358.250000     1.000000     0.000000  ...
# max     800.000000   812.000000   507.000000     1.000000     1.000000  ...
#
#            Valv_13      Valv_14      Valv_15  Valv_16     Valv_17  \
# count  2420.000000  2420.000000  2420.000000   2420.0  2420.00000
# mean      0.524380     0.524380     0.524380      0.0     0.38595
# std       0.499508     0.499508     0.499508      0.0     0.48692
# min       0.000000     0.000000     0.000000      0.0     0.00000
# 25%       0.000000     0.000000     0.000000      0.0     0.00000
# 50%       1.000000     1.000000     1.000000      0.0     0.00000
# 75%       1.000000     1.000000     1.000000      0.0     1.00000
# max       1.000000     1.000000     1.000000      0.0     1.00000
#
#            Valv_18  Valv_19      Valv_20  Valv_21      Valv_22
# count  2420.000000   2420.0  2420.000000   2420.0  2420.000000
# mean      0.230992      0.0     0.619835      0.0     0.433058
# std       0.421554      0.0     0.485528      0.0     0.495601
# min       0.000000      0.0     0.000000      0.0     0.000000
# 25%       0.000000      0.0     0.000000      0.0     0.000000
# 50%       0.000000      0.0     1.000000      0.0     0.000000
# 75%       0.000000      0.0     1.000000      0.0     1.000000
# max       1.000000      0.0     1.000000      0.0     1.000000
#
# [8 rows x 40 columns]

# %%
#from numpy import array
import keras
import numpy as np
from math import sqrt
import os, datetime
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, r2_score
from keras.models import Sequential
from keras.layers import Dense
from keras.layers.core import Dropout
from keras.layers import LSTM
from keras.layers import *

np.random.seed(17)

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

#load dataset
dataset = read_csv('phy_cps.csv', header=0, index_col=0)
values = dataset.values
 
#integer encode wind direction, as it's the only categorical variable.
#encoder = LabelEncoder()
#values[:,4] = encoder.fit_transform(values[:,4])
 
#ensure all data are float32 values
values = values.astype('float32')
 
#normalize input features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
 
#frame as supervised learning
n_hours = 1 
n_features = 6 
reframed = series_to_supervised(scaled, n_hours, 1)
values = reframed.values
# n_train_hours = 1936
n_train_hours = 1694
n_test = 484
train = values[:n_train_hours, :]
test = values[n_train_hours:n_train_hours+n_test, :]
out_test = values[n_train_hours+n_test:, :]
 

#split into input and outputs
n_obs = n_hours * n_features
train_X = train[:, :n_obs]
train_y = train[:, -n_features:(-n_features+4)] #+2 because of indexing madness.
test_X = test[:, :n_obs]
test_y = test[:, -n_features:(-n_features+4)]
 
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
 

#Need to output four values, not one.
#design network
model = Sequential()
model.add(LSTM(50, activation='relu',return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.1))
model.add(LSTM(20, activation='relu', return_sequences=True))
model.add(Dropout(0.1))
model.add(LSTM(20, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(4))

model.compile(loss='mse', optimizer='adam')

# Create a Tensorboard logger
#logger = keras.callbacks.TensorBoard(log_dir='log', write_graph=True, histogram_freq=5)
logdir = os.path.join("mylog", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
logger = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

#fit network
# history = model.fit(train_X, train_y, epochs=200, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
history = model.fit(train_X, train_y, epochs=250, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False, callbacks=[logger])

# Plot history
pyplot.xlabel('Epochs')
pyplot.ylabel('Loss')
pyplot.title('Model Train vs Testing Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
 

#make a prediction
y_hat = model.predict(test_X)
 
#calculate RMSE - CHANGED to output RMSE for each variable.
norm_rmse_1 = sqrt(mean_squared_error(y_hat[:,0], test_y[:,0])) #RMSE for the first variable (Tank_1)
norm_rmse_2 = sqrt(mean_squared_error(y_hat[:,1], test_y[:,1])) #RMSE for the second variable (Tank_2)
norm_rmse_3 = sqrt(mean_squared_error(y_hat[:,2], test_y[:,2])) #RMSE for the third variable (Tank_3)
norm_rmse_4 = sqrt(mean_squared_error(y_hat[:,3], test_y[:,3])) #RMSE for the fourth variable (Pump_1)
print('Normalized Test RMSE: ', norm_rmse_1, norm_rmse_2, norm_rmse_3, norm_rmse_4)
    
test_X = test_X.reshape((test_X.shape[0], n_hours*n_features))
inv_yhat = concatenate((y_hat, test_X[:,-2:]), axis=1) #changed 7 to 6
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0:4] #changed from 0 to 0:2. Should be first 2 columns that contain the predictions
 

#invert scaling for actual
test_y = test_y.reshape((len(test_y),4)) #changed 1 to 2
inv_y = concatenate((test_y, test_X[:,-2:]), axis=1) #changed 7 to 6
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0:4] #changed from 0 to 0:2. Should be first 2 columns that contain the predictions.
 

    
#calculate RMSE - CHANGED to output RMSE for each variable.
rmse_1 = sqrt(mean_squared_error(inv_y[:,0], inv_yhat[:,0])) #RMSE for the first variable (Tank_1)
rmse_2 = sqrt(mean_squared_error(inv_y[:,1], inv_yhat[:,1])) #RMSE for the second variable (Tank_2)
rmse_3 = sqrt(mean_squared_error(inv_y[:,2], inv_yhat[:,2])) #RMSE for the third variable (Tank_3)
rmse_4 = sqrt(mean_squared_error(inv_y[:,3], inv_yhat[:,3])) #RMSE for the fourth variable (Pump_1)

r_sq1 = r2_score(inv_y[:,0], inv_yhat[:,0])
r_sq2 = r2_score(inv_y[:,1], inv_yhat[:,1])
r_sq3 = r2_score(inv_y[:,2], inv_yhat[:,2])
r_sq4 = r2_score(inv_y[:,3], inv_yhat[:,3])

print('Test RMSE: ', rmse_1, rmse_2, rmse_3, rmse_4)

print("Test R-squared: ", r_sq1, r_sq2, r_sq3, r_sq4)
model.summary()

import xlsxwriter

# Create file (workbook) and worksheet
outWorkbook = xlsxwriter.Workbook("out.xlsx")
outSheet = outWorkbook.add_worksheet()

# Declare data
values = [[rmse_1,norm_rmse_1,r_sq1],
          [rmse_2,norm_rmse_2,r_sq2],
          [rmse_3,norm_rmse_3,r_sq3],
          [rmse_4,norm_rmse_4,r_sq4]]

# Write headers
outSheet.write("C1", "Tank_1")
outSheet.write("D1", "Tank_2")
outSheet.write("E1", "Tank_3")
outSheet.write("F1", "Pump_1")

# Write data to file
outSheet.write("C2",values[0][0])
outSheet.write("C3",values[0][1])
outSheet.write("C4",values[0][2])

outSheet.write("D2",values[1][0])
outSheet.write("D3",values[1][1])
outSheet.write("D4",values[1][2])

outSheet.write("E2",values[2][0])
outSheet.write("E3",values[2][1])
outSheet.write("E4",values[2][2])

outSheet.write("F2",values[3][0])
outSheet.write("F3",values[3][1])
outSheet.write("F4",values[3][2])

outWorkbook.close()

# Save the model to disk
model.save('multi_lstm_model.h5')
print('Model saved to disk')
# Out:
# Epoch 1/250
# 24/24 - 4s - loss: 0.2253 - val_loss: 0.2302 - 4s/epoch - 158ms/step
# Epoch 2/250
# 24/24 - 0s - loss: 0.2103 - val_loss: 0.2156 - 197ms/epoch - 8ms/step
# Epoch 3/250
# 24/24 - 0s - loss: 0.1927 - val_loss: 0.1976 - 191ms/epoch - 8ms/step
# Epoch 4/250
# 24/24 - 0s - loss: 0.1642 - val_loss: 0.1710 - 187ms/epoch - 8ms/step
# Epoch 5/250
# 24/24 - 0s - loss: 0.1165 - val_loss: 0.1480 - 191ms/epoch - 8ms/step
# Epoch 6/250
# 24/24 - 0s - loss: 0.0908 - val_loss: 0.1472 - 191ms/epoch - 8ms/step
# Epoch 7/250
# 24/24 - 0s - loss: 0.0789 - val_loss: 0.1466 - 191ms/epoch - 8ms/step
# Epoch 8/250
# 24/24 - 0s - loss: 0.0771 - val_loss: 0.1454 - 193ms/epoch - 8ms/step
# Epoch 9/250
# 24/24 - 0s - loss: 0.0731 - val_loss: 0.1436 - 188ms/epoch - 8ms/step
# Epoch 10/250
# 24/24 - 0s - loss: 0.0718 - val_loss: 0.1421 - 193ms/epoch - 8ms/step
# Epoch 11/250
# 24/24 - 0s - loss: 0.0680 - val_loss: 0.1403 - 190ms/epoch - 8ms/step
# Epoch 12/250
# 24/24 - 0s - loss: 0.0675 - val_loss: 0.1382 - 189ms/epoch - 8ms/step
# Epoch 13/250
# 24/24 - 0s - loss: 0.0627 - val_loss: 0.1349 - 193ms/epoch - 8ms/step
# Epoch 14/250
# 24/24 - 0s - loss: 0.0604 - val_loss: 0.1302 - 187ms/epoch - 8ms/step
# Epoch 15/250
# 24/24 - 0s - loss: 0.0561 - val_loss: 0.1249 - 192ms/epoch - 8ms/step
# Epoch 16/250
# 24/24 - 0s - loss: 0.0534 - val_loss: 0.1196 - 189ms/epoch - 8ms/step
# Epoch 17/250
# 24/24 - 0s - loss: 0.0503 - val_loss: 0.1140 - 188ms/epoch - 8ms/step
# Epoch 18/250
# 24/24 - 0s - loss: 0.0461 - val_loss: 0.1081 - 187ms/epoch - 8ms/step
# Epoch 19/250
# 24/24 - 0s - loss: 0.0439 - val_loss: 0.1045 - 186ms/epoch - 8ms/step
# Epoch 20/250
# 24/24 - 0s - loss: 0.0410 - val_loss: 0.1007 - 185ms/epoch - 8ms/step
# Epoch 21/250
# 24/24 - 0s - loss: 0.0408 - val_loss: 0.0987 - 190ms/epoch - 8ms/step
# Epoch 22/250
# 24/24 - 0s - loss: 0.0398 - val_loss: 0.0976 - 189ms/epoch - 8ms/step
# Epoch 23/250
# 24/24 - 0s - loss: 0.0384 - val_loss: 0.0960 - 197ms/epoch - 8ms/step
# Epoch 24/250
# 24/24 - 0s - loss: 0.0376 - val_loss: 0.0931 - 191ms/epoch - 8ms/step
# Epoch 25/250
# 24/24 - 0s - loss: 0.0359 - val_loss: 0.0914 - 192ms/epoch - 8ms/step
# Epoch 26/250
# 24/24 - 0s - loss: 0.0357 - val_loss: 0.0882 - 192ms/epoch - 8ms/step
# Epoch 27/250
# 24/24 - 0s - loss: 0.0342 - val_loss: 0.0864 - 187ms/epoch - 8ms/step
# Epoch 28/250
# 24/24 - 0s - loss: 0.0343 - val_loss: 0.0842 - 187ms/epoch - 8ms/step
# Epoch 29/250
# 24/24 - 0s - loss: 0.0319 - val_loss: 0.0814 - 189ms/epoch - 8ms/step
# Epoch 30/250
# 24/24 - 0s - loss: 0.0322 - val_loss: 0.0782 - 189ms/epoch - 8ms/step
# Epoch 31/250
# 24/24 - 0s - loss: 0.0314 - val_loss: 0.0774 - 187ms/epoch - 8ms/step
# Epoch 32/250
# 24/24 - 0s - loss: 0.0303 - val_loss: 0.0743 - 187ms/epoch - 8ms/step
# Epoch 33/250
# 24/24 - 0s - loss: 0.0298 - val_loss: 0.0719 - 189ms/epoch - 8ms/step
# Epoch 34/250
# 24/24 - 0s - loss: 0.0298 - val_loss: 0.0693 - 190ms/epoch - 8ms/step
# Epoch 35/250
# 24/24 - 0s - loss: 0.0283 - val_loss: 0.0671 - 187ms/epoch - 8ms/step
# Epoch 36/250
# 24/24 - 0s - loss: 0.0285 - val_loss: 0.0662 - 188ms/epoch - 8ms/step
# Epoch 37/250
# 24/24 - 0s - loss: 0.0275 - val_loss: 0.0642 - 192ms/epoch - 8ms/step
# Epoch 38/250
# 24/24 - 0s - loss: 0.0279 - val_loss: 0.0625 - 194ms/epoch - 8ms/step
# Epoch 39/250
# 24/24 - 0s - loss: 0.0262 - val_loss: 0.0610 - 188ms/epoch - 8ms/step
# Epoch 40/250
# 24/24 - 0s - loss: 0.0262 - val_loss: 0.0602 - 191ms/epoch - 8ms/step
# Epoch 41/250
# 24/24 - 0s - loss: 0.0271 - val_loss: 0.0584 - 189ms/epoch - 8ms/step
# Epoch 42/250
# 24/24 - 0s - loss: 0.0258 - val_loss: 0.0571 - 191ms/epoch - 8ms/step
# Epoch 43/250
# 24/24 - 0s - loss: 0.0255 - val_loss: 0.0572 - 190ms/epoch - 8ms/step
# Epoch 44/250
# 24/24 - 0s - loss: 0.0252 - val_loss: 0.0565 - 189ms/epoch - 8ms/step
# Epoch 45/250
# 24/24 - 0s - loss: 0.0250 - val_loss: 0.0558 - 190ms/epoch - 8ms/step
# Epoch 46/250
# 24/24 - 0s - loss: 0.0238 - val_loss: 0.0540 - 187ms/epoch - 8ms/step
# Epoch 47/250
# 24/24 - 0s - loss: 0.0241 - val_loss: 0.0521 - 188ms/epoch - 8ms/step
# Epoch 48/250
# 24/24 - 0s - loss: 0.0226 - val_loss: 0.0522 - 193ms/epoch - 8ms/step
# Epoch 49/250
# 24/24 - 0s - loss: 0.0235 - val_loss: 0.0496 - 197ms/epoch - 8ms/step
# Epoch 50/250
# 24/24 - 0s - loss: 0.0233 - val_loss: 0.0484 - 188ms/epoch - 8ms/step
# Epoch 51/250
# 24/24 - 0s - loss: 0.0228 - val_loss: 0.0468 - 186ms/epoch - 8ms/step
# Epoch 52/250
# 24/24 - 0s - loss: 0.0214 - val_loss: 0.0455 - 201ms/epoch - 8ms/step
# Epoch 53/250
# 24/24 - 0s - loss: 0.0214 - val_loss: 0.0443 - 197ms/epoch - 8ms/step
# Epoch 54/250
# 24/24 - 0s - loss: 0.0211 - val_loss: 0.0426 - 187ms/epoch - 8ms/step
# Epoch 55/250
# 24/24 - 0s - loss: 0.0212 - val_loss: 0.0414 - 187ms/epoch - 8ms/step
# Epoch 56/250
# 24/24 - 0s - loss: 0.0206 - val_loss: 0.0387 - 195ms/epoch - 8ms/step
# Epoch 57/250
# 24/24 - 0s - loss: 0.0206 - val_loss: 0.0392 - 187ms/epoch - 8ms/step
# Epoch 58/250
# 24/24 - 0s - loss: 0.0199 - val_loss: 0.0361 - 185ms/epoch - 8ms/step
# Epoch 59/250
# 24/24 - 0s - loss: 0.0206 - val_loss: 0.0373 - 183ms/epoch - 8ms/step
# Epoch 60/250
# 24/24 - 0s - loss: 0.0204 - val_loss: 0.0345 - 191ms/epoch - 8ms/step
# Epoch 61/250
# 24/24 - 0s - loss: 0.0193 - val_loss: 0.0336 - 190ms/epoch - 8ms/step
# Epoch 62/250
# 24/24 - 0s - loss: 0.0194 - val_loss: 0.0319 - 187ms/epoch - 8ms/step
# Epoch 63/250
# 24/24 - 0s - loss: 0.0189 - val_loss: 0.0304 - 189ms/epoch - 8ms/step
# Epoch 64/250
# 24/24 - 0s - loss: 0.0185 - val_loss: 0.0307 - 190ms/epoch - 8ms/step
# Epoch 65/250
# 24/24 - 0s - loss: 0.0185 - val_loss: 0.0288 - 197ms/epoch - 8ms/step
# Epoch 66/250
# 24/24 - 0s - loss: 0.0182 - val_loss: 0.0292 - 185ms/epoch - 8ms/step
# Epoch 67/250
# 24/24 - 0s - loss: 0.0184 - val_loss: 0.0265 - 194ms/epoch - 8ms/step
# Epoch 68/250
# 24/24 - 0s - loss: 0.0182 - val_loss: 0.0270 - 183ms/epoch - 8ms/step
# Epoch 69/250
# 24/24 - 0s - loss: 0.0179 - val_loss: 0.0273 - 192ms/epoch - 8ms/step
# Epoch 70/250
# 24/24 - 0s - loss: 0.0173 - val_loss: 0.0252 - 190ms/epoch - 8ms/step
# Epoch 71/250
# 24/24 - 0s - loss: 0.0171 - val_loss: 0.0248 - 189ms/epoch - 8ms/step
# Epoch 72/250
# 24/24 - 0s - loss: 0.0173 - val_loss: 0.0244 - 187ms/epoch - 8ms/step
# Epoch 73/250
# 24/24 - 0s - loss: 0.0177 - val_loss: 0.0232 - 187ms/epoch - 8ms/step
# Epoch 74/250
# 24/24 - 0s - loss: 0.0171 - val_loss: 0.0243 - 186ms/epoch - 8ms/step
# Epoch 75/250
# 24/24 - 0s - loss: 0.0170 - val_loss: 0.0215 - 185ms/epoch - 8ms/step
# Epoch 76/250
# 24/24 - 0s - loss: 0.0164 - val_loss: 0.0212 - 184ms/epoch - 8ms/step
# Epoch 77/250
# 24/24 - 0s - loss: 0.0167 - val_loss: 0.0218 - 184ms/epoch - 8ms/step
# Epoch 78/250
# 24/24 - 0s - loss: 0.0163 - val_loss: 0.0202 - 194ms/epoch - 8ms/step
# Epoch 79/250
# 24/24 - 0s - loss: 0.0166 - val_loss: 0.0208 - 186ms/epoch - 8ms/step
# Epoch 80/250
# 24/24 - 0s - loss: 0.0159 - val_loss: 0.0207 - 187ms/epoch - 8ms/step
# Epoch 81/250
# 24/24 - 0s - loss: 0.0164 - val_loss: 0.0192 - 187ms/epoch - 8ms/step
# Epoch 82/250
# 24/24 - 0s - loss: 0.0156 - val_loss: 0.0197 - 190ms/epoch - 8ms/step
# Epoch 83/250
# 24/24 - 0s - loss: 0.0160 - val_loss: 0.0189 - 188ms/epoch - 8ms/step
# Epoch 84/250
# 24/24 - 0s - loss: 0.0162 - val_loss: 0.0189 - 185ms/epoch - 8ms/step
# Epoch 85/250
# 24/24 - 0s - loss: 0.0149 - val_loss: 0.0187 - 186ms/epoch - 8ms/step
# Epoch 86/250
# 24/24 - 0s - loss: 0.0163 - val_loss: 0.0177 - 181ms/epoch - 8ms/step
# Epoch 87/250
# 24/24 - 0s - loss: 0.0160 - val_loss: 0.0171 - 183ms/epoch - 8ms/step
# Epoch 88/250
# 24/24 - 0s - loss: 0.0157 - val_loss: 0.0174 - 184ms/epoch - 8ms/step
# Epoch 89/250
# 24/24 - 0s - loss: 0.0154 - val_loss: 0.0171 - 185ms/epoch - 8ms/step
# Epoch 90/250
# 24/24 - 0s - loss: 0.0148 - val_loss: 0.0175 - 185ms/epoch - 8ms/step
# Epoch 91/250
# 24/24 - 0s - loss: 0.0146 - val_loss: 0.0173 - 180ms/epoch - 8ms/step
# Epoch 92/250
# 24/24 - 0s - loss: 0.0147 - val_loss: 0.0164 - 192ms/epoch - 8ms/step
# Epoch 93/250
# 24/24 - 0s - loss: 0.0153 - val_loss: 0.0163 - 188ms/epoch - 8ms/step
# Epoch 94/250
# 24/24 - 0s - loss: 0.0147 - val_loss: 0.0161 - 187ms/epoch - 8ms/step
# Epoch 95/250
# 24/24 - 0s - loss: 0.0143 - val_loss: 0.0160 - 185ms/epoch - 8ms/step
# Epoch 96/250
# 24/24 - 0s - loss: 0.0144 - val_loss: 0.0158 - 186ms/epoch - 8ms/step
# Epoch 97/250
# 24/24 - 0s - loss: 0.0145 - val_loss: 0.0151 - 187ms/epoch - 8ms/step
# Epoch 98/250
# 24/24 - 0s - loss: 0.0144 - val_loss: 0.0153 - 190ms/epoch - 8ms/step
# Epoch 99/250
# 24/24 - 0s - loss: 0.0145 - val_loss: 0.0156 - 190ms/epoch - 8ms/step
# Epoch 100/250
# 24/24 - 0s - loss: 0.0151 - val_loss: 0.0158 - 184ms/epoch - 8ms/step
# Epoch 101/250
# 24/24 - 0s - loss: 0.0139 - val_loss: 0.0152 - 190ms/epoch - 8ms/step
# Epoch 102/250
# 24/24 - 0s - loss: 0.0145 - val_loss: 0.0150 - 186ms/epoch - 8ms/step
# Epoch 103/250
# 24/24 - 0s - loss: 0.0137 - val_loss: 0.0148 - 188ms/epoch - 8ms/step
# Epoch 104/250
# 24/24 - 0s - loss: 0.0139 - val_loss: 0.0148 - 190ms/epoch - 8ms/step
# Epoch 105/250
# 24/24 - 0s - loss: 0.0136 - val_loss: 0.0151 - 186ms/epoch - 8ms/step
# Epoch 106/250
# 24/24 - 0s - loss: 0.0132 - val_loss: 0.0153 - 185ms/epoch - 8ms/step
# Epoch 107/250
# 24/24 - 0s - loss: 0.0133 - val_loss: 0.0146 - 184ms/epoch - 8ms/step
# Epoch 108/250
# 24/24 - 0s - loss: 0.0138 - val_loss: 0.0146 - 195ms/epoch - 8ms/step
# Epoch 109/250
# 24/24 - 0s - loss: 0.0138 - val_loss: 0.0147 - 186ms/epoch - 8ms/step
# Epoch 110/250
# 24/24 - 0s - loss: 0.0126 - val_loss: 0.0154 - 190ms/epoch - 8ms/step
# Epoch 111/250
# 24/24 - 0s - loss: 0.0131 - val_loss: 0.0151 - 184ms/epoch - 8ms/step
# Epoch 112/250
# 24/24 - 0s - loss: 0.0135 - val_loss: 0.0149 - 186ms/epoch - 8ms/step
# Epoch 113/250
# 24/24 - 0s - loss: 0.0127 - val_loss: 0.0148 - 188ms/epoch - 8ms/step
# Epoch 114/250
# 24/24 - 0s - loss: 0.0134 - val_loss: 0.0151 - 193ms/epoch - 8ms/step
# Epoch 115/250
# 24/24 - 0s - loss: 0.0129 - val_loss: 0.0148 - 184ms/epoch - 8ms/step
# Epoch 116/250
# 24/24 - 0s - loss: 0.0128 - val_loss: 0.0149 - 187ms/epoch - 8ms/step
# Epoch 117/250
# 24/24 - 0s - loss: 0.0130 - val_loss: 0.0144 - 186ms/epoch - 8ms/step
# Epoch 118/250
# 24/24 - 0s - loss: 0.0129 - val_loss: 0.0145 - 183ms/epoch - 8ms/step
# Epoch 119/250
# 24/24 - 0s - loss: 0.0131 - val_loss: 0.0146 - 197ms/epoch - 8ms/step
# Epoch 120/250
# 24/24 - 0s - loss: 0.0127 - val_loss: 0.0148 - 183ms/epoch - 8ms/step
# Epoch 121/250
# 24/24 - 0s - loss: 0.0124 - val_loss: 0.0146 - 201ms/epoch - 8ms/step
# Epoch 122/250
# 24/24 - 0s - loss: 0.0127 - val_loss: 0.0150 - 187ms/epoch - 8ms/step
# Epoch 123/250
# 24/24 - 0s - loss: 0.0118 - val_loss: 0.0148 - 185ms/epoch - 8ms/step
# Epoch 124/250
# 24/24 - 0s - loss: 0.0121 - val_loss: 0.0149 - 185ms/epoch - 8ms/step
# Epoch 125/250
# 24/24 - 0s - loss: 0.0124 - val_loss: 0.0154 - 187ms/epoch - 8ms/step
# Epoch 126/250
# 24/24 - 0s - loss: 0.0120 - val_loss: 0.0150 - 187ms/epoch - 8ms/step
# Epoch 127/250
# 24/24 - 0s - loss: 0.0124 - val_loss: 0.0156 - 189ms/epoch - 8ms/step
# Epoch 128/250
# 24/24 - 0s - loss: 0.0121 - val_loss: 0.0153 - 184ms/epoch - 8ms/step
# Epoch 129/250
# 24/24 - 0s - loss: 0.0121 - val_loss: 0.0151 - 185ms/epoch - 8ms/step
# Epoch 130/250
# 24/24 - 0s - loss: 0.0119 - val_loss: 0.0154 - 184ms/epoch - 8ms/step
# Epoch 131/250
# 24/24 - 0s - loss: 0.0121 - val_loss: 0.0149 - 183ms/epoch - 8ms/step
# Epoch 132/250
# 24/24 - 0s - loss: 0.0118 - val_loss: 0.0158 - 185ms/epoch - 8ms/step
# Epoch 133/250
# 24/24 - 0s - loss: 0.0116 - val_loss: 0.0155 - 181ms/epoch - 8ms/step
# Epoch 134/250
# 24/24 - 0s - loss: 0.0121 - val_loss: 0.0154 - 179ms/epoch - 7ms/step
# Epoch 135/250
# 24/24 - 0s - loss: 0.0119 - val_loss: 0.0155 - 185ms/epoch - 8ms/step
# Epoch 136/250
# 24/24 - 0s - loss: 0.0118 - val_loss: 0.0149 - 179ms/epoch - 7ms/step
# Epoch 137/250
# 24/24 - 0s - loss: 0.0121 - val_loss: 0.0154 - 200ms/epoch - 8ms/step
# Epoch 138/250
# 24/24 - 0s - loss: 0.0115 - val_loss: 0.0153 - 186ms/epoch - 8ms/step
# Epoch 139/250
# 24/24 - 0s - loss: 0.0117 - val_loss: 0.0152 - 186ms/epoch - 8ms/step
# Epoch 140/250
# 24/24 - 0s - loss: 0.0115 - val_loss: 0.0156 - 185ms/epoch - 8ms/step
# Epoch 141/250
# 24/24 - 0s - loss: 0.0114 - val_loss: 0.0160 - 184ms/epoch - 8ms/step
# Epoch 142/250
# 24/24 - 0s - loss: 0.0112 - val_loss: 0.0166 - 182ms/epoch - 8ms/step
# Epoch 143/250
# 24/24 - 0s - loss: 0.0112 - val_loss: 0.0156 - 185ms/epoch - 8ms/step
# Epoch 144/250
# 24/24 - 0s - loss: 0.0112 - val_loss: 0.0153 - 183ms/epoch - 8ms/step
# Epoch 145/250
# 24/24 - 0s - loss: 0.0115 - val_loss: 0.0160 - 182ms/epoch - 8ms/step
# Epoch 146/250
# 24/24 - 0s - loss: 0.0110 - val_loss: 0.0155 - 185ms/epoch - 8ms/step
# Epoch 147/250
# 24/24 - 0s - loss: 0.0109 - val_loss: 0.0156 - 184ms/epoch - 8ms/step
# Epoch 148/250
# 24/24 - 0s - loss: 0.0112 - val_loss: 0.0155 - 189ms/epoch - 8ms/step
# Epoch 149/250
# 24/24 - 0s - loss: 0.0111 - val_loss: 0.0150 - 184ms/epoch - 8ms/step
# Epoch 150/250
# 24/24 - 0s - loss: 0.0111 - val_loss: 0.0156 - 188ms/epoch - 8ms/step
# Epoch 151/250
# 24/24 - 0s - loss: 0.0109 - val_loss: 0.0158 - 186ms/epoch - 8ms/step
# Epoch 152/250
# 24/24 - 0s - loss: 0.0107 - val_loss: 0.0159 - 185ms/epoch - 8ms/step
# Epoch 153/250
# 24/24 - 0s - loss: 0.0111 - val_loss: 0.0145 - 187ms/epoch - 8ms/step
# Epoch 154/250
# 24/24 - 0s - loss: 0.0106 - val_loss: 0.0147 - 183ms/epoch - 8ms/step
# Epoch 155/250
# 24/24 - 0s - loss: 0.0110 - val_loss: 0.0155 - 182ms/epoch - 8ms/step
# Epoch 156/250
# 24/24 - 0s - loss: 0.0113 - val_loss: 0.0145 - 185ms/epoch - 8ms/step
# Epoch 157/250
# 24/24 - 0s - loss: 0.0105 - val_loss: 0.0153 - 181ms/epoch - 8ms/step
# Epoch 158/250
# 24/24 - 0s - loss: 0.0110 - val_loss: 0.0149 - 183ms/epoch - 8ms/step
# Epoch 159/250
# 24/24 - 0s - loss: 0.0105 - val_loss: 0.0163 - 181ms/epoch - 8ms/step
# Epoch 160/250
# 24/24 - 0s - loss: 0.0104 - val_loss: 0.0155 - 183ms/epoch - 8ms/step
# Epoch 161/250
# 24/24 - 0s - loss: 0.0110 - val_loss: 0.0148 - 180ms/epoch - 7ms/step
# Epoch 162/250
# 24/24 - 0s - loss: 0.0105 - val_loss: 0.0151 - 184ms/epoch - 8ms/step
# Epoch 163/250
# 24/24 - 0s - loss: 0.0103 - val_loss: 0.0151 - 185ms/epoch - 8ms/step
# Epoch 164/250
# 24/24 - 0s - loss: 0.0102 - val_loss: 0.0157 - 185ms/epoch - 8ms/step
# Epoch 165/250
# 24/24 - 0s - loss: 0.0105 - val_loss: 0.0154 - 185ms/epoch - 8ms/step
# Epoch 166/250
# 24/24 - 0s - loss: 0.0107 - val_loss: 0.0148 - 189ms/epoch - 8ms/step
# Epoch 167/250
# 24/24 - 0s - loss: 0.0105 - val_loss: 0.0151 - 186ms/epoch - 8ms/step
# Epoch 168/250
# 24/24 - 0s - loss: 0.0103 - val_loss: 0.0147 - 185ms/epoch - 8ms/step
# Epoch 169/250
# 24/24 - 0s - loss: 0.0100 - val_loss: 0.0156 - 184ms/epoch - 8ms/step
# Epoch 170/250
# 24/24 - 0s - loss: 0.0100 - val_loss: 0.0145 - 181ms/epoch - 8ms/step
# Epoch 171/250
# 24/24 - 0s - loss: 0.0099 - val_loss: 0.0149 - 181ms/epoch - 8ms/step
# Epoch 172/250
# 24/24 - 0s - loss: 0.0098 - val_loss: 0.0149 - 182ms/epoch - 8ms/step
# Epoch 173/250
# 24/24 - 0s - loss: 0.0103 - val_loss: 0.0146 - 188ms/epoch - 8ms/step
# Epoch 174/250
# 24/24 - 0s - loss: 0.0103 - val_loss: 0.0148 - 184ms/epoch - 8ms/step
# Epoch 175/250
# 24/24 - 0s - loss: 0.0104 - val_loss: 0.0155 - 182ms/epoch - 8ms/step
# Epoch 176/250
# 24/24 - 0s - loss: 0.0107 - val_loss: 0.0154 - 184ms/epoch - 8ms/step
# Epoch 177/250
# 24/24 - 0s - loss: 0.0100 - val_loss: 0.0150 - 204ms/epoch - 9ms/step
# Epoch 178/250
# 24/24 - 0s - loss: 0.0101 - val_loss: 0.0148 - 185ms/epoch - 8ms/step
# Epoch 179/250
# 24/24 - 0s - loss: 0.0098 - val_loss: 0.0150 - 206ms/epoch - 9ms/step
# Epoch 180/250
# 24/24 - 0s - loss: 0.0106 - val_loss: 0.0152 - 195ms/epoch - 8ms/step
# Epoch 181/250
# 24/24 - 0s - loss: 0.0103 - val_loss: 0.0159 - 185ms/epoch - 8ms/step
# Epoch 182/250
# 24/24 - 0s - loss: 0.0095 - val_loss: 0.0148 - 196ms/epoch - 8ms/step
# Epoch 183/250
# 24/24 - 0s - loss: 0.0101 - val_loss: 0.0155 - 186ms/epoch - 8ms/step
# Epoch 184/250
# 24/24 - 0s - loss: 0.0099 - val_loss: 0.0151 - 192ms/epoch - 8ms/step
# Epoch 185/250
# 24/24 - 0s - loss: 0.0104 - val_loss: 0.0154 - 188ms/epoch - 8ms/step
# Epoch 186/250
# 24/24 - 0s - loss: 0.0098 - val_loss: 0.0151 - 187ms/epoch - 8ms/step
# Epoch 187/250
# 24/24 - 0s - loss: 0.0096 - val_loss: 0.0143 - 185ms/epoch - 8ms/step
# Epoch 188/250
# 24/24 - 0s - loss: 0.0099 - val_loss: 0.0152 - 191ms/epoch - 8ms/step
# Epoch 189/250
# 24/24 - 0s - loss: 0.0096 - val_loss: 0.0146 - 190ms/epoch - 8ms/step
# Epoch 190/250
# 24/24 - 0s - loss: 0.0096 - val_loss: 0.0146 - 180ms/epoch - 7ms/step
# Epoch 191/250
# 24/24 - 0s - loss: 0.0095 - val_loss: 0.0147 - 189ms/epoch - 8ms/step
# Epoch 192/250
# 24/24 - 0s - loss: 0.0089 - val_loss: 0.0137 - 184ms/epoch - 8ms/step
# Epoch 193/250
# 24/24 - 0s - loss: 0.0095 - val_loss: 0.0148 - 203ms/epoch - 8ms/step
# Epoch 194/250
# 24/24 - 0s - loss: 0.0094 - val_loss: 0.0148 - 191ms/epoch - 8ms/step
# Epoch 195/250
# 24/24 - 0s - loss: 0.0095 - val_loss: 0.0148 - 184ms/epoch - 8ms/step
# Epoch 196/250
# 24/24 - 0s - loss: 0.0095 - val_loss: 0.0140 - 190ms/epoch - 8ms/step
# Epoch 197/250
# 24/24 - 0s - loss: 0.0094 - val_loss: 0.0144 - 186ms/epoch - 8ms/step
# Epoch 198/250
# 24/24 - 0s - loss: 0.0097 - val_loss: 0.0148 - 179ms/epoch - 7ms/step
# Epoch 199/250
# 24/24 - 0s - loss: 0.0096 - val_loss: 0.0147 - 188ms/epoch - 8ms/step
# Epoch 200/250
# 24/24 - 0s - loss: 0.0098 - val_loss: 0.0141 - 186ms/epoch - 8ms/step
# Epoch 201/250
# 24/24 - 0s - loss: 0.0096 - val_loss: 0.0143 - 186ms/epoch - 8ms/step
# Epoch 202/250
# 24/24 - 0s - loss: 0.0095 - val_loss: 0.0147 - 189ms/epoch - 8ms/step
# Epoch 203/250
# 24/24 - 0s - loss: 0.0097 - val_loss: 0.0142 - 189ms/epoch - 8ms/step
# Epoch 204/250
# 24/24 - 0s - loss: 0.0093 - val_loss: 0.0147 - 186ms/epoch - 8ms/step
# Epoch 205/250
# 24/24 - 0s - loss: 0.0094 - val_loss: 0.0143 - 190ms/epoch - 8ms/step
# Epoch 206/250
# 24/24 - 0s - loss: 0.0095 - val_loss: 0.0151 - 183ms/epoch - 8ms/step
# Epoch 207/250
# 24/24 - 0s - loss: 0.0090 - val_loss: 0.0145 - 189ms/epoch - 8ms/step
# Epoch 208/250
# 24/24 - 0s - loss: 0.0091 - val_loss: 0.0147 - 188ms/epoch - 8ms/step
# Epoch 209/250
# 24/24 - 0s - loss: 0.0097 - val_loss: 0.0149 - 186ms/epoch - 8ms/step
# Epoch 210/250
# 24/24 - 0s - loss: 0.0094 - val_loss: 0.0147 - 188ms/epoch - 8ms/step
# Epoch 211/250
# 24/24 - 0s - loss: 0.0092 - val_loss: 0.0150 - 188ms/epoch - 8ms/step
# Epoch 212/250
# 24/24 - 0s - loss: 0.0093 - val_loss: 0.0146 - 189ms/epoch - 8ms/step
# Epoch 213/250
# 24/24 - 0s - loss: 0.0089 - val_loss: 0.0153 - 185ms/epoch - 8ms/step
# Epoch 214/250
# 24/24 - 0s - loss: 0.0093 - val_loss: 0.0148 - 193ms/epoch - 8ms/step
# Epoch 215/250
# 24/24 - 0s - loss: 0.0093 - val_loss: 0.0143 - 198ms/epoch - 8ms/step
# Epoch 216/250
# 24/24 - 0s - loss: 0.0095 - val_loss: 0.0138 - 185ms/epoch - 8ms/step
# Epoch 217/250
# 24/24 - 0s - loss: 0.0092 - val_loss: 0.0142 - 185ms/epoch - 8ms/step
# Epoch 218/250
# 24/24 - 0s - loss: 0.0091 - val_loss: 0.0145 - 186ms/epoch - 8ms/step
# Epoch 219/250
# 24/24 - 0s - loss: 0.0089 - val_loss: 0.0150 - 186ms/epoch - 8ms/step
# Epoch 220/250
# 24/24 - 0s - loss: 0.0101 - val_loss: 0.0146 - 188ms/epoch - 8ms/step
# Epoch 221/250
# 24/24 - 0s - loss: 0.0095 - val_loss: 0.0148 - 184ms/epoch - 8ms/step
# Epoch 222/250
# 24/24 - 0s - loss: 0.0092 - val_loss: 0.0131 - 185ms/epoch - 8ms/step
# Epoch 223/250
# 24/24 - 0s - loss: 0.0093 - val_loss: 0.0146 - 184ms/epoch - 8ms/step
# Epoch 224/250
# 24/24 - 0s - loss: 0.0091 - val_loss: 0.0147 - 182ms/epoch - 8ms/step
# Epoch 225/250
# 24/24 - 0s - loss: 0.0093 - val_loss: 0.0145 - 185ms/epoch - 8ms/step
# Epoch 226/250
# 24/24 - 0s - loss: 0.0090 - val_loss: 0.0147 - 185ms/epoch - 8ms/step
# Epoch 227/250
# 24/24 - 0s - loss: 0.0093 - val_loss: 0.0144 - 188ms/epoch - 8ms/step
# Epoch 228/250
# 24/24 - 0s - loss: 0.0091 - val_loss: 0.0142 - 187ms/epoch - 8ms/step
# Epoch 229/250
# 24/24 - 0s - loss: 0.0089 - val_loss: 0.0142 - 188ms/epoch - 8ms/step
# Epoch 230/250
# 24/24 - 0s - loss: 0.0089 - val_loss: 0.0141 - 193ms/epoch - 8ms/step
# Epoch 231/250
# 24/24 - 0s - loss: 0.0092 - val_loss: 0.0140 - 212ms/epoch - 9ms/step
# Epoch 232/250
# 24/24 - 0s - loss: 0.0091 - val_loss: 0.0140 - 194ms/epoch - 8ms/step
# Epoch 233/250
# 24/24 - 0s - loss: 0.0089 - val_loss: 0.0148 - 186ms/epoch - 8ms/step
# Epoch 234/250
# 24/24 - 0s - loss: 0.0086 - val_loss: 0.0149 - 184ms/epoch - 8ms/step
# Epoch 235/250
# 24/24 - 0s - loss: 0.0093 - val_loss: 0.0144 - 187ms/epoch - 8ms/step
# Epoch 236/250
# 24/24 - 0s - loss: 0.0095 - val_loss: 0.0155 - 204ms/epoch - 8ms/step
# Epoch 237/250
# 24/24 - 0s - loss: 0.0092 - val_loss: 0.0147 - 216ms/epoch - 9ms/step
# Epoch 238/250
# 24/24 - 0s - loss: 0.0087 - val_loss: 0.0141 - 184ms/epoch - 8ms/step
# Epoch 239/250
# 24/24 - 0s - loss: 0.0087 - val_loss: 0.0146 - 185ms/epoch - 8ms/step
# Epoch 240/250
# 24/24 - 0s - loss: 0.0088 - val_loss: 0.0156 - 191ms/epoch - 8ms/step
# Epoch 241/250
# 24/24 - 0s - loss: 0.0088 - val_loss: 0.0146 - 186ms/epoch - 8ms/step
# Epoch 242/250
# 24/24 - 0s - loss: 0.0092 - val_loss: 0.0139 - 194ms/epoch - 8ms/step
# Epoch 243/250
# 24/24 - 0s - loss: 0.0088 - val_loss: 0.0143 - 189ms/epoch - 8ms/step
# Epoch 244/250
# 24/24 - 0s - loss: 0.0094 - val_loss: 0.0147 - 195ms/epoch - 8ms/step
# Epoch 245/250
# 24/24 - 0s - loss: 0.0089 - val_loss: 0.0143 - 187ms/epoch - 8ms/step
# Epoch 246/250
# 24/24 - 0s - loss: 0.0097 - val_loss: 0.0142 - 186ms/epoch - 8ms/step
# Epoch 247/250
# 24/24 - 0s - loss: 0.0092 - val_loss: 0.0143 - 187ms/epoch - 8ms/step
# Epoch 248/250
# 24/24 - 0s - loss: 0.0092 - val_loss: 0.0148 - 185ms/epoch - 8ms/step
# Epoch 249/250
# 24/24 - 0s - loss: 0.0090 - val_loss: 0.0148 - 186ms/epoch - 8ms/step
# Epoch 250/250
# 24/24 - 0s - loss: 0.0090 - val_loss: 0.0155 - 190ms/epoch - 8ms/step
# Normalized Test RMSE:  0.11157521216844374 0.14397238602299667 0.14081041377986114 0.09391196981677961
# Test RMSE:  220.9189084714059 281.0341131263421 482.5572864399983 0.09391197208016791
# Test R-squared:  0.8738685468188753 0.8175153643685615 0.8727632351325681 0.9354270645296835
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 50)             11400
#
#  dropout (Dropout)           (None, 1, 50)             0
#
#  lstm_1 (LSTM)               (None, 1, 20)             5680
#
#  dropout_1 (Dropout)         (None, 1, 20)             0
#
#  lstm_2 (LSTM)               (None, 20)                3280
#
#  dropout_2 (Dropout)         (None, 20)                0
#
#  dense (Dense)               (None, 4)                 84
#
# =================================================================
# Total params: 20,444
# Trainable params: 20,444
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <module>
#     155 print("Test R-squared: ", r_sq1, r_sq2, r_sq3, r_sq4)
#     156 model.summary()
# --> 158 import xlsxwriter
#     160 # Create file (workbook) and worksheet
#     161 outWorkbook = xlsxwriter.Workbook("out.xlsx")
#
# ModuleNotFoundError: No module named 'xlsxwriter'

# %%
# %tensorboard --logdir mylog
# Out:
# Reusing TensorBoard on port 6006 (pid 3200), started 19:59:37 ago. (Use '!kill 3200' to kill it.)
#       <iframe id="tensorboard-frame-42e2064a11932361" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-42e2064a11932361");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from keras.models import load_model

model = load_model('multi_lstm_model.h5')

test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
yhat = model.predict(test_X)
#calculate RMSE - CHANGED to output RMSE for each variable.
norm_rmse_1 = sqrt(mean_squared_error(y_hat[:241,0], test_y[:,0])) #RMSE for the first variable (Tank_1)
norm_rmse_2 = sqrt(mean_squared_error(y_hat[:241,1], test_y[:,1])) #RMSE for the second variable (Tank_2)
norm_rmse_3 = sqrt(mean_squared_error(y_hat[:241,2], test_y[:,2])) #RMSE for the third variable (Tank_3)
norm_rmse_4 = sqrt(mean_squared_error(y_hat[:241,3], test_y[:,3])) #RMSE for the fourth variable (Pump_1)
print('Test RMSE: ', norm_rmse_1, norm_rmse_2, norm_rmse_3, norm_rmse_4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <module>
#       3 model = load_model('multi_lstm_model.h5')
#       5 test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
# ----> 6 yhat = model.predict(test_X)
#       7 #calculate RMSE - CHANGED to output RMSE for each variable.
#       8 norm_rmse_1 = sqrt(mean_squared_error(y_hat[:241,0], test_y[:,0])) #RMSE for the first variable (Tank_1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\func_graph.py:1147, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1145 except Exception as e:  # pylint:disable=broad-except
#    1146   if hasattr(e, "ag_error_metadata"):
# -> 1147     raise e.ag_error_metadata.to_exception(e)
#    1148   else:
#    1149     raise
#
# ValueError: in user code:
#
#     File "C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 1801, in predict_function  *
#         return step_function(self, iterator)
#     File "C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 1790, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 1783, in run_step  **
#         outputs = model.predict_step(data)
#     File "C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py", line 1751, in predict_step
#         return self(x, training=False)
#     File "C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\input_spec.py", line 264, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential_8" is incompatible with the layer: expected shape=(None, 3, 6), found shape=(None, 1, 6)

# %% [markdown]
# ### Box plot for rmse

# %%
from pandas import DataFrame
from pandas import read_csv
from numpy import mean
from numpy import std
from matplotlib import pyplot
# load results file
results = read_csv('rmse_multiple_results.csv', header=0)
# descriptive stats
print(results.describe())
# box and whisker plot
results.boxplot(whiskerprops = dict(linestyle='-', linewidth=2))
pyplot.ylabel("RMSE")
pyplot.show()
# histogram
results.hist()
pyplot.show()
# Out:
#            Tank_1      Tank_2      Tank_3     Pump_1
# count   33.000000   33.000000   33.000000  33.000000
# mean   144.161401  109.906095  134.719121   0.117114
# std     29.680144   35.276328   34.676943   0.009327
# min     88.629391   59.307521   74.722553   0.100214
# 25%    128.229447   79.751047  110.285824   0.109556
# 50%    142.568261  110.000502  126.947889   0.117160
# 75%    152.599295  128.335886  152.758458   0.124281
# max    210.698327  197.403725  201.181122   0.132437

# %%
out_test.shape
# Out:
# (241, 12)

# %% [markdown]
# ### Box plot for normalised rmse

# %%
from pandas import DataFrame
from pandas import read_csv
from numpy import mean
from numpy import std
from matplotlib import pyplot
# load results file
results = read_csv('norm_rmse_multiple_results.csv', header=0)
# descriptive stats
print(results.describe())
# box and whisker plot
results.boxplot(whiskerprops = dict(linestyle='-', linewidth=2))
pyplot.ylabel("Normalised RMSE")
pyplot.show()
# histogram
results.hist()
pyplot.show()
# Out:
#           Tank_1     Tank_2     Tank_3     Pump_1
# count  33.000000  33.000000  33.000000  33.000000
# mean    0.072809   0.056304   0.039311   0.117114
# std     0.014990   0.018072   0.010119   0.009327
# min     0.044762   0.030383   0.021804   0.100214
# 25%     0.064762   0.040856   0.032181   0.109556
# 50%     0.072004   0.056353   0.037043   0.117160
# 75%     0.077070   0.065746   0.044575   0.124281
# max     0.106413   0.101129   0.058705   0.132437

# %% [markdown]
# ### Box Plot for COefficient of Determination (R-Squared )

# %%
from pandas import DataFrame
from pandas import read_csv
from numpy import mean
from numpy import std
from matplotlib import pyplot
# load results file
results = read_csv('r_sq_multiple_results.csv', header=0)
# descriptive stats
print(results.describe())
# box and whisker plot
results.boxplot(whiskerprops = dict(linestyle='-', linewidth=2))
pyplot.ylabel("R-squared")
pyplot.show()
# histogram
results.hist()
pyplot.show()
# Out:
#           Tank_1     Tank_2     Tank_3     Pump_1
# count  33.000000  33.000000  33.000000  33.000000
# mean    0.942453   0.970305   0.910426   0.937769
# std     0.023750   0.019602   0.044893   0.009843
# min     0.881927   0.912903   0.812304   0.920907
# 25%     0.938065   0.963188   0.891784   0.930348
# 50%     0.945940   0.972955   0.925264   0.938101
# 75%     0.956268   0.985784   0.943595   0.945875
# max     0.979108   0.992138   0.974107   0.954713

# %% [markdown]
# ### RMSE Function

# %%
import math
def rms(x,y):
    if len(x)!= len(y):
        return "The two inputs are incompatible"
    total = 0
    for i in range(len(x)):
        total += ((x[i]-y[i])**2)
    return math.sqrt(total/len(x))


p = [10,20,30,40,5]
q = [11,17,29,40]
print(rms(p,q))
val = [x for x in range(1000,10000,100)]
val2 = [k + 50 for k in val]
# del val2[3]
print(rms(val,val2))
# Out:
# The two inputs are incompatible
# 50.0

# %% [markdown]
# ### Plot the prediction

# %%
pyplot.plot(inv_yhat[0:500,0], label='predicted')
pyplot.plot(inv_y[0:500,0], label='actual')
pyplot.xlabel("Time step")
pyplot.ylabel("Tank 1")
pyplot.legend()
pyplot.show()

# %%
pyplot.plot(inv_yhat[0:500,1], label='predicted')
pyplot.plot(inv_y[0:500,1], label='actual')
pyplot.xlabel("Time step")
pyplot.ylabel("Tank 2")
pyplot.legend()
pyplot.show()

# %%
pyplot.plot(inv_yhat[0:500,2], label='predicted')
pyplot.plot(inv_y[0:500,2], label='actual')
pyplot.xlabel("Time step")
pyplot.ylabel("Tank 3")
pyplot.legend()
pyplot.show()

# %%
pyplot.plot(inv_yhat[0:500,3], label='predicted')
pyplot.plot(inv_y[0:500,3], label='actual')
pyplot.xlabel("Time step")
pyplot.ylabel("PUmp 1")
pyplot.legend()
pyplot.show()

# %% [markdown]
# ### Load saved model

# %%
from keras.models import load_model

model = load_model('multi_lstm_model.h5')

#split into input and outputs
# n_obs = n_hours * n_features

test_X = out_test[:, :n_obs]
test_y = out_test[:, -n_features:(-n_features+4)]

test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))

# Make a prediction
yhat = model.predict(test_X)

#calculate RMSE - CHANGED to output RMSE for each variable.
norm_rmse_1 = sqrt(mean_squared_error(y_hat[:241,0], test_y[:,0])) #RMSE for the first variable (Tank_1)
norm_rmse_2 = sqrt(mean_squared_error(y_hat[:241,1], test_y[:,1])) #RMSE for the second variable (Tank_2)
norm_rmse_3 = sqrt(mean_squared_error(y_hat[:241,2], test_y[:,2])) #RMSE for the third variable (Tank_3)
norm_rmse_4 = sqrt(mean_squared_error(y_hat[:241,3], test_y[:,3])) #RMSE for the fourth variable (Pump_1)
print('Test RMSE: ', norm_rmse_1, norm_rmse_2, norm_rmse_3, norm_rmse_4)
    
# test_X = test_X.reshape((test_X.shape[0], n_hours*n_features))
# inv_yhat = concatenate((y_hat, test_X[:,-2:]), axis=1) #changed 7 to 6
# inv_yhat = scaler.inverse_transform(inv_yhat)
# inv_yhat = inv_yhat[:,0:4] #changed from 0 to 0:2. Should be first 2 columns that contain the predictions
 

# #invert scaling for actual
# test_y = test_y.reshape((len(test_y),4)) #changed 1 to 2
# inv_y = concatenate((test_y, test_X[:,-2:]), axis=1) #changed 7 to 6
# inv_y = scaler.inverse_transform(inv_y)
# inv_y = inv_y[:,0:4] #changed from 0 to 0:2. Should be first 2 columns that contain the predictions.
 

    
# #calculate RMSE - CHANGED to output RMSE for each variable.
# rmse_1 = sqrt(mean_squared_error(inv_y[:,0], inv_yhat[:,0])) #RMSE for the first variable (Tank_1)
# rmse_2 = sqrt(mean_squared_error(inv_y[:,1], inv_yhat[:,1])) #RMSE for the second variable (Tank_2)
# rmse_3 = sqrt(mean_squared_error(inv_y[:,2], inv_yhat[:,2])) #RMSE for the third variable (Tank_3)
# rmse_4 = sqrt(mean_squared_error(inv_y[:,3], inv_yhat[:,3])) #RMSE for the fourth variable (Pump_1)

# r_sq1 = r2_score(inv_y[:,0], inv_yhat[:,0])
# r_sq2 = r2_score(inv_y[:,1], inv_yhat[:,1])
# r_sq3 = r2_score(inv_y[:,2], inv_yhat[:,2])
# r_sq4 = r2_score(inv_y[:,3], inv_yhat[:,3])

# print('Test RMSE: ', rmse_1, rmse_2, rmse_3, rmse_4)

# print("Test R-squared: ", r_sq1, r_sq2, r_sq3, r_sq4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from keras.models import load_model
#       3 model = load_model('multi_lstm_model.h5')
#       5 #split into input and outputs
#       6 # n_obs = n_hours * n_features
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\keras\__init__.py:21, in <module>
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python import tf2
#      22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\tensorflow\__init__.py:37, in <module>
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\tensorflow\python\__init__.py:37, in <module>
#      29 # We aim to keep this file minimal and ideally remove completely.
#      30 # If you are adding a new file with @tf_export decorators,
#      31 # import it in modules_with_exports.py instead.
#      32
#      33 # go/tf-wildcard-import
#      34 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
#      42 from tensorflow.python import data
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\tensorflow\python\eager\context.py:26, in <module>
#      23 import threading
#      25 from absl import logging
# ---> 26 import numpy as np
#      27 import six
#      29 from tensorflow.core.framework import function_pb2
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\numpy\__init__.py:159, in <module>
#     156 from .lib import *
#     158 from . import linalg
# --> 159 from . import fft
#     160 from . import polynomial
#     161 from . import random
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\numpy\fft\__init__.py:203, in <module>
#       1 """
#       2 Discrete Fourier Transform (:mod:`numpy.fft`)
#       3 =============================================
#    (...)
#     200
#     201 """
# --> 203 from . import _pocketfft, helper
#     204 from ._pocketfft import *
#     205 from .helper import *
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:971, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:914, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1407, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1379, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1539, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:156, in _path_isfile(path)
#
# File <frozen importlib._bootstrap_external>:148, in _path_is_mode_type(path, mode)
#
# File <frozen importlib._bootstrap_external>:142, in _path_stat(path)
#
# KeyboardInterrupt:

# %%
test_X.shape
# Out:
# (241, 1, 6)

# %% [markdown]
# ### After injecting some faults in the model

# %%
import tensorflow as tf
model.summary()
#print(len(model.weights))
print(len(model.get_weights()))
new_model = tf.keras.models.clone_model(model)
new_model.pop()
new_model.summary()
model.save('faulty_lstm_model.h5')
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_33 (LSTM)              (None, 1, 50)             11400
#
#  dropout_33 (Dropout)        (None, 1, 50)             0
#
#  lstm_34 (LSTM)              (None, 1, 20)             5680
#
#  dropout_34 (Dropout)        (None, 1, 20)             0
#
#  lstm_35 (LSTM)              (None, 20)                3280
#
#  dropout_35 (Dropout)        (None, 20)                0
#
#  dense_11 (Dense)            (None, 4)                 84
#
# =================================================================
# Total params: 20,444
# Trainable params: 20,444
# Non-trainable params: 0
# _________________________________________________________________
# 11
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_33 (LSTM)              (None, 1, 50)             11400
#
#  dropout_33 (Dropout)        (None, 1, 50)             0
#
#  lstm_34 (LSTM)              (None, 1, 20)             5680
#
#  dropout_34 (Dropout)        (None, 1, 20)             0
#
#  lstm_35 (LSTM)              (None, 20)                3280
#
#  dropout_35 (Dropout)        (None, 20)                0
#
# =================================================================
# Total params: 20,360
# Trainable params: 20,360
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.models import load_model

# model = load_model('multi_lstm_model.h5')
model = load_model('faulty_lstm_model.h5')

#Injecting faults
#model.layers[0].filters *=2


test_X = out_test[:, :n_obs]
test_y = out_test[:, -n_features:(-n_features+4)]

test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))

# Make a prediction
y_hat = model.predict(test_X)

#calculate RMSE - CHANGED to output RMSE for each variable.
norm_rmse_1 = sqrt(mean_squared_error(y_hat[:241,0], test_y[:,0])) #RMSE for the first variable (Tank_1)
norm_rmse_2 = sqrt(mean_squared_error(y_hat[:241,1], test_y[:,1])) #RMSE for the second variable (Tank_2)
norm_rmse_3 = sqrt(mean_squared_error(y_hat[:241,2], test_y[:,2])) #RMSE for the third variable (Tank_3)
norm_rmse_4 = sqrt(mean_squared_error(y_hat[:241,3], test_y[:,3])) #RMSE for the fourth variable (Pump_1)
print('Test RMSE: ', norm_rmse_1, norm_rmse_2, norm_rmse_3, norm_rmse_4)
    
# test_X = test_X.reshape((test_X.shape[0], n_hours*n_features))
# inv_yhat = concatenate((y_hat, test_X[:,-2:]), axis=1) #changed 7 to 6
# inv_yhat = scaler.inverse_transform(inv_yhat)
# inv_yhat = inv_yhat[:,0:4] #changed from 0 to 0:2. Should be first 2 columns that contain the predictions
 

# #invert scaling for actual
# test_y = test_y.reshape((len(test_y),4)) #changed 1 to 2
# inv_y = concatenate((test_y, test_X[:,-2:]), axis=1) #changed 7 to 6
# inv_y = scaler.inverse_transform(inv_y)
# inv_y = inv_y[:,0:4] #changed from 0 to 0:2. Should be first 2 columns that contain the predictions.
 

    
# #calculate RMSE - CHANGED to output RMSE for each variable.
# rmse_1 = sqrt(mean_squared_error(inv_y[:,0], inv_yhat[:,0])) #RMSE for the first variable (Tank_1)
# rmse_2 = sqrt(mean_squared_error(inv_y[:,1], inv_yhat[:,1])) #RMSE for the second variable (Tank_2)
# rmse_3 = sqrt(mean_squared_error(inv_y[:,2], inv_yhat[:,2])) #RMSE for the third variable (Tank_3)
# rmse_4 = sqrt(mean_squared_error(inv_y[:,3], inv_yhat[:,3])) #RMSE for the fourth variable (Pump_1)

# r_sq1 = r2_score(inv_y[:,0], inv_yhat[:,0])
# r_sq2 = r2_score(inv_y[:,1], inv_yhat[:,1])
# r_sq3 = r2_score(inv_y[:,2], inv_yhat[:,2])
# r_sq4 = r2_score(inv_y[:,3], inv_yhat[:,3])

# print('Test RMSE: ', rmse_1, rmse_2, rmse_3, rmse_4)

# print("Test R-squared: ", r_sq1, r_sq2, r_sq3, r_sq4)
# Out:
# Test RMSE:  0.08614524742897423 0.06842594311518578 0.041183177696781516 0.08832120328890113

# %%
pyplot.plot(test_y[:,], label='actual')
pyplot.legend()
pyplot.show()

# %%
print("jg")
# Out:
# jg
