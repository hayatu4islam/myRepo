# %% [markdown]
# ## Fault Injection (Value Flip)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
# ADF Test - null hypothesis - non-stationary - if p-value < 5% reject null hypothesis
# adfuller_result = adfuller(series, autolag="AIC")
# tankData = pd.read_csv("waterTankNew.csv", header=0, index_col=0)
tankData = pd.read_csv("trig.csv", header=0, index_col=0)
attr = ["sine", "cosine", "sin(2t)", "2sin(t+1)-3cos(t-1)"]
# adfuller_result = adfuller(tankData["wt3_valve"].values, autolag="AIC")

for feature in attr:
    
    adfuller_result = adfuller(tankData[feature].values, autolag="AIC")
    print("Stationarity metrics for each series")
    print(f'ADF Statistic: {adfuller_result[0]}')
    print(f'p-value: {adfuller_result[1]}')

    for key, value in adfuller_result[4].items():
        print('Critical Values: ')
        print(f'    {key}, {value}')

    print("Conclusion")
    if adfuller_result[1] > 0.05:
        print("Series is not stationary")
    else:
        print("Series is stationary")
    print("\n\n")
# Out:
# Stationarity metrics for each series
# ADF Statistic: -1011573335.1382487
# p-value: 0.0
# Critical Values:
#     1%, -3.4362125920049498
# Critical Values:
#     5%, -2.8641286575615426
# Critical Values:
#     10%, -2.5681482759591785
# Conclusion
# Series is stationary
#
#
#
# Stationarity metrics for each series
# ADF Statistic: -1011166234.5397538
# p-value: 0.0
# Critical Values:
#     1%, -3.4362125920049498
# Critical Values:
#     5%, -2.8641286575615426
# Critical Values:
#     10%, -2.5681482759591785
# Conclusion
# Series is stationary
#
#
#
# Stationarity metrics for each series
# ADF Statistic: -4839487399.352907
# p-value: 0.0
# Critical Values:
#     1%, -3.4362125920049498
# Critical Values:
#     5%, -2.8641286575615426
# Critical Values:
#     10%, -2.5681482759591785
# Conclusion
# Series is stationary
#
#
#
# Stationarity metrics for each series
# ADF Statistic: -1822503589.1901038
# p-value: 0.0
# Critical Values:
#     1%, -3.4362125920049498
# Critical Values:
#     5%, -2.8641286575615426
# Critical Values:
#     10%, -2.5681482759591785
# Conclusion
# Series is stationary

# %% [markdown]
# ### Visualise the data

# %%
from pandas import read_csv
# mydata = read_csv('waterTankNew.csv', header=0, index_col=0)
mydata = read_csv('trig.csv', header=0, index_col=0)
# attr = ["wt3_valve", "Tank1InFlow", "Tank1WaterLevel", "Tank3OutFlow", "Tank2.level"]
attr = ["sine", "cosine", "sin(2t)", "2sin(t+1)-3cos(t-1)"]
for i in range(len(attr)):
    title = "Plot of "+str(attr[i])
    actual = mydata.iloc[:2000,i]
#     actual = mydata.iloc[750:1000,i]
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylabel(attr[i])
#     plt.plot(actual, label="original")
    plt.plot(actual)
#     plt.legend()
    plt.show()

# %%
# multivariate output stacked lstm example
import pandas as pd
from numpy import array
from numpy import hstack, vstack
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Bidirectional, RepeatVector, TimeDistributed
from keras.layers.core import Dropout
from sklearn.preprocessing import MinMaxScaler
from pandas import read_csv
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np



# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# define input sequence

# Read the data
# data = read_csv('waterTank.csv', header=0, index_col=0)
# data = read_csv('outputs.csv', header=0, index_col=0)
# data = read_csv('trig.csv', header=0, index_col=0)
data = read_csv('trig.csv', header=0, index_col=0)

# horizontally stack columns
raw_data = data.values
print(f'The shape of the raw_data before scaling is {raw_data.shape}')
#normalize input features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(raw_data)

n_train = 1000
dataset = scaled_data[0:n_train,:]
# choose a number of time steps
# n_steps_in, n_steps_out = 50, 100
n_steps_in, n_steps_out = 50, 100

# convert into input/output
X, y = split_sequences(dataset, n_steps_in, n_steps_out)
# the dataset knows the number of features, e.g. 2
n_features = X.shape[2]
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps_in, n_features)))
model.add(RepeatVector(n_steps_out))
model.add(LSTM(50, activation='relu', return_sequences=True))
# model.add(TimeDistributed(Dense(50, activation='relu')))
model.add(TimeDistributed(Dense(n_features)))
# model.add(TimeDistributed(Dense(1)))
model.compile(optimizer='adam', loss='mse')
# fit model
train_history = model.fit(X, y, epochs=200, verbose=2, shuffle=False)

# demonstrate Direct prediction
# x_inp = raw_data[n_train:n_train+n_steps,:]
x_inp = scaled_data[n_train:n_train+n_steps_in,:]
print(f'Initial shape of x_input {x_inp.shape}')
x_input = x_inp.reshape((1, n_steps_in, n_features))
yhat = model.predict(x_input, verbose=0)
print(f'The shape of yhat after prediction is {yhat.shape}')
yhat = yhat.reshape(n_steps_out, n_features)
print(f'The new shape of yhat  is {yhat.shape}')
inv_yhat = scaler.inverse_transform(yhat)
print(inv_yhat)

print("-------Learning Curve--------")
plt.plot(train_history.history['loss'], label='train')
# plt.plot(train_history.history['val_loss'], label='test')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

model.summary()

#save the model to disk
model.save('Trig.h5')
print("Model saved!")
# Out:
# The shape of the raw_data before scaling is (1120, 4)
# Epoch 1/200
# 27/27 - 3s - loss: 0.2297 - 3s/epoch - 127ms/step
# Epoch 2/200
# 27/27 - 1s - loss: 0.1321 - 1s/epoch - 51ms/step
# Epoch 3/200
# 27/27 - 1s - loss: 0.1292 - 1s/epoch - 51ms/step
# Epoch 4/200
# 27/27 - 1s - loss: 0.1279 - 1s/epoch - 50ms/step
# Epoch 5/200
# 27/27 - 1s - loss: 0.1253 - 1s/epoch - 51ms/step
# Epoch 6/200
# 27/27 - 1s - loss: 0.1262 - 1s/epoch - 51ms/step
# Epoch 7/200
# 27/27 - 1s - loss: 0.1273 - 1s/epoch - 50ms/step
# Epoch 8/200
# 27/27 - 1s - loss: 0.1244 - 1s/epoch - 51ms/step
# Epoch 9/200
# 27/27 - 1s - loss: 0.1081 - 1s/epoch - 52ms/step
# Epoch 10/200
# 27/27 - 1s - loss: 0.0634 - 1s/epoch - 51ms/step
# Epoch 11/200
# 27/27 - 1s - loss: 0.0352 - 1s/epoch - 51ms/step
# Epoch 12/200
# 27/27 - 1s - loss: 0.0194 - 1s/epoch - 51ms/step
# Epoch 13/200
# 27/27 - 1s - loss: 0.0115 - 1s/epoch - 50ms/step
# Epoch 14/200
# 27/27 - 1s - loss: 0.0090 - 1s/epoch - 51ms/step
# Epoch 15/200
# 27/27 - 1s - loss: 0.0070 - 1s/epoch - 50ms/step
# Epoch 16/200
# 27/27 - 1s - loss: 0.0075 - 1s/epoch - 50ms/step
# Epoch 17/200
# 27/27 - 1s - loss: 0.0055 - 1s/epoch - 51ms/step
# Epoch 18/200
# 27/27 - 1s - loss: 0.0046 - 1s/epoch - 51ms/step
# Epoch 19/200
# 27/27 - 1s - loss: 0.0066 - 1s/epoch - 51ms/step
# Epoch 20/200
# 27/27 - 1s - loss: 0.0046 - 1s/epoch - 51ms/step
# Epoch 21/200
# 27/27 - 1s - loss: 0.0036 - 1s/epoch - 51ms/step
# Epoch 22/200
# 27/27 - 1s - loss: 0.0032 - 1s/epoch - 51ms/step
# Epoch 23/200
# 27/27 - 1s - loss: 0.0028 - 1s/epoch - 51ms/step
# Epoch 24/200
# 27/27 - 1s - loss: 0.0063 - 1s/epoch - 51ms/step
# Epoch 25/200
# 27/27 - 1s - loss: 0.0036 - 1s/epoch - 51ms/step
# Epoch 26/200
# 27/27 - 1s - loss: 0.0027 - 1s/epoch - 51ms/step
# Epoch 27/200
# 27/27 - 1s - loss: 0.0083 - 1s/epoch - 51ms/step
# Epoch 28/200
# 27/27 - 1s - loss: 0.0038 - 1s/epoch - 51ms/step
# Epoch 29/200
# 27/27 - 1s - loss: 0.0025 - 1s/epoch - 51ms/step
# Epoch 30/200
# 27/27 - 1s - loss: 0.0022 - 1s/epoch - 51ms/step
# Epoch 31/200
# 27/27 - 1s - loss: 0.0020 - 1s/epoch - 51ms/step
# Epoch 32/200
# 27/27 - 1s - loss: 0.0019 - 1s/epoch - 51ms/step
# Epoch 33/200
# 27/27 - 1s - loss: 0.0017 - 1s/epoch - 51ms/step
# Epoch 34/200
# 27/27 - 1s - loss: 0.0016 - 1s/epoch - 51ms/step
# Epoch 35/200
# 27/27 - 1s - loss: 0.0015 - 1s/epoch - 51ms/step
# Epoch 36/200
# 27/27 - 1s - loss: 0.0014 - 1s/epoch - 50ms/step
# Epoch 37/200
# 27/27 - 1s - loss: 0.0014 - 1s/epoch - 53ms/step
# Epoch 38/200
# 27/27 - 2s - loss: 0.0013 - 2s/epoch - 56ms/step
# Epoch 39/200
# 27/27 - 1s - loss: 0.0013 - 1s/epoch - 50ms/step
# Epoch 40/200
# 27/27 - 1s - loss: 0.0012 - 1s/epoch - 50ms/step
# Epoch 41/200
# 27/27 - 1s - loss: 0.0067 - 1s/epoch - 53ms/step
# Epoch 42/200
# 27/27 - 1s - loss: 0.0024 - 1s/epoch - 54ms/step
# Epoch 43/200
# 27/27 - 2s - loss: 0.0014 - 2s/epoch - 58ms/step
# Epoch 44/200
# 27/27 - 1s - loss: 0.0012 - 1s/epoch - 53ms/step
# Epoch 45/200
# 27/27 - 1s - loss: 0.0011 - 1s/epoch - 53ms/step
# Epoch 46/200
# 27/27 - 1s - loss: 0.0010 - 1s/epoch - 54ms/step
# Epoch 47/200
# 27/27 - 1s - loss: 9.7422e-04 - 1s/epoch - 54ms/step
# Epoch 48/200
# 27/27 - 1s - loss: 9.2554e-04 - 1s/epoch - 53ms/step
# Epoch 49/200
# 27/27 - 1s - loss: 8.8048e-04 - 1s/epoch - 53ms/step
# Epoch 50/200
# 27/27 - 1s - loss: 8.4311e-04 - 1s/epoch - 53ms/step
# Epoch 51/200
# 27/27 - 1s - loss: 8.4765e-04 - 1s/epoch - 53ms/step
# Epoch 52/200
# 27/27 - 1s - loss: 7.7050e-04 - 1s/epoch - 53ms/step
# Epoch 53/200
# 27/27 - 1s - loss: 7.3851e-04 - 1s/epoch - 53ms/step
# Epoch 54/200
# 27/27 - 1s - loss: 7.1409e-04 - 1s/epoch - 53ms/step
# Epoch 55/200
# 27/27 - 1s - loss: 8.0065e-04 - 1s/epoch - 53ms/step
# Epoch 56/200
# 27/27 - 1s - loss: 6.7693e-04 - 1s/epoch - 53ms/step
# Epoch 57/200
# 27/27 - 1s - loss: 0.0035 - 1s/epoch - 53ms/step
# Epoch 58/200
# 27/27 - 1s - loss: 0.0019 - 1s/epoch - 53ms/step
# Epoch 59/200
# 27/27 - 1s - loss: 8.7983e-04 - 1s/epoch - 53ms/step
# Epoch 60/200
# 27/27 - 1s - loss: 6.6339e-04 - 1s/epoch - 53ms/step
# Epoch 61/200
# 27/27 - 1s - loss: 6.1880e-04 - 1s/epoch - 53ms/step
# Epoch 62/200
# 27/27 - 1s - loss: 5.8764e-04 - 1s/epoch - 52ms/step
# Epoch 63/200
# 27/27 - 1s - loss: 5.6243e-04 - 1s/epoch - 53ms/step
# Epoch 64/200
# 27/27 - 1s - loss: 7.1995e-04 - 1s/epoch - 53ms/step
# Epoch 65/200
# 27/27 - 1s - loss: 5.5513e-04 - 1s/epoch - 54ms/step
# Epoch 66/200
# 27/27 - 1s - loss: 5.0620e-04 - 1s/epoch - 53ms/step
# Epoch 67/200
# 27/27 - 1s - loss: 4.8523e-04 - 1s/epoch - 54ms/step
# Epoch 68/200
# 27/27 - 1s - loss: 4.6759e-04 - 1s/epoch - 53ms/step
# Epoch 69/200
# 27/27 - 1s - loss: 4.4892e-04 - 1s/epoch - 53ms/step
# Epoch 70/200
# 27/27 - 1s - loss: 8.8916e-04 - 1s/epoch - 53ms/step
# Epoch 71/200
# 27/27 - 1s - loss: 8.1284e-04 - 1s/epoch - 53ms/step
# Epoch 72/200
# 27/27 - 1s - loss: 4.8135e-04 - 1s/epoch - 53ms/step
# Epoch 73/200
# 27/27 - 2s - loss: 4.1538e-04 - 2s/epoch - 56ms/step
# Epoch 74/200
# 27/27 - 2s - loss: 3.9243e-04 - 2s/epoch - 57ms/step
# Epoch 75/200
# 27/27 - 2s - loss: 3.7690e-04 - 2s/epoch - 57ms/step
# Epoch 76/200
# 27/27 - 2s - loss: 3.6324e-04 - 2s/epoch - 58ms/step
# Epoch 77/200
# 27/27 - 2s - loss: 3.5037e-04 - 2s/epoch - 57ms/step
# Epoch 78/200
# 27/27 - 2s - loss: 0.0021 - 2s/epoch - 56ms/step
# Epoch 79/200
# 27/27 - 2s - loss: 0.0051 - 2s/epoch - 57ms/step
# Epoch 80/200
# 27/27 - 2s - loss: 8.5390e-04 - 2s/epoch - 57ms/step
# Epoch 81/200
# 27/27 - 2s - loss: 5.0965e-04 - 2s/epoch - 57ms/step
# Epoch 82/200
# 27/27 - 2s - loss: 4.2443e-04 - 2s/epoch - 57ms/step
# Epoch 83/200
# 27/27 - 1s - loss: 3.8521e-04 - 1s/epoch - 54ms/step
# Epoch 84/200
# 27/27 - 1s - loss: 3.5951e-04 - 1s/epoch - 54ms/step
# Epoch 85/200
# 27/27 - 1s - loss: 3.3973e-04 - 1s/epoch - 54ms/step
# Epoch 86/200
# 27/27 - 1s - loss: 3.2290e-04 - 1s/epoch - 54ms/step
# Epoch 87/200
# 27/27 - 1s - loss: 3.0791e-04 - 1s/epoch - 53ms/step
# Epoch 88/200
# 27/27 - 1s - loss: 2.9428e-04 - 1s/epoch - 53ms/step
# Epoch 89/200
# 27/27 - 1s - loss: 2.8175e-04 - 1s/epoch - 54ms/step
# Epoch 90/200
# 27/27 - 1s - loss: 2.7020e-04 - 1s/epoch - 54ms/step
# Epoch 91/200
# 27/27 - 1s - loss: 2.5922e-04 - 1s/epoch - 53ms/step
# Epoch 92/200
# 27/27 - 1s - loss: 2.4899e-04 - 1s/epoch - 54ms/step
# Epoch 93/200
# 27/27 - 2s - loss: 2.3932e-04 - 2s/epoch - 56ms/step
# Epoch 94/200
# 27/27 - 1s - loss: 2.3040e-04 - 1s/epoch - 53ms/step
# Epoch 95/200
# 27/27 - 1s - loss: 2.6172e-04 - 1s/epoch - 53ms/step
# Epoch 96/200
# 27/27 - 1s - loss: 4.0487e-04 - 1s/epoch - 53ms/step
# Epoch 97/200
# 27/27 - 1s - loss: 2.3661e-04 - 1s/epoch - 53ms/step
# Epoch 98/200
# 27/27 - 1s - loss: 2.1002e-04 - 1s/epoch - 53ms/step
# Epoch 99/200
# 27/27 - 1s - loss: 1.9820e-04 - 1s/epoch - 53ms/step
# Epoch 100/200
# 27/27 - 1s - loss: 1.9058e-04 - 1s/epoch - 53ms/step
# Epoch 101/200
# 27/27 - 1s - loss: 1.8269e-04 - 1s/epoch - 53ms/step
# Epoch 102/200
# 27/27 - 1s - loss: 1.7637e-04 - 1s/epoch - 54ms/step
# Epoch 103/200
# 27/27 - 2s - loss: 0.0059 - 2s/epoch - 60ms/step
# Epoch 104/200
# 27/27 - 2s - loss: 0.0038 - 2s/epoch - 58ms/step
# Epoch 105/200
# 27/27 - 2s - loss: 7.7253e-04 - 2s/epoch - 56ms/step
# Epoch 106/200
# 27/27 - 2s - loss: 3.7774e-04 - 2s/epoch - 57ms/step
# Epoch 107/200
# 27/27 - 2s - loss: 2.9212e-04 - 2s/epoch - 60ms/step
# Epoch 108/200
# 27/27 - 1s - loss: 2.4957e-04 - 1s/epoch - 54ms/step
# Epoch 109/200
# 27/27 - 1s - loss: 2.2201e-04 - 1s/epoch - 53ms/step
# Epoch 110/200
# 27/27 - 1s - loss: 2.0256e-04 - 1s/epoch - 53ms/step
# Epoch 111/200
# 27/27 - 1s - loss: 1.8793e-04 - 1s/epoch - 53ms/step
# Epoch 112/200
# 27/27 - 1s - loss: 1.7633e-04 - 1s/epoch - 53ms/step
# Epoch 113/200
# 27/27 - 1s - loss: 1.6671e-04 - 1s/epoch - 54ms/step
# Epoch 114/200
# 27/27 - 1s - loss: 1.5856e-04 - 1s/epoch - 53ms/step
# Epoch 115/200
# 27/27 - 1s - loss: 1.5151e-04 - 1s/epoch - 53ms/step
# Epoch 116/200
# 27/27 - 1s - loss: 1.4529e-04 - 1s/epoch - 53ms/step
# Epoch 117/200
# 27/27 - 1s - loss: 1.3975e-04 - 1s/epoch - 53ms/step
# Epoch 118/200
# 27/27 - 1s - loss: 1.3481e-04 - 1s/epoch - 53ms/step
# Epoch 119/200
# 27/27 - 1s - loss: 1.3027e-04 - 1s/epoch - 54ms/step
# Epoch 120/200
# 27/27 - 1s - loss: 1.2612e-04 - 1s/epoch - 53ms/step
# Epoch 121/200
# 27/27 - 1s - loss: 1.2226e-04 - 1s/epoch - 53ms/step
# Epoch 122/200
# 27/27 - 1s - loss: 1.1867e-04 - 1s/epoch - 53ms/step
# Epoch 123/200
# 27/27 - 1s - loss: 1.1529e-04 - 1s/epoch - 53ms/step
# Epoch 124/200
# 27/27 - 1s - loss: 1.1215e-04 - 1s/epoch - 53ms/step
# Epoch 125/200
# 27/27 - 1s - loss: 1.0922e-04 - 1s/epoch - 54ms/step
# Epoch 126/200
# 27/27 - 1s - loss: 1.0643e-04 - 1s/epoch - 54ms/step
# Epoch 127/200
# 27/27 - 1s - loss: 1.0485e-04 - 1s/epoch - 54ms/step
# Epoch 128/200
# 27/27 - 1s - loss: 1.0511e-04 - 1s/epoch - 54ms/step
# Epoch 129/200
# 27/27 - 1s - loss: 9.9097e-05 - 1s/epoch - 54ms/step
# Epoch 130/200
# 27/27 - 1s - loss: 9.7525e-05 - 1s/epoch - 55ms/step
# Epoch 131/200
# 27/27 - 1s - loss: 2.7605e-04 - 1s/epoch - 54ms/step
# Epoch 132/200
# 27/27 - 1s - loss: 1.7445e-04 - 1s/epoch - 54ms/step
# Epoch 133/200
# 27/27 - 1s - loss: 1.0068e-04 - 1s/epoch - 54ms/step
# Epoch 134/200
# 27/27 - 1s - loss: 9.0412e-05 - 1s/epoch - 53ms/step
# Epoch 135/200
# 27/27 - 1s - loss: 8.7690e-05 - 1s/epoch - 53ms/step
# Epoch 136/200
# 27/27 - 1s - loss: 8.5425e-05 - 1s/epoch - 54ms/step
# Epoch 137/200
# 27/27 - 1s - loss: 8.3487e-05 - 1s/epoch - 54ms/step
# Epoch 138/200
# 27/27 - 1s - loss: 0.0021 - 1s/epoch - 54ms/step
# Epoch 139/200
# 27/27 - 1s - loss: 0.0029 - 1s/epoch - 53ms/step
# Epoch 140/200
# 27/27 - 1s - loss: 2.7667e-04 - 1s/epoch - 54ms/step
# Epoch 141/200
# 27/27 - 1s - loss: 1.4066e-04 - 1s/epoch - 53ms/step
# Epoch 142/200
# 27/27 - 1s - loss: 1.1603e-04 - 1s/epoch - 53ms/step
# Epoch 143/200
# 27/27 - 1s - loss: 1.0519e-04 - 1s/epoch - 54ms/step
# Epoch 144/200
# 27/27 - 1s - loss: 9.8285e-05 - 1s/epoch - 53ms/step
# Epoch 145/200
# 27/27 - 1s - loss: 9.3058e-05 - 1s/epoch - 53ms/step
# Epoch 146/200
# 27/27 - 1s - loss: 8.9004e-05 - 1s/epoch - 54ms/step
# Epoch 147/200
# 27/27 - 1s - loss: 8.5712e-05 - 1s/epoch - 53ms/step
# Epoch 148/200
# 27/27 - 1s - loss: 8.2909e-05 - 1s/epoch - 53ms/step
# Epoch 149/200
# 27/27 - 1s - loss: 8.0440e-05 - 1s/epoch - 54ms/step
# Epoch 150/200
# 27/27 - 1s - loss: 7.8208e-05 - 1s/epoch - 54ms/step
# Epoch 151/200
# 27/27 - 1s - loss: 7.6129e-05 - 1s/epoch - 53ms/step
# Epoch 152/200
# 27/27 - 1s - loss: 7.4150e-05 - 1s/epoch - 53ms/step
# Epoch 153/200
# 27/27 - 1s - loss: 7.2326e-05 - 1s/epoch - 53ms/step
# Epoch 154/200
# 27/27 - 1s - loss: 7.0640e-05 - 1s/epoch - 53ms/step
# Epoch 155/200
# 27/27 - 1s - loss: 6.9063e-05 - 1s/epoch - 54ms/step
# Epoch 156/200
# 27/27 - 1s - loss: 6.7569e-05 - 1s/epoch - 53ms/step
# Epoch 157/200
# 27/27 - 1s - loss: 6.6130e-05 - 1s/epoch - 53ms/step
# Epoch 158/200
# 27/27 - 1s - loss: 6.4741e-05 - 1s/epoch - 54ms/step
# Epoch 159/200
# 27/27 - 1s - loss: 6.3395e-05 - 1s/epoch - 53ms/step
# Epoch 160/200
# 27/27 - 1s - loss: 6.2079e-05 - 1s/epoch - 53ms/step
# Epoch 161/200
# 27/27 - 1s - loss: 6.0784e-05 - 1s/epoch - 54ms/step
# Epoch 162/200
# 27/27 - 1s - loss: 5.9466e-05 - 1s/epoch - 54ms/step
# Epoch 163/200
# 27/27 - 1s - loss: 5.8231e-05 - 1s/epoch - 55ms/step
# Epoch 164/200
# 27/27 - 1s - loss: 5.7041e-05 - 1s/epoch - 53ms/step
# Epoch 165/200
# 27/27 - 1s - loss: 5.5888e-05 - 1s/epoch - 53ms/step
# Epoch 166/200
# 27/27 - 1s - loss: 5.4781e-05 - 1s/epoch - 54ms/step
# Epoch 167/200
# 27/27 - 1s - loss: 5.3864e-05 - 1s/epoch - 53ms/step
# Epoch 168/200
# 27/27 - 1s - loss: 1.1472e-04 - 1s/epoch - 53ms/step
# Epoch 169/200
# 27/27 - 1s - loss: 6.0671e-05 - 1s/epoch - 53ms/step
# Epoch 170/200
# 27/27 - 1s - loss: 5.3492e-05 - 1s/epoch - 53ms/step
# Epoch 171/200
# 27/27 - 1s - loss: 5.2434e-05 - 1s/epoch - 54ms/step
# Epoch 172/200
# 27/27 - 1s - loss: 0.0039 - 1s/epoch - 54ms/step
# Epoch 173/200
# 27/27 - 1s - loss: 0.0027 - 1s/epoch - 54ms/step
# Epoch 174/200
# 27/27 - 1s - loss: 2.7011e-04 - 1s/epoch - 53ms/step
# Epoch 175/200
# 27/27 - 1s - loss: 1.1879e-04 - 1s/epoch - 54ms/step
# Epoch 176/200
# 27/27 - 2s - loss: 9.2050e-05 - 2s/epoch - 56ms/step
# Epoch 177/200
# 27/27 - 1s - loss: 8.0390e-05 - 1s/epoch - 53ms/step
# Epoch 178/200
# 27/27 - 1s - loss: 7.3390e-05 - 1s/epoch - 54ms/step
# Epoch 179/200
# 27/27 - 1s - loss: 6.8352e-05 - 1s/epoch - 53ms/step
# Epoch 180/200
# 27/27 - 1s - loss: 6.4455e-05 - 1s/epoch - 53ms/step
# Epoch 181/200
# 27/27 - 1s - loss: 6.1397e-05 - 1s/epoch - 53ms/step
# Epoch 182/200
# 27/27 - 1s - loss: 5.8838e-05 - 1s/epoch - 53ms/step
# Epoch 183/200
# 27/27 - 1s - loss: 5.6668e-05 - 1s/epoch - 53ms/step
# Epoch 184/200
# 27/27 - 1s - loss: 5.4812e-05 - 1s/epoch - 55ms/step
# Epoch 185/200
# 27/27 - 1s - loss: 5.3193e-05 - 1s/epoch - 53ms/step
# Epoch 186/200
# 27/27 - 1s - loss: 5.1716e-05 - 1s/epoch - 53ms/step
# Epoch 187/200
# 27/27 - 1s - loss: 5.0337e-05 - 1s/epoch - 53ms/step
# Epoch 188/200
# 27/27 - 1s - loss: 4.9091e-05 - 1s/epoch - 53ms/step
# Epoch 189/200
# 27/27 - 1s - loss: 4.7923e-05 - 1s/epoch - 54ms/step
# Epoch 190/200
# 27/27 - 1s - loss: 4.6816e-05 - 1s/epoch - 54ms/step
# Epoch 191/200
# 27/27 - 1s - loss: 4.5797e-05 - 1s/epoch - 53ms/step
# Epoch 192/200
# 27/27 - 1s - loss: 4.4844e-05 - 1s/epoch - 53ms/step
# Epoch 193/200
# 27/27 - 1s - loss: 4.3943e-05 - 1s/epoch - 53ms/step
# Epoch 194/200
# 27/27 - 1s - loss: 4.3091e-05 - 1s/epoch - 53ms/step
# Epoch 195/200
# 27/27 - 1s - loss: 4.2271e-05 - 1s/epoch - 53ms/step
# Epoch 196/200
# 27/27 - 1s - loss: 4.1492e-05 - 1s/epoch - 54ms/step
# Epoch 197/200
# 27/27 - 1s - loss: 4.0745e-05 - 1s/epoch - 54ms/step
# Epoch 198/200
# 27/27 - 1s - loss: 4.0018e-05 - 1s/epoch - 53ms/step
# Epoch 199/200
# 27/27 - 1s - loss: 3.9319e-05 - 1s/epoch - 53ms/step
# Epoch 200/200
# 27/27 - 1s - loss: 3.8652e-05 - 1s/epoch - 53ms/step
# Initial shape of x_input (50, 4)
# The shape of yhat after prediction is (1, 100, 4)
# The new shape of yhat  is (100, 4)
# [[-9.0068060e-01  4.2843878e-01 -7.1621490e-01  1.3374106e+00]
#  [-8.4397537e-01  5.6806135e-01 -9.1894871e-01  1.2494628e+00]
#  [-7.1999204e-01  7.0220232e-01 -9.9015683e-01  1.0489869e+00]
#  [ 5.4869139e-01  8.3395505e-01  9.3498015e-01 -7.4357224e-01]
#  [ 7.0648432e-01  7.1122897e-01  1.0036643e+00 -9.7573227e-01]
#  [ 8.3287930e-01  5.6187987e-01  9.2734385e-01 -1.1708914e+00]
#  [ 9.2523038e-01  3.8704705e-01  7.1452999e-01 -1.3184216e+00]
#  [ 9.8122954e-01  1.9485009e-01  3.8087678e-01 -1.4132516e+00]
#  [ 9.9713206e-01 -5.6818128e-03 -1.4213860e-02 -1.4434609e+00]
#  [ 9.7080195e-01 -2.0269638e-01 -3.9755166e-01 -1.4202396e+00]
#  [ 9.1017902e-01 -3.8843095e-01 -7.1928579e-01 -1.3460884e+00]
#  [ 8.2073748e-01 -5.5317235e-01 -9.2845726e-01 -1.2312027e+00]
#  [ 7.0573342e-01 -6.9098222e-01 -1.0007427e+00 -1.0780607e+00]
#  [ 5.6190252e-01 -8.1871217e-01 -9.2038286e-01 -8.6173964e-01]
#  [ 3.9145279e-01 -9.1921860e-01 -7.0015013e-01 -6.0860413e-01]
#  [ 2.0536196e-01 -9.8162597e-01 -3.7355423e-01 -3.3524278e-01]
#  [ 7.2628260e-03 -9.9963725e-01  9.6261501e-03 -4.6492837e-02]
#  [-1.9411081e-01 -9.7244215e-01  3.9394069e-01  2.4891514e-01]
#  [-3.8497061e-01 -9.1133153e-01  7.1164346e-01  5.2046859e-01]
#  [-5.6110412e-01 -8.1824833e-01  9.3182516e-01  7.5883687e-01]
#  [-7.1714109e-01 -7.0161891e-01  1.0015035e+00  9.7213322e-01]
#  [-8.4081143e-01 -5.5707681e-01  9.1747594e-01  1.1582235e+00]
#  [-9.2367965e-01 -3.8634980e-01  6.9798541e-01  1.3108442e+00]
#  [-9.7491115e-01 -1.9968104e-01  3.8982987e-01  1.4063333e+00]
#  [-9.9410272e-01 -7.2168112e-03  2.0945191e-02  1.4394385e+00]
#  [-9.7574502e-01  1.9404638e-01 -3.7150562e-01  1.4311429e+00]
#  [-9.2795706e-01  3.9301300e-01 -7.1782261e-01  1.3576269e+00]
#  [-8.4419137e-01  5.6615376e-01 -9.3026429e-01  1.2432698e+00]
#  [-7.1589452e-01  7.1192861e-01 -9.9971324e-01  1.0753874e+00]
#  [-5.5635774e-01  8.2673597e-01 -9.1913885e-01  8.5935551e-01]]
# -------Learning Curve--------
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 50)                11000
#
#  repeat_vector_3 (RepeatVect  (None, 100, 50)          0
#  or)
#
#  lstm_7 (LSTM)               (None, 100, 50)           20200
#
#  time_distributed_3 (TimeDis  (None, 100, 4)           204
#  tributed)
#
# =================================================================
# Total params: 31,404
# Trainable params: 31,404
# Non-trainable params: 0
# _________________________________________________________________
# Model saved!

# %%
# attr = len(inv_yhat.T)
attr = ["sine", "cosine", "sin(2t)", "2sin(t+1)-3cos(t-1)"]
# attr = ["wt3_valve", "Tank1InFlow", "Tank1WaterLevel", "Tank3OutFlow", "Tank2.level"]
for i in range(len(attr)):
    title = "Prediction of "+str(attr[i])
#     actual = raw_data[9901:10000,i]
    actual = raw_data[901:1000,i]
    pred = inv_yhat.T
    pred_df = pd.DataFrame(inv_yhat)
    # specify the range based on the length of predicted output
    index = pd.Index(list(range(100,200)))
    pred_df = pred_df.set_index(index)
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylabel("values")
#     plt.plot(pred[i], label="predicted")
#     plt.plot(actual, label="actual")
    plt.plot(pred_df[i])
    plt.plot(actual)
    plt.show()

# %% [markdown]
# ## Load the pre-trained surrogate model

# %%
from keras.models import load_model

s_model = load_model('Value-Flip.h5')

new_data = scaled_data[12000:14000,:]

# choose a number of time steps
n_steps_in, n_steps_out = 50, 100

# convert into input/output
test_X, test_y = split_sequences(new_data, n_steps_in, n_steps_out)
# the dataset knows the number of features, e.g. 2
n_features = X.shape[2]

score = s_model.evaluate(test_X, test_y, verbose=0)
# test_yhat = s_model.predict(test_X, verbose=0)
print("%s:  %.2f%%" % (s_model.metrics_names[0], score*100))


print("Prediction is successful!")
# Out:
# loss:  0.07%
# Prediction is successful!

# %% [markdown]
# ### Predict wit faulty data

# %%
s_model = load_model('Value-Flip.h5')

data = read_csv('waterTank_Value_Flip.csv', header=0, index_col=0)

# horizontally stack columns
raw_data = data.values
print(f'The shape of the raw_data before scaling is {raw_data.shape}')
#normalize input features
scaler = MinMaxScaler(feature_range=(0, 1))
f_scaled_data = scaler.fit_transform(raw_data)

# n_train = 10000
# dataset = f_scaled_data[0:n_train,:]


new_data = f_scaled_data[0:2000,:]

# choose a number of time steps
n_steps_in, n_steps_out = 50, 100

# convert into input/output
test_X, test_y = split_sequences(new_data, n_steps_in, n_steps_out)
# the dataset knows the number of features, e.g. 2
n_features = X.shape[2]

score = s_model.evaluate(test_X, test_y, verbose=0)
test_yhat = s_model.predict(test_X, verbose=0)
print("%s:  %.2f%%" % (s_model.metrics_names[0], score*100))

resh_test_yhat = yhat.reshape(n_steps_out, n_features)
print(f'The new shape of yhat  is {resh_test_yhat.shape}')
res_inv_yhat = scaler.inverse_transform(resh_test_yhat)
print(res_inv_yhat)


print(len(s_model.metrics_names))
print("Prediction is successful!")
# Out:
# The shape of the raw_data before scaling is (15001, 6)
# loss:  3.05%
# The new shape of yhat  is (100, 6)
# [[ 3.00061297e+00  2.98385572e+00  4.80544806e-01  1.29019761e+00
#    1.80935037e+00  6.47287905e-01]
#  [ 3.05723381e+00  2.98266745e+00  5.00694692e-01  1.99252796e+00
#    1.80637741e+00  9.56161797e-01]
#  [ 3.09067678e+00  2.99787879e+00  5.08644044e-01  2.28880405e+00
#    1.73258221e+00  1.09165633e+00]
#  [ 3.08514404e+00  3.03368068e+00  5.01566350e-01  2.21877909e+00
#    1.59531713e+00  1.08355701e+00]
#  [ 3.07328272e+00  3.04974484e+00  4.94731694e-01  2.13665104e+00
#    1.52321327e+00  1.00002837e+00]
#  [ 3.07602668e+00  3.05062842e+00  4.94974554e-01  2.10663080e+00
#    1.49341834e+00  9.57982600e-01]
#  [ 3.10299611e+00  3.06861591e+00  5.01170397e-01  2.10701847e+00
#    1.45067310e+00  9.97359216e-01]
#  [ 3.10985231e+00  3.06079674e+00  5.03706753e-01  2.02171183e+00
#    1.38344562e+00  1.00241756e+00]
#  [ 3.09160900e+00  3.04144883e+00  4.99846756e-01  3.80778536e-02
#    9.76865947e-01  3.77307087e-02]
#  [ 3.11226296e+00  3.05739832e+00  5.03420711e-01  1.07740210e-02
#    1.00211048e+00  1.55491084e-02]
#  [ 3.10590363e+00  3.04668427e+00  5.02280951e-01 -8.62595160e-03
#    1.02120364e+00  1.06294453e-03]
#  [ 3.10740232e+00  3.04452300e+00  5.02763152e-01 -2.60048378e-02
#    1.04290414e+00 -1.34382695e-02]
#  [ 3.10187507e+00  3.03556633e+00  5.02111018e-01 -3.62280421e-02
#    1.06289423e+00 -2.24043280e-02]
#  [ 3.09766293e+00  3.02809119e+00  5.01800835e-01 -4.12825868e-02
#    1.08433175e+00 -2.83488482e-02]
#  [ 3.09219241e+00  3.01945472e+00  5.01335561e-01 -4.05723788e-02
#    1.10603380e+00 -3.05979699e-02]
#  [ 3.08728456e+00  3.01148796e+00  5.01025736e-01 -3.51755358e-02
#    1.12864995e+00 -3.00509781e-02]
#  [ 3.08274317e+00  3.00429201e+00  5.00766695e-01 -2.70801727e-02
#    1.15210152e+00 -2.74232775e-02]
#  [ 3.07930565e+00  2.99876285e+00  5.00642598e-01 -1.85647458e-02
#    1.17651331e+00 -2.38763243e-02]
#  [ 3.07681274e+00  2.99467731e+00  5.00618219e-01 -1.03212520e-02
#    1.20146620e+00 -1.98604316e-02]
#  [ 3.07515383e+00  2.99189258e+00  5.00670910e-01 -2.69027986e-03
#    1.22672439e+00 -1.56191140e-02]
#  [ 3.07426119e+00  2.99031162e+00  5.00787199e-01  3.99539806e-03
#    1.25211000e+00 -1.13870353e-02]
#  [ 3.07401705e+00  2.98978257e+00  5.00945926e-01  9.48792882e-03
#    1.27744555e+00 -7.34977424e-03]
#  [ 3.07430220e+00  2.99014544e+00  5.01127303e-01  1.36252083e-02
#    1.30257761e+00 -3.65115702e-03]
#  [ 3.07498980e+00  2.99122810e+00  5.01312196e-01  1.63271837e-02
#    1.32737160e+00 -3.92809510e-04]
#  [ 3.07596087e+00  2.99286413e+00  5.01483738e-01  1.75857674e-02
#    1.35171759e+00  2.36098468e-03]
#  [ 3.07710886e+00  2.99489880e+00  5.01628876e-01  1.74516309e-02
#    1.37553334e+00  4.57914174e-03]
#  [ 3.07834625e+00  2.99719834e+00  5.01738369e-01  1.60190314e-02
#    1.39876449e+00  6.25656545e-03]]
# 1
# Prediction is successful!

# %%
attr = ["Tank1WaterLevel", "Tank2WaterLevel", "Tank2OutFlow", "Tank3OutFlow", "Tank2.level", "wt3_valve"]
for i in range(len(attr)):
    title = "Prediction of "+str(attr[i])
    actual = raw_data[1900:2000,i]
    pred = res_inv_yhat.T
    pred_df = pd.DataFrame(res_inv_yhat)
    # specify the range based on the length of predicted output
    index = pd.Index(list(range(100,200)))
    pred_df = pred_df.set_index(index)
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylabel("Values")
#     plt.plot(pred[i], label="predicted")
#     plt.plot(actual, label="actual")
    plt.plot(pred_df[i])
    plt.plot(actual)
    plt.show()
