# %% [markdown]
# ## Fault Injection (Value Flip)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
# ADF Test - null hypothesis - non-stationary - if p-value < 5% reject null hypothesis
# adfuller_result = adfuller(series, autolag="AIC")
# tankData = pd.read_csv("waterTankNew.csv", header=0, index_col=0)
tankData = pd.read_csv("trig.csv", header=0, index_col=0)
attr = ["sine", "cosine", "sin(2t)", "2sin(t+1)-3cos(t-1)"]
# adfuller_result = adfuller(tankData["wt3_valve"].values, autolag="AIC")

for feature in attr:
    
    adfuller_result = adfuller(tankData[feature].values, autolag="AIC")
    print("Stationarity metrics for each series")
    print(f'ADF Statistic: {adfuller_result[0]}')
    print(f'p-value: {adfuller_result[1]}')

    for key, value in adfuller_result[4].items():
        print('Critical Values: ')
        print(f'    {key}, {value}')

    print("Conclusion")
    if adfuller_result[1] > 0.05:
        print("Series is not stationary")
    else:
        print("Series is stationary")
    print("\n\n")
# Out:
# Stationarity metrics for each series
# ADF Statistic: -1011573335.1382487
# p-value: 0.0
# Critical Values:
#     1%, -3.4362125920049498
# Critical Values:
#     5%, -2.8641286575615426
# Critical Values:
#     10%, -2.5681482759591785
# Conclusion
# Series is stationary
#
#
#
# Stationarity metrics for each series
# ADF Statistic: -1011166234.5397538
# p-value: 0.0
# Critical Values:
#     1%, -3.4362125920049498
# Critical Values:
#     5%, -2.8641286575615426
# Critical Values:
#     10%, -2.5681482759591785
# Conclusion
# Series is stationary
#
#
#
# Stationarity metrics for each series
# ADF Statistic: -4839487399.352907
# p-value: 0.0
# Critical Values:
#     1%, -3.4362125920049498
# Critical Values:
#     5%, -2.8641286575615426
# Critical Values:
#     10%, -2.5681482759591785
# Conclusion
# Series is stationary
#
#
#
# Stationarity metrics for each series
# ADF Statistic: -1822503589.1901038
# p-value: 0.0
# Critical Values:
#     1%, -3.4362125920049498
# Critical Values:
#     5%, -2.8641286575615426
# Critical Values:
#     10%, -2.5681482759591785
# Conclusion
# Series is stationary

# %% [markdown]
# ### Visualise the data

# %%
from pandas import read_csv
# mydata = read_csv('waterTankNew.csv', header=0, index_col=0)
mydata = read_csv('trig.csv', header=0, index_col=0)
# attr = ["wt3_valve", "Tank1InFlow", "Tank1WaterLevel", "Tank3OutFlow", "Tank2.level"]
attr = ["sine", "cosine", "sin(2t)", "2sin(t+1)-3cos(t-1)"]
for i in range(len(attr)):
    title = "Plot of "+str(attr[i])
    actual = mydata.iloc[:2000,i]
#     actual = mydata.iloc[750:1000,i]
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylabel(attr[i])
#     plt.plot(actual, label="original")
    plt.plot(actual)
#     plt.legend()
    plt.show()

# %%
# multivariate output stacked lstm example
import pandas as pd
from numpy import array
from numpy import hstack, vstack
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Bidirectional, RepeatVector, TimeDistributed
from keras.layers.core import Dropout
from sklearn.preprocessing import MinMaxScaler
from pandas import read_csv
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np



# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# define input sequence

# Read the data
# data = read_csv('waterTank.csv', header=0, index_col=0)
# data = read_csv('outputs.csv', header=0, index_col=0)
# data = read_csv('trig.csv', header=0, index_col=0)
data = read_csv('trig.csv', header=0, index_col=0)

# horizontally stack columns
raw_data = data.values
print(f'The shape of the raw_data before scaling is {raw_data.shape}')
#normalize input features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(raw_data)

n_train = 1000
dataset = scaled_data[0:n_train,:]
# choose a number of time steps
# n_steps_in, n_steps_out = 50, 100
n_steps_in, n_steps_out = 50, 100

# convert into input/output
X, y = split_sequences(dataset, n_steps_in, n_steps_out)
# the dataset knows the number of features, e.g. 2
n_features = X.shape[2]
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps_in, n_features)))
model.add(RepeatVector(n_steps_out))
model.add(LSTM(50, activation='relu', return_sequences=True))
# model.add(TimeDistributed(Dense(50, activation='relu')))
model.add(TimeDistributed(Dense(n_features)))
# model.add(TimeDistributed(Dense(1)))
model.compile(optimizer='adam', loss='mse')
# fit model
train_history = model.fit(X, y, epochs=200, verbose=2, shuffle=False)

# demonstrate Direct prediction
# x_inp = raw_data[n_train:n_train+n_steps,:]
x_inp = scaled_data[n_train:n_train+n_steps_in,:]
print(f'Initial shape of x_input {x_inp.shape}')
x_input = x_inp.reshape((1, n_steps_in, n_features))
yhat = model.predict(x_input, verbose=0)
print(f'The shape of yhat after prediction is {yhat.shape}')
yhat = yhat.reshape(n_steps_out, n_features)
print(f'The new shape of yhat  is {yhat.shape}')
inv_yhat = scaler.inverse_transform(yhat)
# print(inv_yhat)

print("-------Learning Curve--------")
plt.plot(train_history.history['loss'], label='train')
# plt.plot(train_history.history['val_loss'], label='test')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

model.summary()

#save the model to disk
model.save('Trig.h5')
print("Model saved!")
# Out:
# The shape of the raw_data before scaling is (1120, 4)
# Epoch 1/200
# 27/27 - 4s - loss: 0.2071 - 4s/epoch - 149ms/step
# Epoch 2/200
# 27/27 - 2s - loss: 0.1319 - 2s/epoch - 59ms/step
# Epoch 3/200
# 27/27 - 2s - loss: 0.1288 - 2s/epoch - 60ms/step
# Epoch 4/200
# 27/27 - 2s - loss: 0.1265 - 2s/epoch - 60ms/step
# Epoch 5/200
# 27/27 - 2s - loss: 0.1227 - 2s/epoch - 59ms/step
# Epoch 6/200
# 27/27 - 2s - loss: 0.1011 - 2s/epoch - 59ms/step
# Epoch 7/200
# 27/27 - 2s - loss: 0.0536 - 2s/epoch - 56ms/step
# Epoch 8/200
# 27/27 - 2s - loss: 0.0280 - 2s/epoch - 59ms/step
# Epoch 9/200
# 27/27 - 2s - loss: 0.0135 - 2s/epoch - 63ms/step
# Epoch 10/200
# 27/27 - 2s - loss: 0.0083 - 2s/epoch - 66ms/step
# Epoch 11/200
# 27/27 - 2s - loss: 0.0104 - 2s/epoch - 67ms/step
# Epoch 12/200
# 27/27 - 2s - loss: 0.0086 - 2s/epoch - 67ms/step
# Epoch 13/200
# 27/27 - 2s - loss: 0.0051 - 2s/epoch - 66ms/step
# Epoch 14/200
# 27/27 - 2s - loss: 0.0040 - 2s/epoch - 66ms/step
# Epoch 15/200
# 27/27 - 2s - loss: 0.0036 - 2s/epoch - 84ms/step
# Epoch 16/200
# 27/27 - 2s - loss: 0.0030 - 2s/epoch - 68ms/step
# Epoch 17/200
# 27/27 - 2s - loss: 0.0028 - 2s/epoch - 67ms/step
# Epoch 18/200
# 27/27 - 2s - loss: 0.0024 - 2s/epoch - 67ms/step
# Epoch 19/200
# 27/27 - 2s - loss: 0.0023 - 2s/epoch - 66ms/step
# Epoch 20/200
# 27/27 - 2s - loss: 0.0020 - 2s/epoch - 67ms/step
# Epoch 21/200
# 27/27 - 2s - loss: 0.0018 - 2s/epoch - 67ms/step
# Epoch 22/200
# 27/27 - 2s - loss: 0.0018 - 2s/epoch - 66ms/step
# Epoch 23/200
# 27/27 - 2s - loss: 0.0026 - 2s/epoch - 67ms/step
# Epoch 24/200
# 27/27 - 2s - loss: 0.0085 - 2s/epoch - 65ms/step
# Epoch 25/200
# 27/27 - 2s - loss: 0.0023 - 2s/epoch - 67ms/step
# Epoch 26/200
# 27/27 - 2s - loss: 0.0015 - 2s/epoch - 68ms/step
# Epoch 27/200
# 27/27 - 2s - loss: 0.0012 - 2s/epoch - 67ms/step
# Epoch 28/200
# 27/27 - 2s - loss: 0.0011 - 2s/epoch - 67ms/step
# Epoch 29/200
# 27/27 - 2s - loss: 9.9694e-04 - 2s/epoch - 67ms/step
# Epoch 30/200
# 27/27 - 2s - loss: 9.1087e-04 - 2s/epoch - 67ms/step
# Epoch 31/200
# 27/27 - 2s - loss: 8.3654e-04 - 2s/epoch - 67ms/step
# Epoch 32/200
# 27/27 - 2s - loss: 7.7160e-04 - 2s/epoch - 65ms/step
# Epoch 33/200
# 27/27 - 2s - loss: 7.1332e-04 - 2s/epoch - 66ms/step
# Epoch 34/200
# 27/27 - 2s - loss: 6.5986e-04 - 2s/epoch - 67ms/step
# Epoch 35/200
# 27/27 - 2s - loss: 6.3461e-04 - 2s/epoch - 67ms/step
# Epoch 36/200
# 27/27 - 2s - loss: 6.3764e-04 - 2s/epoch - 66ms/step
# Epoch 37/200
# 27/27 - 2s - loss: 7.0714e-04 - 2s/epoch - 66ms/step
# Epoch 38/200
# 27/27 - 2s - loss: 0.0073 - 2s/epoch - 66ms/step
# Epoch 39/200
# 27/27 - 2s - loss: 0.0027 - 2s/epoch - 66ms/step
# Epoch 40/200
# 27/27 - 2s - loss: 0.0010 - 2s/epoch - 66ms/step
# Epoch 41/200
# 27/27 - 2s - loss: 6.9943e-04 - 2s/epoch - 66ms/step
# Epoch 42/200
# 27/27 - 2s - loss: 5.8179e-04 - 2s/epoch - 67ms/step
# Epoch 43/200
# 27/27 - 2s - loss: 5.1646e-04 - 2s/epoch - 66ms/step
# Epoch 44/200
# 27/27 - 2s - loss: 4.7298e-04 - 2s/epoch - 65ms/step
# Epoch 45/200
# 27/27 - 2s - loss: 4.3919e-04 - 2s/epoch - 66ms/step
# Epoch 46/200
# 27/27 - 2s - loss: 4.1119e-04 - 2s/epoch - 67ms/step
# Epoch 47/200
# 27/27 - 2s - loss: 3.8721e-04 - 2s/epoch - 67ms/step
# Epoch 48/200
# 27/27 - 2s - loss: 3.7188e-04 - 2s/epoch - 66ms/step
# Epoch 49/200
# 27/27 - 2s - loss: 3.8966e-04 - 2s/epoch - 63ms/step
# Epoch 50/200
# 27/27 - 2s - loss: 4.3574e-04 - 2s/epoch - 64ms/step
# Epoch 51/200
# 27/27 - 2s - loss: 4.7198e-04 - 2s/epoch - 62ms/step
# Epoch 52/200
# 27/27 - 2s - loss: 3.1040e-04 - 2s/epoch - 65ms/step
# Epoch 53/200
# 27/27 - 2s - loss: 2.9533e-04 - 2s/epoch - 67ms/step
# Epoch 54/200
# 27/27 - 2s - loss: 5.8394e-04 - 2s/epoch - 69ms/step
# Epoch 55/200
# 27/27 - 2s - loss: 0.0036 - 2s/epoch - 67ms/step
# Epoch 56/200
# 27/27 - 2s - loss: 0.0010 - 2s/epoch - 66ms/step
# Epoch 57/200
# 27/27 - 2s - loss: 3.8563e-04 - 2s/epoch - 67ms/step
# Epoch 58/200
# 27/27 - 2s - loss: 3.0458e-04 - 2s/epoch - 66ms/step
# Epoch 59/200
# 27/27 - 2s - loss: 2.7899e-04 - 2s/epoch - 68ms/step
# Epoch 60/200
# 27/27 - 2s - loss: 2.6326e-04 - 2s/epoch - 68ms/step
# Epoch 61/200
# 27/27 - 2s - loss: 2.5101e-04 - 2s/epoch - 69ms/step
# Epoch 62/200
# 27/27 - 2s - loss: 2.4037e-04 - 2s/epoch - 66ms/step
# Epoch 63/200
# 27/27 - 2s - loss: 2.3060e-04 - 2s/epoch - 64ms/step
# Epoch 64/200
# 27/27 - 2s - loss: 2.2227e-04 - 2s/epoch - 65ms/step
# Epoch 65/200
# 27/27 - 2s - loss: 2.2110e-04 - 2s/epoch - 66ms/step
# Epoch 66/200
# 27/27 - 2s - loss: 2.2632e-04 - 2s/epoch - 69ms/step
# Epoch 67/200
# 27/27 - 2s - loss: 2.0467e-04 - 2s/epoch - 67ms/step
# Epoch 68/200
# 27/27 - 2s - loss: 2.1988e-04 - 2s/epoch - 67ms/step
# Epoch 69/200
# 27/27 - 2s - loss: 0.0012 - 2s/epoch - 66ms/step
# Epoch 70/200
# 27/27 - 2s - loss: 8.9063e-04 - 2s/epoch - 66ms/step
# Epoch 71/200
# 27/27 - 2s - loss: 2.5711e-04 - 2s/epoch - 67ms/step
# Epoch 72/200
# 27/27 - 2s - loss: 1.9423e-04 - 2s/epoch - 66ms/step
# Epoch 73/200
# 27/27 - 2s - loss: 1.7991e-04 - 2s/epoch - 67ms/step
# Epoch 74/200
# 27/27 - 2s - loss: 1.7189e-04 - 2s/epoch - 68ms/step
# Epoch 75/200
# 27/27 - 2s - loss: 1.6552e-04 - 2s/epoch - 66ms/step
# Epoch 76/200
# 27/27 - 2s - loss: 1.5988e-04 - 2s/epoch - 66ms/step
# Epoch 77/200
# 27/27 - 2s - loss: 1.5478e-04 - 2s/epoch - 66ms/step
# Epoch 78/200
# 27/27 - 2s - loss: 1.5012e-04 - 2s/epoch - 66ms/step
# Epoch 79/200
# 27/27 - 2s - loss: 1.4569e-04 - 2s/epoch - 66ms/step
# Epoch 80/200
# 27/27 - 2s - loss: 1.5094e-04 - 2s/epoch - 67ms/step
# Epoch 81/200
# 27/27 - 2s - loss: 1.4842e-04 - 2s/epoch - 68ms/step
# Epoch 82/200
# 27/27 - 2s - loss: 1.7860e-04 - 2s/epoch - 64ms/step
# Epoch 83/200
# 27/27 - 2s - loss: 2.7049e-04 - 2s/epoch - 66ms/step
# Epoch 84/200
# 27/27 - 2s - loss: 1.3988e-04 - 2s/epoch - 66ms/step
# Epoch 85/200
# 27/27 - 2s - loss: 1.2676e-04 - 2s/epoch - 67ms/step
# Epoch 86/200
# 27/27 - 2s - loss: 1.2121e-04 - 2s/epoch - 67ms/step
# Epoch 87/200
# 27/27 - 2s - loss: 1.1808e-04 - 2s/epoch - 66ms/step
# Epoch 88/200
# 27/27 - 2s - loss: 0.0018 - 2s/epoch - 67ms/step
# Epoch 89/200
# 27/27 - 2s - loss: 0.0406 - 2s/epoch - 67ms/step
# Epoch 90/200
# 27/27 - 2s - loss: 0.0083 - 2s/epoch - 66ms/step
# Epoch 91/200
# 27/27 - 2s - loss: 0.0036 - 2s/epoch - 65ms/step
# Epoch 92/200
# 27/27 - 2s - loss: 0.0022 - 2s/epoch - 67ms/step
# Epoch 93/200
# 27/27 - 2s - loss: 0.0015 - 2s/epoch - 67ms/step
# Epoch 94/200
# 27/27 - 2s - loss: 0.0012 - 2s/epoch - 66ms/step
# Epoch 95/200
# 27/27 - 2s - loss: 8.8300e-04 - 2s/epoch - 67ms/step
# Epoch 96/200
# 27/27 - 2s - loss: 7.3649e-04 - 2s/epoch - 67ms/step
# Epoch 97/200
# 27/27 - 2s - loss: 6.1805e-04 - 2s/epoch - 66ms/step
# Epoch 98/200
# 27/27 - 2s - loss: 5.8399e-04 - 2s/epoch - 67ms/step
# Epoch 99/200
# 27/27 - 2s - loss: 4.3240e-04 - 2s/epoch - 65ms/step
# Epoch 100/200
# 27/27 - 2s - loss: 3.7384e-04 - 2s/epoch - 66ms/step
# Epoch 101/200
# 27/27 - 2s - loss: 3.3981e-04 - 2s/epoch - 65ms/step
# Epoch 102/200
# 27/27 - 2s - loss: 0.0012 - 2s/epoch - 65ms/step
# Epoch 103/200
# 27/27 - 2s - loss: 8.5097e-04 - 2s/epoch - 66ms/step
# Epoch 104/200
# 27/27 - 2s - loss: 3.3080e-04 - 2s/epoch - 66ms/step
# Epoch 105/200
# 27/27 - 2s - loss: 2.6539e-04 - 2s/epoch - 65ms/step
# Epoch 106/200
# 27/27 - 2s - loss: 2.3986e-04 - 2s/epoch - 65ms/step
# Epoch 107/200
# 27/27 - 2s - loss: 2.2247e-04 - 2s/epoch - 66ms/step
# Epoch 108/200
# 27/27 - 2s - loss: 2.0840e-04 - 2s/epoch - 66ms/step
# Epoch 109/200
# 27/27 - 2s - loss: 1.9591e-04 - 2s/epoch - 66ms/step
# Epoch 110/200
# 27/27 - 2s - loss: 1.8476e-04 - 2s/epoch - 65ms/step
# Epoch 111/200
# 27/27 - 2s - loss: 1.7503e-04 - 2s/epoch - 66ms/step
# Epoch 112/200
# 27/27 - 2s - loss: 1.6639e-04 - 2s/epoch - 65ms/step
# Epoch 113/200
# 27/27 - 2s - loss: 1.5865e-04 - 2s/epoch - 65ms/step
# Epoch 114/200
# 27/27 - 2s - loss: 1.5162e-04 - 2s/epoch - 63ms/step
# Epoch 115/200
# 27/27 - 2s - loss: 1.4505e-04 - 2s/epoch - 63ms/step
# Epoch 116/200
# 27/27 - 2s - loss: 1.3897e-04 - 2s/epoch - 65ms/step
# Epoch 117/200
# 27/27 - 2s - loss: 1.3333e-04 - 2s/epoch - 67ms/step
# Epoch 118/200
# 27/27 - 2s - loss: 1.2800e-04 - 2s/epoch - 64ms/step
# Epoch 119/200
# 27/27 - 2s - loss: 1.2305e-04 - 2s/epoch - 65ms/step
# Epoch 120/200
# 27/27 - 2s - loss: 1.1860e-04 - 2s/epoch - 65ms/step
# Epoch 121/200
# 27/27 - 2s - loss: 1.1962e-04 - 2s/epoch - 66ms/step
# Epoch 122/200
# 27/27 - 2s - loss: 1.2602e-04 - 2s/epoch - 65ms/step
# Epoch 123/200
# 27/27 - 2s - loss: 0.0013 - 2s/epoch - 65ms/step
# Epoch 124/200
# 27/27 - 2s - loss: 3.9308e-04 - 2s/epoch - 65ms/step
# Epoch 125/200
# 27/27 - 2s - loss: 1.3430e-04 - 2s/epoch - 66ms/step
# Epoch 126/200
# 27/27 - 2s - loss: 1.1027e-04 - 2s/epoch - 66ms/step
# Epoch 127/200
# 27/27 - 2s - loss: 1.0331e-04 - 2s/epoch - 65ms/step
# Epoch 128/200
# 27/27 - 2s - loss: 9.9028e-05 - 2s/epoch - 65ms/step
# Epoch 129/200
# 27/27 - 2s - loss: 9.5568e-05 - 2s/epoch - 67ms/step
# Epoch 130/200
# 27/27 - 2s - loss: 9.2548e-05 - 2s/epoch - 66ms/step
# Epoch 131/200
# 27/27 - 2s - loss: 8.9772e-05 - 2s/epoch - 65ms/step
# Epoch 132/200
# 27/27 - 2s - loss: 8.7128e-05 - 2s/epoch - 65ms/step
# Epoch 133/200
# 27/27 - 2s - loss: 8.4594e-05 - 2s/epoch - 66ms/step
# Epoch 134/200
# 27/27 - 2s - loss: 8.2196e-05 - 2s/epoch - 65ms/step
# Epoch 135/200
# 27/27 - 2s - loss: 7.9914e-05 - 2s/epoch - 65ms/step
# Epoch 136/200
# 27/27 - 2s - loss: 7.7723e-05 - 2s/epoch - 65ms/step
# Epoch 137/200
# 27/27 - 2s - loss: 7.5682e-05 - 2s/epoch - 69ms/step
# Epoch 138/200
# 27/27 - 2s - loss: 7.3742e-05 - 2s/epoch - 65ms/step
# Epoch 139/200
# 27/27 - 2s - loss: 7.1880e-05 - 2s/epoch - 67ms/step
# Epoch 140/200
# 27/27 - 2s - loss: 7.0086e-05 - 2s/epoch - 65ms/step
# Epoch 141/200
# 27/27 - 2s - loss: 6.9552e-05 - 2s/epoch - 65ms/step
# Epoch 142/200
# 27/27 - 2s - loss: 5.1347e-04 - 2s/epoch - 65ms/step
# Epoch 143/200
# 27/27 - 2s - loss: 0.0011 - 2s/epoch - 65ms/step
# Epoch 144/200
# 27/27 - 2s - loss: 1.5864e-04 - 2s/epoch - 66ms/step
# Epoch 145/200
# 27/27 - 2s - loss: 8.0263e-05 - 2s/epoch - 65ms/step
# Epoch 146/200
# 27/27 - 2s - loss: 7.0463e-05 - 2s/epoch - 65ms/step
# Epoch 147/200
# 27/27 - 2s - loss: 6.6497e-05 - 2s/epoch - 64ms/step
# Epoch 148/200
# 27/27 - 2s - loss: 6.3863e-05 - 2s/epoch - 65ms/step
# Epoch 149/200
# 27/27 - 2s - loss: 6.1760e-05 - 2s/epoch - 66ms/step
# Epoch 150/200
# 27/27 - 2s - loss: 5.9982e-05 - 2s/epoch - 65ms/step
# Epoch 151/200
# 27/27 - 2s - loss: 5.8411e-05 - 2s/epoch - 65ms/step
# Epoch 152/200
# 27/27 - 2s - loss: 5.6993e-05 - 2s/epoch - 65ms/step
# Epoch 153/200
# 27/27 - 2s - loss: 5.5688e-05 - 2s/epoch - 65ms/step
# Epoch 154/200
# 27/27 - 2s - loss: 5.4464e-05 - 2s/epoch - 65ms/step
# Epoch 155/200
# 27/27 - 2s - loss: 5.3286e-05 - 2s/epoch - 65ms/step
# Epoch 156/200
# 27/27 - 2s - loss: 5.2164e-05 - 2s/epoch - 66ms/step
# Epoch 157/200
# 27/27 - 2s - loss: 5.1101e-05 - 2s/epoch - 65ms/step
# Epoch 158/200
# 27/27 - 2s - loss: 5.0830e-05 - 2s/epoch - 65ms/step
# Epoch 159/200
# 27/27 - 2s - loss: 6.5565e-05 - 2s/epoch - 65ms/step
# Epoch 160/200
# 27/27 - 2s - loss: 6.5567e-05 - 2s/epoch - 65ms/step
# Epoch 161/200
# 27/27 - 2s - loss: 6.1228e-05 - 2s/epoch - 66ms/step
# Epoch 162/200
# 27/27 - 2s - loss: 0.0025 - 2s/epoch - 65ms/step
# Epoch 163/200
# 27/27 - 2s - loss: 0.0012 - 2s/epoch - 65ms/step
# Epoch 164/200
# 27/27 - 2s - loss: 2.9357e-04 - 2s/epoch - 66ms/step
# Epoch 165/200
# 27/27 - 2s - loss: 8.1057e-05 - 2s/epoch - 66ms/step
# Epoch 166/200
# 27/27 - 2s - loss: 5.7685e-05 - 2s/epoch - 66ms/step
# Epoch 167/200
# 27/27 - 2s - loss: 5.2094e-05 - 2s/epoch - 69ms/step
# Epoch 168/200
# 27/27 - 2s - loss: 4.9099e-05 - 2s/epoch - 70ms/step
# Epoch 169/200
# 27/27 - 2s - loss: 4.7102e-05 - 2s/epoch - 69ms/step
# Epoch 170/200
# 27/27 - 2s - loss: 4.5559e-05 - 2s/epoch - 66ms/step
# Epoch 171/200
# 27/27 - 2s - loss: 4.4267e-05 - 2s/epoch - 65ms/step
# Epoch 172/200
# 27/27 - 2s - loss: 4.3130e-05 - 2s/epoch - 65ms/step
# Epoch 173/200
# 27/27 - 2s - loss: 4.2096e-05 - 2s/epoch - 66ms/step
# Epoch 174/200
# 27/27 - 2s - loss: 4.1158e-05 - 2s/epoch - 65ms/step
# Epoch 175/200
# 27/27 - 2s - loss: 4.0289e-05 - 2s/epoch - 65ms/step
# Epoch 176/200
# 27/27 - 2s - loss: 3.9463e-05 - 2s/epoch - 64ms/step
# Epoch 177/200
# 27/27 - 2s - loss: 3.8691e-05 - 2s/epoch - 65ms/step
# Epoch 178/200
# 27/27 - 2s - loss: 3.7976e-05 - 2s/epoch - 65ms/step
# Epoch 179/200
# 27/27 - 2s - loss: 3.7296e-05 - 2s/epoch - 65ms/step
# Epoch 180/200
# 27/27 - 2s - loss: 3.6637e-05 - 2s/epoch - 65ms/step
# Epoch 181/200
# 27/27 - 2s - loss: 3.6019e-05 - 2s/epoch - 67ms/step
# Epoch 182/200
# 27/27 - 2s - loss: 3.5431e-05 - 2s/epoch - 66ms/step
# Epoch 183/200
# 27/27 - 2s - loss: 3.4872e-05 - 2s/epoch - 65ms/step
# Epoch 184/200
# 27/27 - 2s - loss: 3.4328e-05 - 2s/epoch - 65ms/step
# Epoch 185/200
# 27/27 - 2s - loss: 3.3793e-05 - 2s/epoch - 62ms/step
# Epoch 186/200
# 27/27 - 2s - loss: 3.3285e-05 - 2s/epoch - 63ms/step
# Epoch 187/200
# 27/27 - 2s - loss: 3.2795e-05 - 2s/epoch - 66ms/step
# Epoch 188/200
# 27/27 - 2s - loss: 3.2333e-05 - 2s/epoch - 65ms/step
# Epoch 189/200
# 27/27 - 2s - loss: 3.1856e-05 - 2s/epoch - 64ms/step
# Epoch 190/200
# 27/27 - 2s - loss: 3.1392e-05 - 2s/epoch - 65ms/step
# Epoch 191/200
# 27/27 - 2s - loss: 3.1048e-05 - 2s/epoch - 66ms/step
# Epoch 192/200
# 27/27 - 2s - loss: 3.1187e-05 - 2s/epoch - 65ms/step
# Epoch 193/200
# 27/27 - 2s - loss: 6.6577e-04 - 2s/epoch - 65ms/step
# Epoch 194/200
# 27/27 - 2s - loss: 0.0018 - 2s/epoch - 65ms/step
# Epoch 195/200
# 27/27 - 2s - loss: 3.0336e-04 - 2s/epoch - 67ms/step
# Epoch 196/200
# 27/27 - 2s - loss: 7.0638e-05 - 2s/epoch - 66ms/step
# Epoch 197/200
# 27/27 - 2s - loss: 4.0181e-05 - 2s/epoch - 66ms/step
# Epoch 198/200
# 27/27 - 2s - loss: 3.4089e-05 - 2s/epoch - 65ms/step
# Epoch 199/200
# 27/27 - 2s - loss: 3.2190e-05 - 2s/epoch - 65ms/step
# Epoch 200/200
# 27/27 - 2s - loss: 3.1003e-05 - 2s/epoch - 65ms/step
# Initial shape of x_input (50, 4)
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001CFC29CA680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  [ 5.55771947e-01  8.50598335e-01  9.33824539e-01 -7.51892149e-01]
#  [ 7.12120414e-01  7.24523306e-01  9.95364189e-01 -9.83988643e-01]
#  [ 8.39101195e-01  5.72414994e-01  9.08901095e-01 -1.17395759e+00]
#  [ 9.25562382e-01  3.97904158e-01  6.91282034e-01 -1.31600058e+00]
#  [ 9.70168233e-01  2.02706933e-01  3.75488043e-01 -1.40715253e+00]
#  [ 9.90475535e-01 -4.92334366e-05  1.16002560e-03 -1.44578660e+00]
#  [ 9.88692164e-01 -2.00488985e-01 -3.77288342e-01 -1.43444550e+00]
#  [ 9.35465217e-01 -3.90091419e-01 -6.94799423e-01 -1.36544693e+00]
#  [ 8.32674623e-01 -5.56156218e-01 -9.03482974e-01 -1.24216592e+00]
#  [ 7.01508760e-01 -7.00162232e-01 -9.75859404e-01 -1.07287955e+00]
#  [ 5.57630897e-01 -8.25891733e-01 -9.03802633e-01 -8.64658833e-01]
#  [ 3.87483120e-01 -9.23494101e-01 -6.94335639e-01 -6.17093682e-01]
#  [ 1.97823524e-01 -9.87169325e-01 -3.70904565e-01 -3.42264563e-01]
#  [-1.08897686e-04 -1.01222956e+00  2.13701725e-02 -5.57714030e-02]
#  [-1.93736136e-01 -9.94827569e-01  3.94930005e-01  2.28797778e-01]
#  [-3.78672183e-01 -9.36695099e-01  7.06574440e-01  5.03287375e-01]
#  [-5.54843307e-01 -8.32986772e-01  9.19501543e-01  7.62115657e-01]
#  [-7.06883788e-01 -6.96929097e-01  1.00255251e+00  9.80811656e-01]
#  [-8.27410758e-01 -5.41228592e-01  9.32892919e-01  1.15598786e+00]
#  [-9.16810632e-01 -3.75584006e-01  7.07546949e-01  1.29891574e+00]
#  [-9.73710835e-01 -1.99810326e-01  3.79208565e-01  1.39913559e+00]
#  [-9.95212972e-01 -1.03949904e-02  6.04391098e-05  1.45381105e+00]
#  [-9.81478631e-01  1.91513896e-01 -3.79864812e-01  1.44265687e+00]
#  [-9.22457039e-01  3.86571407e-01 -7.05456197e-01  1.36117554e+00]
#  [-8.23859572e-01  5.58151245e-01 -9.19397235e-01  1.22613716e+00]
#  [-7.05666602e-01  7.01468706e-01 -9.95983481e-01  1.05172193e+00]
#  [-5.56950450e-01  8.23456168e-01 -9.23282266e-01  8.42646360e-01]]
# -------Learning Curve--------
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 50)                11000
#
#  repeat_vector_4 (RepeatVect  (None, 100, 50)          0
#  or)
#
#  lstm_9 (LSTM)               (None, 100, 50)           20200
#
#  time_distributed_4 (TimeDis  (None, 100, 4)           204
#  tributed)
#
# =================================================================
# Total params: 31,404
# Trainable params: 31,404
# Non-trainable params: 0
# _________________________________________________________________
# Model saved!

# %%
# attr = len(inv_yhat.T)
attr = ["sine", "cosine", "sin(2t)", "2sin(t+1)-3cos(t-1)"]
# attr = ["wt3_valve", "Tank1InFlow", "Tank1WaterLevel", "Tank3OutFlow", "Tank2.level"]
for i in range(len(attr)):
    title = "Prediction of "+str(attr[i])
#     actual = raw_data[9901:10000,i]
    actual = raw_data[901:1000,i]
    pred = inv_yhat.T
    pred_df = pd.DataFrame(inv_yhat)
    # specify the range based on the length of predicted output
    index = pd.Index(list(range(100,200)))
    pred_df = pred_df.set_index(index)
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylabel("values")
#     plt.plot(pred[i], label="predicted")
#     plt.plot(actual, label="actual")
    plt.plot(pred_df[i])
    plt.plot(actual)
    plt.show()

# %% [markdown]
# ## Load the pre-trained surrogate model

# %%
from keras.models import load_model

s_model = load_model('Value-Flip.h5')

new_data = scaled_data[12000:14000,:]

# choose a number of time steps
n_steps_in, n_steps_out = 50, 100

# convert into input/output
test_X, test_y = split_sequences(new_data, n_steps_in, n_steps_out)
# the dataset knows the number of features, e.g. 2
n_features = X.shape[2]

score = s_model.evaluate(test_X, test_y, verbose=0)
# test_yhat = s_model.predict(test_X, verbose=0)
print("%s:  %.2f%%" % (s_model.metrics_names[0], score*100))


print("Prediction is successful!")
# Out:
# loss:  0.07%
# Prediction is successful!

# %% [markdown]
# ### Predict wit faulty data

# %%
s_model = load_model('Value-Flip.h5')

data = read_csv('waterTank_Value_Flip.csv', header=0, index_col=0)

# horizontally stack columns
raw_data = data.values
print(f'The shape of the raw_data before scaling is {raw_data.shape}')
#normalize input features
scaler = MinMaxScaler(feature_range=(0, 1))
f_scaled_data = scaler.fit_transform(raw_data)

# n_train = 10000
# dataset = f_scaled_data[0:n_train,:]


new_data = f_scaled_data[0:2000,:]

# choose a number of time steps
n_steps_in, n_steps_out = 50, 100

# convert into input/output
test_X, test_y = split_sequences(new_data, n_steps_in, n_steps_out)
# the dataset knows the number of features, e.g. 2
n_features = X.shape[2]

score = s_model.evaluate(test_X, test_y, verbose=0)
test_yhat = s_model.predict(test_X, verbose=0)
print("%s:  %.2f%%" % (s_model.metrics_names[0], score*100))

resh_test_yhat = yhat.reshape(n_steps_out, n_features)
print(f'The new shape of yhat  is {resh_test_yhat.shape}')
res_inv_yhat = scaler.inverse_transform(resh_test_yhat)
print(res_inv_yhat)


print(len(s_model.metrics_names))
print("Prediction is successful!")
# Out:
# The shape of the raw_data before scaling is (15001, 6)
# loss:  3.05%
# The new shape of yhat  is (100, 6)
# [[ 3.00061297e+00  2.98385572e+00  4.80544806e-01  1.29019761e+00
#    1.80935037e+00  6.47287905e-01]
#  [ 3.05723381e+00  2.98266745e+00  5.00694692e-01  1.99252796e+00
#    1.80637741e+00  9.56161797e-01]
#  [ 3.09067678e+00  2.99787879e+00  5.08644044e-01  2.28880405e+00
#    1.73258221e+00  1.09165633e+00]
#  [ 3.08514404e+00  3.03368068e+00  5.01566350e-01  2.21877909e+00
#    1.59531713e+00  1.08355701e+00]
#  [ 3.07328272e+00  3.04974484e+00  4.94731694e-01  2.13665104e+00
#    1.52321327e+00  1.00002837e+00]
#  [ 3.07602668e+00  3.05062842e+00  4.94974554e-01  2.10663080e+00
#    1.49341834e+00  9.57982600e-01]
#  [ 3.10299611e+00  3.06861591e+00  5.01170397e-01  2.10701847e+00
#    1.45067310e+00  9.97359216e-01]
#  [ 3.10985231e+00  3.06079674e+00  5.03706753e-01  2.02171183e+00
#    9.38323200e-01  3.52881402e-02]
#  [ 3.09160900e+00  3.04144883e+00  4.99846756e-01  3.80778536e-02
#    9.76865947e-01  3.77307087e-02]
#  [ 3.11226296e+00  3.05739832e+00  5.03420711e-01  1.07740210e-02
#    1.00211048e+00  1.55491084e-02]
#  [ 3.10590363e+00  3.04668427e+00  5.02280951e-01 -8.62595160e-03
#    1.02120364e+00  1.06294453e-03]
#  [ 3.10740232e+00  3.04452300e+00  5.02763152e-01 -2.60048378e-02
#    1.04290414e+00 -1.34382695e-02]
#  [ 3.10187507e+00  3.03556633e+00  5.02111018e-01 -3.62280421e-02
#    1.06289423e+00 -2.24043280e-02]
#  [ 3.09766293e+00  3.02809119e+00  5.01800835e-01 -4.12825868e-02
#    1.08433175e+00 -2.83488482e-02]
#  [ 3.09219241e+00  3.01945472e+00  5.01335561e-01 -4.05723788e-02
#    1.10603380e+00 -3.05979699e-02]
#  [ 3.08728456e+00  3.01148796e+00  5.01025736e-01 -3.51755358e-02
#    1.12864995e+00 -3.00509781e-02]
#  [ 3.08274317e+00  3.00429201e+00  5.00766695e-01 -2.70801727e-02
#    1.15210152e+00 -2.74232775e-02]
#  [ 3.07930565e+00  2.99876285e+00  5.00642598e-01 -1.85647458e-02
#    1.17651331e+00 -2.38763243e-02]
#  [ 3.07681274e+00  2.99467731e+00  5.00618219e-01 -1.03212520e-02
#    1.20146620e+00 -1.98604316e-02]
#  [ 3.07515383e+00  2.99189258e+00  5.00670910e-01 -2.69027986e-03
#    1.22672439e+00 -1.56191140e-02]
#  [ 3.07426119e+00  2.99031162e+00  5.00787199e-01  3.99539806e-03
#    1.25211000e+00 -1.13870353e-02]
#  [ 3.07401705e+00  2.98978257e+00  5.00945926e-01  9.48792882e-03
#    1.27744555e+00 -7.34977424e-03]
#  [ 3.07430220e+00  2.99014544e+00  5.01127303e-01  1.36252083e-02
#    1.30257761e+00 -3.65115702e-03]
#  [ 3.07498980e+00  2.99122810e+00  5.01312196e-01  1.63271837e-02
#    1.32737160e+00 -3.92809510e-04]
#  [ 3.07596087e+00  2.99286413e+00  5.01483738e-01  1.75857674e-02
#    1.35171759e+00  2.36098468e-03]
#  [ 3.07710886e+00  2.99489880e+00  5.01628876e-01  1.74516309e-02
#    1.37553334e+00  4.57914174e-03]
#  [ 3.07834625e+00  2.99719834e+00  5.01738369e-01  1.60190314e-02
#    1.39876449e+00  6.25656545e-03]]
# 1
# Prediction is successful!

# %%
attr = ["Tank1WaterLevel", "Tank2WaterLevel", "Tank2OutFlow", "Tank3OutFlow", "Tank2.level", "wt3_valve"]
for i in range(len(attr)):
    title = "Prediction of "+str(attr[i])
    actual = raw_data[1900:2000,i]
    pred = res_inv_yhat.T
    pred_df = pd.DataFrame(res_inv_yhat)
    # specify the range based on the length of predicted output
    index = pd.Index(list(range(100,200)))
    pred_df = pred_df.set_index(index)
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylabel("Values")
#     plt.plot(pred[i], label="predicted")
#     plt.plot(actual, label="actual")
    plt.plot(pred_df[i])
    plt.plot(actual)
    plt.show()
