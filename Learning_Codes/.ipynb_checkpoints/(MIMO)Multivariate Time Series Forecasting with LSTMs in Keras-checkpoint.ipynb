# %%
from pandas import read_csv
from datetime import datetime
# load data
def parse(x):
	return datetime.strptime(x, '%Y %m %d %H')
dataset = read_csv('raw.csv',  parse_dates = [['year', 'month', 'day', 'hour']], index_col=0, date_parser=parse)
dataset.drop('No', axis=1, inplace=True)
# manually specify column names
dataset.columns = ['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']
dataset.index.name = 'date'
# mark all NA values with 0
dataset['pollution'].fillna(0, inplace=True)
# drop the first 24 hours
dataset = dataset[24:]
# summarize first 5 rows
print(dataset.head(5))
# save to file
dataset.to_csv('pollution2.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [1], in <cell line: 6>()
#       4 def parse(x):
#       5 	return datetime.strptime(x, '%Y %m %d %H')
# ----> 6 dataset = read_csv('raw.csv',  parse_dates = [['year', 'month', 'day', 'hour']], index_col=0, date_parser=parse)
#       7 dataset.drop('No', axis=1, inplace=True)
#       8 # manually specify column names
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'raw.csv'

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43800 entries, 2010-01-02 00:00:00 to 2014-12-31 23:00:00
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pollution  43800 non-null  float64
#  1   dew        43800 non-null  int64
#  2   temp       43800 non-null  float64
#  3   press      43800 non-null  float64
#  4   wnd_dir    43800 non-null  object
#  5   wnd_spd    43800 non-null  float64
#  6   snow       43800 non-null  int64
#  7   rain       43800 non-null  int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 3.0+ MB

# %%
from pandas import read_csv
from matplotlib import pyplot
# load dataset
dataset = read_csv('pollution.csv', header=0, index_col=0)
values = dataset.values
# specify columns to plot
groups = [0, 1, 2, 3, 5, 6, 7]
i = 1
# plot each column
pyplot.figure()
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(dataset.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %% [markdown]
# ### Multivariate LSTM Forecast Model

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
 
# load dataset
dataset = read_csv('pollution.csv', header=0, index_col=0)
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict
reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
print(reframed.head())
 
# split into train and test sets
values = reframed.values
n_train_hours = 365 * 24
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
 
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
 
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

pyplot.plot(inv_y, label='predicted')
pyplot.plot(test_y, label='actual')
pyplot.legend()
pyplot.show()

# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.129779   0.352941   0.245902   0.527273   0.666667   0.002290
# 2   0.148893   0.367647   0.245902   0.527273   0.666667   0.003811
# 3   0.159960   0.426471   0.229508   0.545454   0.666667   0.005332
# 4   0.182093   0.485294   0.229508   0.563637   0.666667   0.008391
# 5   0.138833   0.485294   0.229508   0.563637   0.666667   0.009912
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1   0.000000        0.0  0.148893
# 2   0.000000        0.0  0.159960
# 3   0.000000        0.0  0.182093
# 4   0.037037        0.0  0.138833
# 5   0.074074        0.0  0.109658
# (8760, 1, 8) (8760,) (35039, 1, 8) (35039,)
# Epoch 1/50
# 122/122 - 4s - loss: 0.0556 - val_loss: 0.0639 - 4s/epoch - 29ms/step
# Epoch 2/50
# 122/122 - 1s - loss: 0.0402 - val_loss: 0.0703 - 989ms/epoch - 8ms/step
# Epoch 3/50
# 122/122 - 1s - loss: 0.0259 - val_loss: 0.0602 - 968ms/epoch - 8ms/step
# Epoch 4/50
# 122/122 - 1s - loss: 0.0189 - val_loss: 0.0511 - 997ms/epoch - 8ms/step
# Epoch 5/50
# 122/122 - 1s - loss: 0.0165 - val_loss: 0.0373 - 1s/epoch - 10ms/step
# Epoch 6/50
# 122/122 - 1s - loss: 0.0155 - val_loss: 0.0252 - 1s/epoch - 9ms/step
# Epoch 7/50
# 122/122 - 1s - loss: 0.0150 - val_loss: 0.0199 - 1s/epoch - 11ms/step
# Epoch 8/50
# 122/122 - 1s - loss: 0.0150 - val_loss: 0.0178 - 994ms/epoch - 8ms/step
# Epoch 9/50
# 122/122 - 1s - loss: 0.0148 - val_loss: 0.0162 - 970ms/epoch - 8ms/step
# Epoch 10/50
# 122/122 - 1s - loss: 0.0148 - val_loss: 0.0157 - 952ms/epoch - 8ms/step
# Epoch 11/50
# 122/122 - 1s - loss: 0.0148 - val_loss: 0.0149 - 964ms/epoch - 8ms/step
# Epoch 12/50
# 122/122 - 1s - loss: 0.0147 - val_loss: 0.0145 - 970ms/epoch - 8ms/step
# Epoch 13/50
# 122/122 - 1s - loss: 0.0147 - val_loss: 0.0144 - 965ms/epoch - 8ms/step
# Epoch 14/50
# 122/122 - 1s - loss: 0.0149 - val_loss: 0.0140 - 987ms/epoch - 8ms/step
# Epoch 15/50
# 122/122 - 1s - loss: 0.0148 - val_loss: 0.0137 - 977ms/epoch - 8ms/step
# Epoch 16/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0144 - 1s/epoch - 9ms/step
# Epoch 17/50
# 122/122 - 1s - loss: 0.0148 - val_loss: 0.0142 - 1s/epoch - 9ms/step
# Epoch 18/50
# 122/122 - 1s - loss: 0.0148 - val_loss: 0.0138 - 1s/epoch - 8ms/step
# Epoch 19/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0139 - 974ms/epoch - 8ms/step
# Epoch 20/50
# 122/122 - 1s - loss: 0.0148 - val_loss: 0.0136 - 1s/epoch - 10ms/step
# Epoch 21/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0141 - 1s/epoch - 9ms/step
# Epoch 22/50
# 122/122 - 1s - loss: 0.0147 - val_loss: 0.0137 - 1s/epoch - 12ms/step
# Epoch 23/50
# 122/122 - 1s - loss: 0.0147 - val_loss: 0.0136 - 1s/epoch - 8ms/step
# Epoch 24/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0136 - 1s/epoch - 8ms/step
# Epoch 25/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0138 - 1s/epoch - 9ms/step
# Epoch 26/50
# 122/122 - 1s - loss: 0.0147 - val_loss: 0.0139 - 998ms/epoch - 8ms/step
# Epoch 27/50
# 122/122 - 1s - loss: 0.0144 - val_loss: 0.0136 - 1s/epoch - 9ms/step
# Epoch 28/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0136 - 1s/epoch - 10ms/step
# Epoch 29/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0135 - 1s/epoch - 10ms/step
# Epoch 30/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0136 - 1s/epoch - 10ms/step
# Epoch 31/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0136 - 1s/epoch - 9ms/step
# Epoch 32/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0135 - 969ms/epoch - 8ms/step
# Epoch 33/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0136 - 978ms/epoch - 8ms/step
# Epoch 34/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0136 - 997ms/epoch - 8ms/step
# Epoch 35/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0136 - 1s/epoch - 11ms/step
# Epoch 36/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0138 - 1s/epoch - 10ms/step
# Epoch 37/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0136 - 1s/epoch - 10ms/step
# Epoch 38/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0137 - 1s/epoch - 9ms/step
# Epoch 39/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0138 - 979ms/epoch - 8ms/step
# Epoch 40/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0138 - 967ms/epoch - 8ms/step
# Epoch 41/50
# 122/122 - 1s - loss: 0.0146 - val_loss: 0.0136 - 967ms/epoch - 8ms/step
# Epoch 42/50
# 122/122 - 1s - loss: 0.0144 - val_loss: 0.0136 - 980ms/epoch - 8ms/step
# Epoch 43/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0135 - 985ms/epoch - 8ms/step
# Epoch 44/50
# 122/122 - 1s - loss: 0.0145 - val_loss: 0.0136 - 983ms/epoch - 8ms/step
# Epoch 45/50
# 122/122 - 1s - loss: 0.0144 - val_loss: 0.0135 - 998ms/epoch - 8ms/step
# Epoch 46/50
# 122/122 - 1s - loss: 0.0144 - val_loss: 0.0137 - 980ms/epoch - 8ms/step
# Epoch 47/50
# 122/122 - 1s - loss: 0.0143 - val_loss: 0.0135 - 988ms/epoch - 8ms/step
# Epoch 48/50
# 122/122 - 1s - loss: 0.0143 - val_loss: 0.0136 - 1s/epoch - 9ms/step
# Epoch 49/50
# 122/122 - 1s - loss: 0.0144 - val_loss: 0.0136 - 988ms/epoch - 8ms/step
# Epoch 50/50
# 122/122 - 1s - loss: 0.0143 - val_loss: 0.0135 - 1s/epoch - 10ms/step
# Test RMSE: 26.490

# %% [markdown]
# ### Train on multiple Lag Timesteps Example

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
 
# load dataset
dataset = read_csv('pollution.csv', header=0, index_col=0)
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# specify the number of lag hours
n_hours = 3
n_features = 8
# frame as supervised learning
reframed = series_to_supervised(scaled, n_hours, 1)
print(reframed.shape)
 
# split into train and test sets
values = reframed.values
n_train_hours = 365 * 24
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
n_obs = n_hours * n_features
train_X, train_y = train[:, :n_obs], train[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -n_features]
print(train_X.shape, len(train_X), train_y.shape)
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
 
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
 
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], n_hours*n_features))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -7:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -7:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# (43797, 32)
# (8760, 24) 8760 (8760,)
# (8760, 3, 8) (8760,) (35037, 3, 8) (35037,)
# Epoch 1/50
# 122/122 - 8s - loss: 0.0454 - val_loss: 0.0900 - 8s/epoch - 63ms/step
# Epoch 2/50
# 122/122 - 2s - loss: 0.0276 - val_loss: 0.0605 - 2s/epoch - 19ms/step
# Epoch 3/50
# 122/122 - 2s - loss: 0.0220 - val_loss: 0.0345 - 2s/epoch - 19ms/step
# Epoch 4/50
# 122/122 - 2s - loss: 0.0214 - val_loss: 0.0301 - 2s/epoch - 20ms/step
# Epoch 5/50
# 122/122 - 3s - loss: 0.0207 - val_loss: 0.0254 - 3s/epoch - 22ms/step
# Epoch 6/50
# 122/122 - 2s - loss: 0.0201 - val_loss: 0.0225 - 2s/epoch - 19ms/step
# Epoch 7/50
# 122/122 - 2s - loss: 0.0196 - val_loss: 0.0205 - 2s/epoch - 19ms/step
# Epoch 8/50
# 122/122 - 2s - loss: 0.0191 - val_loss: 0.0201 - 2s/epoch - 19ms/step
# Epoch 9/50
# 122/122 - 2s - loss: 0.0187 - val_loss: 0.0191 - 2s/epoch - 20ms/step
# Epoch 10/50
# 122/122 - 2s - loss: 0.0181 - val_loss: 0.0191 - 2s/epoch - 19ms/step
# Epoch 11/50
# 122/122 - 2s - loss: 0.0178 - val_loss: 0.0194 - 2s/epoch - 19ms/step
# Epoch 12/50
# 122/122 - 2s - loss: 0.0174 - val_loss: 0.0201 - 2s/epoch - 19ms/step
# Epoch 13/50
# 122/122 - 2s - loss: 0.0169 - val_loss: 0.0198 - 2s/epoch - 20ms/step
# Epoch 14/50
# 122/122 - 3s - loss: 0.0164 - val_loss: 0.0196 - 3s/epoch - 21ms/step
# Epoch 15/50
# 122/122 - 3s - loss: 0.0161 - val_loss: 0.0181 - 3s/epoch - 22ms/step
# Epoch 16/50
# 122/122 - 2s - loss: 0.0156 - val_loss: 0.0178 - 2s/epoch - 20ms/step
# Epoch 17/50
# 122/122 - 2s - loss: 0.0156 - val_loss: 0.0170 - 2s/epoch - 20ms/step
# Epoch 18/50
# 122/122 - 2s - loss: 0.0151 - val_loss: 0.0175 - 2s/epoch - 20ms/step
# Epoch 19/50
# 122/122 - 2s - loss: 0.0151 - val_loss: 0.0174 - 2s/epoch - 19ms/step
# Epoch 20/50
# 122/122 - 2s - loss: 0.0149 - val_loss: 0.0181 - 2s/epoch - 19ms/step
# Epoch 21/50
# 122/122 - 2s - loss: 0.0150 - val_loss: 0.0172 - 2s/epoch - 20ms/step
# Epoch 22/50
# 122/122 - 2s - loss: 0.0146 - val_loss: 0.0176 - 2s/epoch - 19ms/step
# Epoch 23/50
# 122/122 - 2s - loss: 0.0150 - val_loss: 0.0168 - 2s/epoch - 19ms/step
# Epoch 24/50
# 122/122 - 2s - loss: 0.0147 - val_loss: 0.0172 - 2s/epoch - 20ms/step
# Epoch 25/50
# 122/122 - 2s - loss: 0.0147 - val_loss: 0.0166 - 2s/epoch - 19ms/step
# Epoch 26/50
# 122/122 - 2s - loss: 0.0145 - val_loss: 0.0167 - 2s/epoch - 20ms/step
# Epoch 27/50
# 122/122 - 2s - loss: 0.0148 - val_loss: 0.0158 - 2s/epoch - 20ms/step
# Epoch 28/50
# 122/122 - 2s - loss: 0.0145 - val_loss: 0.0164 - 2s/epoch - 20ms/step
# Epoch 29/50
# 122/122 - 2s - loss: 0.0146 - val_loss: 0.0158 - 2s/epoch - 19ms/step
# Epoch 30/50
# 122/122 - 2s - loss: 0.0144 - val_loss: 0.0156 - 2s/epoch - 20ms/step
# Epoch 31/50
# 122/122 - 2s - loss: 0.0146 - val_loss: 0.0151 - 2s/epoch - 19ms/step
# Epoch 32/50
# 122/122 - 2s - loss: 0.0143 - val_loss: 0.0150 - 2s/epoch - 19ms/step
# Epoch 33/50
# 122/122 - 2s - loss: 0.0145 - val_loss: 0.0152 - 2s/epoch - 20ms/step
# Epoch 34/50
# 122/122 - 2s - loss: 0.0144 - val_loss: 0.0147 - 2s/epoch - 19ms/step
# Epoch 35/50
# 122/122 - 2s - loss: 0.0144 - val_loss: 0.0145 - 2s/epoch - 19ms/step
# Epoch 36/50
# 122/122 - 2s - loss: 0.0142 - val_loss: 0.0148 - 2s/epoch - 20ms/step
# Epoch 37/50
# 122/122 - 2s - loss: 0.0144 - val_loss: 0.0147 - 2s/epoch - 20ms/step
# Epoch 38/50
# 122/122 - 3s - loss: 0.0142 - val_loss: 0.0141 - 3s/epoch - 24ms/step
# Epoch 39/50
# 122/122 - 3s - loss: 0.0143 - val_loss: 0.0145 - 3s/epoch - 23ms/step
# Epoch 40/50
# 122/122 - 2s - loss: 0.0143 - val_loss: 0.0143 - 2s/epoch - 20ms/step
# Epoch 41/50
# 122/122 - 2s - loss: 0.0144 - val_loss: 0.0142 - 2s/epoch - 20ms/step
# Epoch 42/50
# 122/122 - 2s - loss: 0.0142 - val_loss: 0.0138 - 2s/epoch - 20ms/step
# Epoch 43/50
# 122/122 - 2s - loss: 0.0142 - val_loss: 0.0142 - 2s/epoch - 20ms/step
# Epoch 44/50
# 122/122 - 2s - loss: 0.0142 - val_loss: 0.0141 - 2s/epoch - 19ms/step
# Epoch 45/50
# 122/122 - 2s - loss: 0.0144 - val_loss: 0.0139 - 2s/epoch - 20ms/step
# Epoch 46/50
# 122/122 - 2s - loss: 0.0143 - val_loss: 0.0141 - 2s/epoch - 20ms/step
# Epoch 47/50
# 122/122 - 2s - loss: 0.0142 - val_loss: 0.0140 - 2s/epoch - 19ms/step
# Epoch 48/50
# 122/122 - 2s - loss: 0.0143 - val_loss: 0.0139 - 2s/epoch - 19ms/step
# Epoch 49/50
# 122/122 - 2s - loss: 0.0143 - val_loss: 0.0139 - 2s/epoch - 19ms/step
# Epoch 50/50
# 122/122 - 2s - loss: 0.0143 - val_loss: 0.0137 - 2s/epoch - 20ms/step
# Test RMSE: 26.441
