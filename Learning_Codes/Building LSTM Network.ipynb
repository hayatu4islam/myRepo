# %% [markdown]
# # BUILDING DEEP LEARNING APPLICATIONS WITH KERAS 2.0

# %% [markdown]
# ## Preprocessing training data

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Load training data set from CSV file
training_data_df = pd.read_csv("phy_cps_train.csv")

# Load testing data set from CSV file
test_data_df = pd.read_csv("phy_cps_test.csv")

# Data needs to be scaled to a small range like 0 to 1 for the neural
# network to work well.
scaler = MinMaxScaler(feature_range=(0, 1))

# Scale both the training inputs and outputs
scaled_training = scaler.fit_transform(training_data_df)
scaled_testing = scaler.transform(test_data_df)

# Print out the adjustment that the scaler applied to the total_earnings column of data
print("Note: total_earnings values were scaled by multiplying by {:.10f} and adding {:.6f}".format(scaler.scale_[8], scaler.min_[8]))

# Create new pandas DataFrame objects from the scaled data
scaled_training_df = pd.DataFrame(scaled_training, columns=training_data_df.columns.values)
scaled_testing_df = pd.DataFrame(scaled_testing, columns=test_data_df.columns.values)

# Save scaled data dataframes to new CSV files
scaled_training_df.to_csv("sales_data_training_scaled.csv", index=False)
scaled_testing_df.to_csv("sales_data_testing_scaled.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [1], in <cell line: 15>()
#      12 scaler = MinMaxScaler(feature_range=(0, 1))
#      14 # Scale both the training inputs and outputs
# ---> 15 scaled_training = scaler.fit_transform(training_data_df)
#      16 scaled_testing = scaler.transform(test_data_df)
#      18 # Print out the adjustment that the scaler applied to the total_earnings column of data
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\preprocessing\_data.py:416, in MinMaxScaler.fit(self, X, y)
#     414 # Reset internal state before fitting
#     415 self._reset()
# --> 416 return self.partial_fit(X, y)
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\preprocessing\_data.py:453, in MinMaxScaler.partial_fit(self, X, y)
#     447     raise TypeError(
#     448         "MinMaxScaler does not support sparse input. "
#     449         "Consider using MaxAbsScaler instead."
#     450     )
#     452 first_pass = not hasattr(self, "n_samples_seen_")
# --> 453 X = self._validate_data(
#     454     X,
#     455     reset=first_pass,
#     456     estimator=self,
#     457     dtype=FLOAT_DTYPES,
#     458     force_all_finite="allow-nan",
#     459 )
#     461 data_min = np.nanmin(X, axis=0)
#     462 data_max = np.nanmax(X, axis=0)
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\base.py:566, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     564     raise ValueError("Validation should be done on X, y or both.")
#     565 elif not no_val_X and no_val_y:
# --> 566     X = check_array(X, **check_params)
#     567     out = X
#     568 elif no_val_X and not no_val_y:
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\sklearn\utils\validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# File ~\Anaconda3\envs\deeplearning\lib\site-packages\pandas\core\generic.py:2072, in NDFrame.__array__(self, dtype)
#    2071 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2072     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: '09/04/2021 18:23'

# %% [markdown]
# ## Neural Network tensorflow

# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import *

#training_data_df = pd.read_csv(io.BytesIO(uploaded4["sales_data_training_scaled.csv"]))
training_data_df = pd.read_csv('sales_data_training_scaled.csv')

X = training_data_df.drop('total_earnings', axis=1).values
Y = training_data_df[['total_earnings']].values

# Define the model
model = Sequential()
model.add(Dense(50, input_dim=9, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2
)

# Load the separate test data set
#test_data_df = pd.read_csv(io.BytesIO(uploaded5['sales_data_test_scaled.csv']))
test_data_df = pd.read_csv("sales_data_test_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))

# Save the model to disk
model.save("trained_model.h5")
print("Model saved to disk.")
# Out:
# Epoch 1/50
# 32/32 - 4s - loss: 0.0175 - 4s/epoch - 116ms/step
# Epoch 2/50
# 32/32 - 0s - loss: 0.0017 - 71ms/epoch - 2ms/step
# Epoch 3/50
# 32/32 - 0s - loss: 6.4824e-04 - 55ms/epoch - 2ms/step
# Epoch 4/50
# 32/32 - 0s - loss: 3.6590e-04 - 63ms/epoch - 2ms/step
# Epoch 5/50
# 32/32 - 0s - loss: 2.4667e-04 - 55ms/epoch - 2ms/step
# Epoch 6/50
# 32/32 - 0s - loss: 1.9756e-04 - 52ms/epoch - 2ms/step
# Epoch 7/50
# 32/32 - 0s - loss: 1.6620e-04 - 59ms/epoch - 2ms/step
# Epoch 8/50
# 32/32 - 0s - loss: 1.2946e-04 - 55ms/epoch - 2ms/step
# Epoch 9/50
# 32/32 - 0s - loss: 9.5685e-05 - 55ms/epoch - 2ms/step
# Epoch 10/50
# 32/32 - 0s - loss: 8.8079e-05 - 59ms/epoch - 2ms/step
# Epoch 11/50
# 32/32 - 0s - loss: 6.5555e-05 - 53ms/epoch - 2ms/step
# Epoch 12/50
# 32/32 - 0s - loss: 6.0014e-05 - 58ms/epoch - 2ms/step
# Epoch 13/50
# 32/32 - 0s - loss: 5.5441e-05 - 52ms/epoch - 2ms/step
# Epoch 14/50
# 32/32 - 0s - loss: 5.0431e-05 - 61ms/epoch - 2ms/step
# Epoch 15/50
# 32/32 - 0s - loss: 4.5157e-05 - 56ms/epoch - 2ms/step
# Epoch 16/50
# 32/32 - 0s - loss: 5.0631e-05 - 62ms/epoch - 2ms/step
# Epoch 17/50
# 32/32 - 0s - loss: 5.8062e-05 - 53ms/epoch - 2ms/step
# Epoch 18/50
# 32/32 - 0s - loss: 3.9822e-05 - 55ms/epoch - 2ms/step
# Epoch 19/50
# 32/32 - 0s - loss: 3.5928e-05 - 54ms/epoch - 2ms/step
# Epoch 20/50
# 32/32 - 0s - loss: 5.4049e-05 - 59ms/epoch - 2ms/step
# Epoch 21/50
# 32/32 - 0s - loss: 3.5077e-05 - 53ms/epoch - 2ms/step
# Epoch 22/50
# 32/32 - 0s - loss: 3.8361e-05 - 60ms/epoch - 2ms/step
# Epoch 23/50
# 32/32 - 0s - loss: 3.0454e-05 - 56ms/epoch - 2ms/step
# Epoch 24/50
# 32/32 - 0s - loss: 5.1251e-05 - 61ms/epoch - 2ms/step
# Epoch 25/50
# 32/32 - 0s - loss: 5.6487e-05 - 64ms/epoch - 2ms/step
# Epoch 26/50
# 32/32 - 0s - loss: 4.5456e-05 - 58ms/epoch - 2ms/step
# Epoch 27/50
# 32/32 - 0s - loss: 3.3682e-05 - 57ms/epoch - 2ms/step
# Epoch 28/50
# 32/32 - 0s - loss: 3.9893e-05 - 60ms/epoch - 2ms/step
# Epoch 29/50
# 32/32 - 0s - loss: 2.9229e-05 - 52ms/epoch - 2ms/step
# Epoch 30/50
# 32/32 - 0s - loss: 2.7394e-05 - 59ms/epoch - 2ms/step
# Epoch 31/50
# 32/32 - 0s - loss: 3.1538e-05 - 58ms/epoch - 2ms/step
# Epoch 32/50
# 32/32 - 0s - loss: 3.9994e-05 - 59ms/epoch - 2ms/step
# Epoch 33/50
# 32/32 - 0s - loss: 4.6973e-05 - 57ms/epoch - 2ms/step
# Epoch 34/50
# 32/32 - 0s - loss: 4.3688e-05 - 63ms/epoch - 2ms/step
# Epoch 35/50
# 32/32 - 0s - loss: 3.1210e-05 - 53ms/epoch - 2ms/step
# Epoch 36/50
# 32/32 - 0s - loss: 6.1045e-05 - 56ms/epoch - 2ms/step
# Epoch 37/50
# 32/32 - 0s - loss: 3.5481e-05 - 52ms/epoch - 2ms/step
# Epoch 38/50
# 32/32 - 0s - loss: 4.1557e-05 - 53ms/epoch - 2ms/step
# Epoch 39/50
# 32/32 - 0s - loss: 4.5892e-05 - 54ms/epoch - 2ms/step
# Epoch 40/50
# 32/32 - 0s - loss: 5.0099e-05 - 62ms/epoch - 2ms/step
# Epoch 41/50
# 32/32 - 0s - loss: 3.3366e-05 - 54ms/epoch - 2ms/step
# Epoch 42/50
# 32/32 - 0s - loss: 3.0522e-05 - 61ms/epoch - 2ms/step
# Epoch 43/50
# 32/32 - 0s - loss: 2.6160e-05 - 54ms/epoch - 2ms/step
# Epoch 44/50
# 32/32 - 0s - loss: 1.8370e-05 - 60ms/epoch - 2ms/step
# Epoch 45/50
# 32/32 - 0s - loss: 2.6225e-05 - 70ms/epoch - 2ms/step
# Epoch 46/50
# 32/32 - 0s - loss: 3.0293e-05 - 60ms/epoch - 2ms/step
# Epoch 47/50
# 32/32 - 0s - loss: 3.0197e-05 - 52ms/epoch - 2ms/step
# Epoch 48/50
# 32/32 - 0s - loss: 2.3759e-05 - 56ms/epoch - 2ms/step
# Epoch 49/50
# 32/32 - 0s - loss: 2.9666e-05 - 52ms/epoch - 2ms/step
# Epoch 50/50
# 32/32 - 0s - loss: 4.2665e-05 - 62ms/epoch - 2ms/step
# The mean squared error (MSE) for the test data set is: 0.00015866370813455433
# Model saved to disk.

# %% [markdown]
# ## Load saved model

# %%
import pandas as pd
from keras.models import load_model

model = load_model('trained_model.h5')

X = pd.read_csv("proposed_new_product.csv").values
prediction = model.predict(X)

# Grab just the first element of the first prediction (since we only have one)
prediction = prediction[0][0]

# Re-scale the data from the 0-to-1 range back to dollars
# These constants are from when the data was originally scaled down to the 0-to-1 range
prediction = prediction + 0.1159
prediction = prediction / 0.0000036968

print("Earnings Prediction for Proposed Product - ${}".format(prediction))
# Out:
# Earnings Prediction for Proposed Product - $267912.93557601894

# %% [markdown]
# ## Monitoring a Keras model with TensorBoard

# %%
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import *

training_data_df = pd.read_csv("sales_data_training_scaled.csv")

X = training_data_df.drop('total_earnings', axis=1).values
Y = training_data_df[['total_earnings']].values

# Define the model
model = Sequential()
model.add(Dense(50, input_dim=9, activation='relu', name='layer_1'))
model.add(Dense(100, activation='relu', name='layer_2'))
model.add(Dense(50, activation='relu', name='layer_3'))
model.add(Dense(1, activation='linear', name='output_layer'))
model.compile(loss='mean_squared_error', optimizer='adam')

# Create a TensorBoard logger
logger = keras.callbacks.TensorBoard(
    log_dir='logs',
    write_graph=True,
    histogram_freq=5
)

# Train the model
model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2,
    callbacks=[logger]
)

# Load the separate test data set
test_data_df = pd.read_csv("sales_data_test_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))
# Out:
# Epoch 1/50
# 32/32 - 2s - loss: 0.0057 - 2s/epoch - 51ms/step
# Epoch 2/50
# 32/32 - 0s - loss: 9.0995e-04 - 136ms/epoch - 4ms/step
# Epoch 3/50
# 32/32 - 0s - loss: 3.7279e-04 - 118ms/epoch - 4ms/step
# Epoch 4/50
# 32/32 - 0s - loss: 2.4609e-04 - 200ms/epoch - 6ms/step
# Epoch 5/50
# 32/32 - 0s - loss: 1.7342e-04 - 197ms/epoch - 6ms/step
# Epoch 6/50
# 32/32 - 0s - loss: 1.1031e-04 - 340ms/epoch - 11ms/step
# Epoch 7/50
# 32/32 - 0s - loss: 9.1766e-05 - 177ms/epoch - 6ms/step
# Epoch 8/50
# 32/32 - 0s - loss: 7.0703e-05 - 183ms/epoch - 6ms/step
# Epoch 9/50
# 32/32 - 0s - loss: 5.7946e-05 - 152ms/epoch - 5ms/step
# Epoch 10/50
# 32/32 - 0s - loss: 6.4212e-05 - 213ms/epoch - 7ms/step
# Epoch 11/50
# 32/32 - 0s - loss: 6.0991e-05 - 478ms/epoch - 15ms/step
# Epoch 12/50
# 32/32 - 0s - loss: 3.8098e-05 - 174ms/epoch - 5ms/step
# Epoch 13/50
# 32/32 - 0s - loss: 3.7454e-05 - 151ms/epoch - 5ms/step
# Epoch 14/50
# 32/32 - 0s - loss: 4.1620e-05 - 136ms/epoch - 4ms/step
# Epoch 15/50
# 32/32 - 0s - loss: 4.8829e-05 - 166ms/epoch - 5ms/step
# Epoch 16/50
# 32/32 - 0s - loss: 4.4300e-05 - 415ms/epoch - 13ms/step
# Epoch 17/50
# 32/32 - 0s - loss: 3.4904e-05 - 150ms/epoch - 5ms/step
# Epoch 18/50
# 32/32 - 0s - loss: 3.2373e-05 - 198ms/epoch - 6ms/step
# Epoch 19/50
# 32/32 - 0s - loss: 3.8101e-05 - 123ms/epoch - 4ms/step
# Epoch 20/50
# 32/32 - 0s - loss: 4.0464e-05 - 209ms/epoch - 7ms/step
# Epoch 21/50
# 32/32 - 0s - loss: 2.8552e-05 - 373ms/epoch - 12ms/step
# Epoch 22/50
# 32/32 - 0s - loss: 2.4706e-05 - 121ms/epoch - 4ms/step
# Epoch 23/50
# 32/32 - 0s - loss: 3.1499e-05 - 163ms/epoch - 5ms/step
# Epoch 24/50
# 32/32 - 0s - loss: 6.0052e-05 - 165ms/epoch - 5ms/step
# Epoch 25/50
# 32/32 - 0s - loss: 9.6381e-05 - 167ms/epoch - 5ms/step
# Epoch 26/50
# 32/32 - 0s - loss: 6.1497e-05 - 448ms/epoch - 14ms/step
# Epoch 27/50
# 32/32 - 0s - loss: 5.5409e-05 - 139ms/epoch - 4ms/step
# Epoch 28/50
# 32/32 - 0s - loss: 3.6739e-05 - 226ms/epoch - 7ms/step
# Epoch 29/50
# 32/32 - 0s - loss: 4.0174e-05 - 126ms/epoch - 4ms/step
# Epoch 30/50
# 32/32 - 0s - loss: 4.7229e-05 - 163ms/epoch - 5ms/step
# Epoch 31/50
# 32/32 - 0s - loss: 8.7919e-05 - 306ms/epoch - 10ms/step
# Epoch 32/50
# 32/32 - 0s - loss: 4.1438e-05 - 177ms/epoch - 6ms/step
# Epoch 33/50
# 32/32 - 0s - loss: 2.8690e-05 - 197ms/epoch - 6ms/step
# Epoch 34/50
# 32/32 - 0s - loss: 3.7586e-05 - 169ms/epoch - 5ms/step
# Epoch 35/50
# 32/32 - 0s - loss: 2.4923e-05 - 120ms/epoch - 4ms/step
# Epoch 36/50
# 32/32 - 0s - loss: 3.1554e-05 - 226ms/epoch - 7ms/step
# Epoch 37/50
# 32/32 - 0s - loss: 3.5224e-05 - 122ms/epoch - 4ms/step
# Epoch 38/50
# 32/32 - 0s - loss: 3.4709e-05 - 118ms/epoch - 4ms/step
# Epoch 39/50
# 32/32 - 0s - loss: 3.1793e-05 - 102ms/epoch - 3ms/step
# Epoch 40/50
# 32/32 - 0s - loss: 4.2846e-05 - 132ms/epoch - 4ms/step
# Epoch 41/50
# 32/32 - 0s - loss: 3.8997e-05 - 227ms/epoch - 7ms/step
# Epoch 42/50
# 32/32 - 0s - loss: 2.7588e-05 - 123ms/epoch - 4ms/step
# Epoch 43/50
# 32/32 - 0s - loss: 3.2672e-05 - 115ms/epoch - 4ms/step
# Epoch 44/50
# 32/32 - 0s - loss: 9.3302e-05 - 118ms/epoch - 4ms/step
# Epoch 45/50
# 32/32 - 0s - loss: 5.4779e-05 - 132ms/epoch - 4ms/step
# Epoch 46/50
# 32/32 - 0s - loss: 4.9030e-05 - 242ms/epoch - 8ms/step
# Epoch 47/50
# 32/32 - 0s - loss: 4.8775e-05 - 109ms/epoch - 3ms/step
# Epoch 48/50
# 32/32 - 0s - loss: 6.8865e-05 - 117ms/epoch - 4ms/step
# Epoch 49/50
# 32/32 - 0s - loss: 8.7145e-05 - 117ms/epoch - 4ms/step
# Epoch 50/50
# 32/32 - 0s - loss: 8.0039e-05 - 116ms/epoch - 4ms/step
# The mean squared error (MSE) for the test data set is: 0.0001278647978324443

# %%
from platform import python_version
print(python_version())
# Out:
# 3.8.12

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.0
