# %% [markdown]
# ### Visualise data

# %%
from pandas import read_csv
import matplotlib.pyplot as plt
# mydata = read_csv('waterTankNew.csv', header=0, index_col=0)
mydata = read_csv('waterTank_Value_Flip.csv', header=0, index_col=0)
# attr = ["wt3_valve", "Tank1InFlow", "Tank1WaterLevel", "Tank3OutFlow", "Tank2.level"]
attr = ["Tank1WaterLevel", "Tank2WaterLevel", "Tank2OutFlow", "Tank3OutFlow", "Tank2.level", "wt3_valve"]
for i in range(len(attr)):
    title = "Plot of "+str(attr[i])
#     actual = mydata.iloc[:6000,i]
    actual = mydata.iloc[0:2000,i]
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylabel(attr[i])
#     plt.plot(actual, label="original")
    plt.plot(actual)
#     plt.legend()
    plt.show()

# %%
# multivariate output stacked lstm example
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, RepeatVector, TimeDistributed

# Load and preprocess data
data = pd.read_csv('waterTank_Value_Flip.csv', header=0, index_col=0)
raw_data = data.values
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(raw_data)

# Split data into train and test sets
# train_size = int(len(data) * 0.7)
train_size = 12000
test_size = len(data) - train_size
train, test = data_scaled[0:train_size,:], data_scaled[train_size:len(data),:]

# Define the number of time steps and features
n_steps_in = 100
n_steps_out = 20
n_features = data.shape[1]

# Reshape data for LSTM
def split_sequence(sequence, n_steps_in, n_steps_out):
    X, y = [], []
    for i in range(len(sequence)):
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out - 1
        if out_end_ix > len(sequence)-1:
            break
        seq_x, seq_y = sequence[i:end_ix, :], sequence[end_ix-1:out_end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

X_train, y_train = split_sequence(train, n_steps_in, n_steps_out)
X_test, y_test = split_sequence(test, n_steps_in, n_steps_out)

# Define the LSTM model
model = Sequential()
model.add(LSTM(20, activation='relu', input_shape=(n_steps_in, n_features)))
model.add(RepeatVector(n_steps_out))
model.add(LSTM(20, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(n_features)))

# Compile and fit the model
model.compile(optimizer='adam', loss='mse')
train_history = model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=2)

# Evaluate the model
mse = model.evaluate(X_test, y_test, verbose=0)
print('Mean Squared Error:', mse)

# Get the last n_steps_in time steps of the original data
x_original = data_scaled[-n_steps_in:, :]

# Reshape predictions for inverse scaling
x_original = x_original.reshape((1, n_steps_in, n_features))

# Make predictions on test data
y_pred = model.predict(x_original)

# Get the forecast values into the future
forecast = scaler.inverse_transform(y_pred[0, :, :])
# forecast = y_pred[0, :, :]

# print(forecast)

print("-------Learning Curve--------")
plt.plot(train_history.history['loss'], label='train')
# plt.plot(train_history.history['val_loss'], label='test')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

model.summary()

#save the model to disk
model.save('value-flip.h5')
print("Model saved!")

# View results
attr = ["Tank1WaterLevel", "Tank2WaterLevel", "Tank2OutFlow", "Tank3OutFlow", "Tank2.level", "wt3_valve"]
for i in range(len(attr)):
    title = "Prediction of "+str(attr[i])
    actual = raw_data[train_size - n_steps_in:train_size,i]
#     actual = raw_data[11901:12000,i]
#     pred = inv_yhat.T
    pred_df = pd.DataFrame(forecast)
    # specify the range based on the length of predicted output
#     index = pd.Index(list(range(n_steps_in,n_steps_in + n_steps_out)))
    index = pd.Index(list(range(n_steps_in, n_steps_in + n_steps_out)))
    pred_df = pred_df.set_index(index)
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylabel("values")
#     plt.plot(pred[i], label="predicted")
#     plt.plot(actual, label="actual")
    plt.plot(pred_df[i], label="predicted")
    plt.plot(actual, label="actual")
    plt.show()
# Out:
# Epoch 1/100
# 372/372 - 13s - loss: 0.0674 - 13s/epoch - 35ms/step
# Epoch 2/100
# 372/372 - 11s - loss: 0.0120 - 11s/epoch - 30ms/step
# Epoch 3/100
# 372/372 - 11s - loss: 0.0095 - 11s/epoch - 31ms/step
# Epoch 4/100
# 372/372 - 12s - loss: 0.0088 - 12s/epoch - 32ms/step
# Epoch 5/100
# 372/372 - 11s - loss: 0.0078 - 11s/epoch - 30ms/step
# Epoch 6/100
# 372/372 - 12s - loss: 0.0070 - 12s/epoch - 31ms/step
# Epoch 7/100
# 372/372 - 11s - loss: 0.0066 - 11s/epoch - 30ms/step
# Epoch 8/100
# 372/372 - 11s - loss: 0.0060 - 11s/epoch - 30ms/step
# Epoch 9/100
# 372/372 - 11s - loss: 0.0062 - 11s/epoch - 30ms/step
# Epoch 10/100
# 372/372 - 11s - loss: 0.0055 - 11s/epoch - 30ms/step
# Epoch 11/100
# 372/372 - 11s - loss: 0.0052 - 11s/epoch - 31ms/step
# Epoch 12/100
# 372/372 - 12s - loss: 0.0055 - 12s/epoch - 32ms/step
# Epoch 13/100
# 372/372 - 12s - loss: 0.0052 - 12s/epoch - 33ms/step
# Epoch 14/100
# 372/372 - 12s - loss: 0.0045 - 12s/epoch - 32ms/step
# Epoch 15/100
# 372/372 - 12s - loss: 0.0043 - 12s/epoch - 33ms/step
# Epoch 16/100
# 372/372 - 12s - loss: 0.0041 - 12s/epoch - 33ms/step
# Epoch 17/100
# 372/372 - 12s - loss: 0.0047 - 12s/epoch - 31ms/step
# Epoch 18/100
# 372/372 - 12s - loss: 0.0041 - 12s/epoch - 31ms/step
# Epoch 19/100
# 372/372 - 12s - loss: 0.0036 - 12s/epoch - 32ms/step
# Epoch 20/100
# 372/372 - 13s - loss: 0.0037 - 13s/epoch - 34ms/step
# Epoch 21/100
# 372/372 - 12s - loss: 0.0034 - 12s/epoch - 32ms/step
# Epoch 22/100
# 372/372 - 12s - loss: 0.0035 - 12s/epoch - 32ms/step
# Epoch 23/100
# 372/372 - 12s - loss: 0.0033 - 12s/epoch - 33ms/step
# Epoch 24/100
# 372/372 - 12s - loss: 0.0033 - 12s/epoch - 31ms/step
# Epoch 25/100
# 372/372 - 13s - loss: 0.0035 - 13s/epoch - 34ms/step
# Epoch 26/100
# 372/372 - 12s - loss: 0.0031 - 12s/epoch - 32ms/step
# Epoch 27/100
# 372/372 - 11s - loss: 0.0030 - 11s/epoch - 30ms/step
# Epoch 28/100
# 372/372 - 11s - loss: 0.0032 - 11s/epoch - 30ms/step
# Epoch 29/100
# 372/372 - 11s - loss: 0.0028 - 11s/epoch - 30ms/step
# Epoch 30/100
# 372/372 - 12s - loss: 0.0029 - 12s/epoch - 31ms/step
# Epoch 31/100
# 372/372 - 13s - loss: 0.0027 - 13s/epoch - 35ms/step
# Epoch 32/100
# 372/372 - 13s - loss: 0.0029 - 13s/epoch - 34ms/step
# Epoch 33/100
# 372/372 - 13s - loss: 0.0027 - 13s/epoch - 35ms/step
# Epoch 34/100
# 372/372 - 11s - loss: 0.0027 - 11s/epoch - 31ms/step
# Epoch 35/100
# 372/372 - 12s - loss: 0.0038 - 12s/epoch - 32ms/step
# Epoch 36/100
# 372/372 - 12s - loss: 0.0026 - 12s/epoch - 33ms/step
# Epoch 37/100
# 372/372 - 12s - loss: 0.0025 - 12s/epoch - 32ms/step
# Epoch 38/100
# 372/372 - 12s - loss: 0.0025 - 12s/epoch - 33ms/step
# Epoch 39/100
# 372/372 - 12s - loss: 0.0026 - 12s/epoch - 32ms/step
# Epoch 40/100
# 372/372 - 12s - loss: 0.0025 - 12s/epoch - 33ms/step
# Epoch 41/100
# 372/372 - 12s - loss: 0.0026 - 12s/epoch - 32ms/step
# Epoch 42/100
# 372/372 - 12s - loss: 0.0024 - 12s/epoch - 33ms/step
# Epoch 43/100
# 372/372 - 13s - loss: 0.0023 - 13s/epoch - 34ms/step
# Epoch 44/100
# 372/372 - 12s - loss: 0.0028 - 12s/epoch - 33ms/step
# Epoch 45/100
# 372/372 - 12s - loss: 0.0023 - 12s/epoch - 31ms/step
# Epoch 46/100
# 372/372 - 11s - loss: 0.0021 - 11s/epoch - 30ms/step
# Epoch 47/100
# 372/372 - 11s - loss: 0.0032 - 11s/epoch - 30ms/step
# Epoch 48/100
# 372/372 - 12s - loss: 0.0024 - 12s/epoch - 33ms/step
# Epoch 49/100
# 372/372 - 12s - loss: 0.0022 - 12s/epoch - 32ms/step
# Epoch 50/100
# 372/372 - 12s - loss: 0.0022 - 12s/epoch - 33ms/step
# Epoch 51/100
# 372/372 - 12s - loss: 0.0023 - 12s/epoch - 31ms/step
# Epoch 52/100
# 372/372 - 11s - loss: 0.0023 - 11s/epoch - 31ms/step
# Epoch 53/100
# 372/372 - 11s - loss: 0.0018 - 11s/epoch - 31ms/step
# Epoch 54/100
# 372/372 - 12s - loss: 0.0018 - 12s/epoch - 31ms/step
# Epoch 55/100
# 372/372 - 11s - loss: 0.0020 - 11s/epoch - 30ms/step
# Epoch 56/100
# 372/372 - 12s - loss: 0.0015 - 12s/epoch - 31ms/step
# Epoch 57/100
# 372/372 - 11s - loss: 0.0015 - 11s/epoch - 31ms/step
# Epoch 58/100
# 372/372 - 11s - loss: 0.0015 - 11s/epoch - 31ms/step
# Epoch 59/100
# 372/372 - 11s - loss: 0.0016 - 11s/epoch - 31ms/step
# Epoch 60/100
# 372/372 - 11s - loss: 0.0014 - 11s/epoch - 30ms/step
# Epoch 61/100
# 372/372 - 12s - loss: 0.0015 - 12s/epoch - 33ms/step
# Epoch 62/100
# 372/372 - 12s - loss: 0.0016 - 12s/epoch - 34ms/step
# Epoch 63/100
# 372/372 - 13s - loss: 0.0013 - 13s/epoch - 34ms/step
# Epoch 64/100
# 372/372 - 12s - loss: 0.0012 - 12s/epoch - 33ms/step
# Epoch 65/100
# 372/372 - 12s - loss: 0.0013 - 12s/epoch - 32ms/step
# Epoch 66/100
# 372/372 - 12s - loss: 0.0012 - 12s/epoch - 32ms/step
# Epoch 67/100
# 372/372 - 12s - loss: 0.0011 - 12s/epoch - 31ms/step
# Epoch 68/100
# 372/372 - 12s - loss: 0.0012 - 12s/epoch - 33ms/step
# Epoch 69/100
# 372/372 - 12s - loss: 0.0011 - 12s/epoch - 33ms/step
# Epoch 70/100
# 372/372 - 12s - loss: 0.0012 - 12s/epoch - 33ms/step
# Epoch 71/100
# 372/372 - 12s - loss: 0.0013 - 12s/epoch - 33ms/step
# Epoch 72/100
# 372/372 - 12s - loss: 0.0012 - 12s/epoch - 32ms/step
# Epoch 73/100
# 372/372 - 12s - loss: 0.0011 - 12s/epoch - 31ms/step
# Epoch 74/100
# 372/372 - 12s - loss: 0.0011 - 12s/epoch - 32ms/step
# Epoch 75/100
# 372/372 - 12s - loss: 0.0012 - 12s/epoch - 32ms/step
# Epoch 76/100
# 372/372 - 13s - loss: 0.0010 - 13s/epoch - 34ms/step
# Epoch 77/100
# 372/372 - 13s - loss: 0.0011 - 13s/epoch - 34ms/step
# Epoch 78/100
# 372/372 - 12s - loss: 0.0014 - 12s/epoch - 32ms/step
# Epoch 79/100
# 372/372 - 12s - loss: 0.0011 - 12s/epoch - 32ms/step
# Epoch 80/100
# 372/372 - 12s - loss: 0.0012 - 12s/epoch - 31ms/step
# Epoch 81/100
# 372/372 - 13s - loss: 9.7130e-04 - 13s/epoch - 36ms/step
# Epoch 82/100
# 372/372 - 12s - loss: 9.3014e-04 - 12s/epoch - 33ms/step
# Epoch 83/100
# 372/372 - 12s - loss: 9.5899e-04 - 12s/epoch - 33ms/step
# Epoch 84/100
# 372/372 - 12s - loss: 9.6416e-04 - 12s/epoch - 33ms/step
# Epoch 85/100
# 372/372 - 12s - loss: 8.7713e-04 - 12s/epoch - 32ms/step
# Epoch 86/100
# 372/372 - 12s - loss: 0.0011 - 12s/epoch - 32ms/step
# Epoch 87/100
# 372/372 - 11s - loss: 0.0010 - 11s/epoch - 30ms/step
# Epoch 88/100
# 372/372 - 12s - loss: 8.5927e-04 - 12s/epoch - 32ms/step
# Epoch 89/100
# 372/372 - 12s - loss: 0.0014 - 12s/epoch - 32ms/step
# Epoch 90/100
# 372/372 - 14s - loss: 8.1057e-04 - 14s/epoch - 36ms/step
# Epoch 91/100
# 372/372 - 11s - loss: 8.7678e-04 - 11s/epoch - 31ms/step
# Epoch 92/100
# 372/372 - 11s - loss: 8.1016e-04 - 11s/epoch - 30ms/step
# Epoch 93/100
# 372/372 - 13s - loss: 0.0010 - 13s/epoch - 35ms/step
# Epoch 94/100
# 372/372 - 13s - loss: 9.6332e-04 - 13s/epoch - 34ms/step
# Epoch 95/100
# 372/372 - 12s - loss: 0.0013 - 12s/epoch - 32ms/step
# Epoch 96/100
# 372/372 - 12s - loss: 8.0510e-04 - 12s/epoch - 33ms/step
# Epoch 97/100
# 372/372 - 13s - loss: 8.2993e-04 - 13s/epoch - 35ms/step
# Epoch 98/100
# 372/372 - 12s - loss: 9.4473e-04 - 12s/epoch - 34ms/step
# Epoch 99/100
# 372/372 - 12s - loss: 0.0011 - 12s/epoch - 33ms/step
# Epoch 100/100
# 372/372 - 11s - loss: 8.3362e-04 - 11s/epoch - 31ms/step
# Mean Squared Error: 0.00023531836632173508
# -------Learning Curve--------
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 20)                2160
#
#  repeat_vector (RepeatVector  (None, 20, 20)           0
#  )
#
#  lstm_1 (LSTM)               (None, 20, 20)            3280
#
#  time_distributed (TimeDistr  (None, 20, 6)            126
#  ibuted)
#
# =================================================================
# Total params: 5,566
# Trainable params: 5,566
# Non-trainable params: 0
# _________________________________________________________________
# Model saved!

# %%
# multivariate output stacked lstm example
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, RepeatVector, TimeDistributed

# Load and preprocess data
data = pd.read_csv('stuck_at_tank2.csv', header=0, index_col=0)
raw_data = data.values
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(raw_data)

# Split data into train and test sets
# train_size = int(len(data) * 0.7)
train_size = 12000
test_size = len(data) - train_size
train, test = data_scaled[0:train_size,:], data_scaled[train_size:len(data),:]

# Define the number of time steps and features
n_steps_in = 100
n_steps_out = 100
n_features = data.shape[1]

# Reshape data for LSTM
def split_sequence(sequence, n_steps_in, n_steps_out):
    X, y = [], []
    for i in range(len(sequence)):
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out - 1
        if out_end_ix > len(sequence)-1:
            break
        seq_x, seq_y = sequence[i:end_ix, :], sequence[end_ix-1:out_end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

X_train, y_train = split_sequence(train, n_steps_in, n_steps_out)
X_test, y_test = split_sequence(test, n_steps_in, n_steps_out)

# Define the LSTM model
model = Sequential()
model.add(LSTM(25, activation='relu', input_shape=(n_steps_in, n_features)))
model.add(RepeatVector(n_steps_out))
model.add(LSTM(20, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(n_features)))

# Compile and fit the model
model.compile(optimizer='adam', loss='mse')
train_history = model.fit(X_train, y_train, epochs=40, batch_size=32, verbose=2)

# Evaluate the model
mse = model.evaluate(X_test, y_test, verbose=0)
print('Mean Squared Error:', mse)

# Get the last n_steps_in time steps of the original data
x_original = raw_data[-n_steps_in:, :]

# Reshape predictions for inverse scaling
x_original = x_original.reshape((1, n_steps_in, n_features))

# Make predictions on test data
y_pred = model.predict(x_original)

# Get the forecast values into the future
forecast = y_pred[0, :, :]
print(forecast)

print("-------Learning Curve--------")
plt.plot(train_history.history['loss'], label='train')
# plt.plot(train_history.history['val_loss'], label='test')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# View results
attr = ["Tank3OutFlow", "Tank2.level", "wt3_valve", "Tank1WaterLevel", "Tank2WaterLevel", "Tank2OutFlow"]
# attr = ["wt3_valve", "Tank1InFlow", "Tank1WaterLevel", "Tank3OutFlow", "Tank2.level"]
for i in range(len(attr)):
    title = "Prediction of "+str(attr[i])
    actual = raw_data[train_size - n_steps_in:train_size,i]
#     actual = raw_data[11901:12000,i]
    pred = inv_yhat.T
    pred_df = pd.DataFrame(inv_yhat)
    # specify the range based on the length of predicted output
#     index = pd.Index(list(range(n_steps_in,n_steps_in + n_steps_out)))
    index = pd.Index(list(range(100,200)))
    pred_df = pred_df.set_index(index)
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylabel("values")
#     plt.plot(pred[i], label="predicted")
#     plt.plot(actual, label="actual")
    plt.plot(pred_df[i], label="predicted")
    plt.plot(actual, label="actual")
    plt.show()

# %%
# attr = len(inv_yhat.T)
attr = ["Tank3OutFlow", "Tank2.level", "wt3_valve", "Tank1WaterLevel", "Tank2WaterLevel", "Tank2OutFlow"]
# attr = ["wt3_valve", "Tank1InFlow", "Tank1WaterLevel", "Tank3OutFlow", "Tank2.level"]
for i in range(len(attr)):
    title = "Prediction of "+str(attr[i])
#     actual = raw_data[9901:10000,i]
    actual = raw_data[11901:12000,i]
    pred = inv_yhat.T
    pred_df = pd.DataFrame(inv_yhat)
    # specify the range based on the length of predicted output
    index = pd.Index(list(range(100,200)))
    pred_df = pred_df.set_index(index)
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylabel("values")
#     plt.plot(pred[i], label="predicted")
#     plt.plot(actual, label="actual")
    plt.plot(pred_df[i])
    plt.plot(actual)
    plt.show()

# %% [markdown]
# ### Load the pretrained surrogate model

# %%
from keras.models import load_model

s_model = load_model('tank1_stuck_at.h5')

new_data = scaled_data[12000:14000,:]

# choose a number of time steps
n_steps_in, n_steps_out = 50, 100

# convert into input/output
test_X, test_y = split_sequences(new_data, n_steps_in, n_steps_out)
# the dataset knows the number of features, e.g. 2
n_features = X.shape[2]

score = s_model.evaluate(test_X, test_y, verbose=0)
# test_yhat = s_model.predict(test_X, verbose=0)
print("%s:  %.2f%%" % (s_model.metrics_names[0], score*100))


print("Prediction is successful!")
# Out:
# loss:  0.09%
# Prediction is successful!
