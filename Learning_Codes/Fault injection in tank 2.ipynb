# %% [markdown]
# ### Visualise data

# %%
from pandas import read_csv
import matplotlib.pyplot as plt
# mydata = read_csv('waterTankNew.csv', header=0, index_col=0)
mydata = read_csv('stuck_at_tank2.csv', header=0, index_col=0)
# attr = ["wt3_valve", "Tank1InFlow", "Tank1WaterLevel", "Tank3OutFlow", "Tank2.level"]
attr = ["Tank3OutFlow", "Tank2.level", "wt3_valve", "Tank1WaterLevel", "Tank2WaterLevel", "Tank2OutFlow"]
for i in range(len(attr)):
    title = "Plot of "+str(attr[i])
    actual = mydata.iloc[:2000,i]
#     actual = mydata.iloc[750:1000,i]
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylabel(attr[i])
#     plt.plot(actual, label="original")
    plt.plot(actual)
#     plt.legend()
    plt.show()

# %%
# multivariate output stacked lstm example
import pandas as pd
from numpy import array
from numpy import hstack, vstack
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Bidirectional, RepeatVector, TimeDistributed
from keras.layers.core import Dropout
from sklearn.preprocessing import MinMaxScaler
from pandas import read_csv
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np



# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# define input sequence

# Read the data
# data = read_csv('waterTank.csv', header=0, index_col=0)
# data = read_csv('outputs.csv', header=0, index_col=0)
# data = read_csv('trig.csv', header=0, index_col=0)
data = read_csv('stuck_at_tank2.csv', header=0, index_col=0)

# horizontally stack columns
raw_data = data.values
print(f'The shape of the raw_data before scaling is {raw_data.shape}')
#normalize input features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(raw_data)

n_train = 12000
dataset = scaled_data[0:n_train,:]
# choose a number of time steps
# n_steps_in, n_steps_out = 50, 100
n_steps_in, n_steps_out = 50, 100

# convert into input/output
X, y = split_sequences(dataset, n_steps_in, n_steps_out)
# the dataset knows the number of features, e.g. 2
n_features = X.shape[2]
# define model
model = Sequential()
model.add(LSTM(25, activation='relu', input_shape=(n_steps_in, n_features)))
model.add(RepeatVector(n_steps_out))
model.add(LSTM(25, activation='relu', return_sequences=True))
# model.add(TimeDistributed(Dense(50, activation='relu')))
model.add(TimeDistributed(Dense(n_features)))
# model.add(TimeDistributed(Dense(1)))
model.compile(optimizer='adam', loss='mse')
# fit model
train_history = model.fit(X, y, epochs=60, verbose=2, shuffle=False)

# demonstrate Direct prediction
# x_inp = raw_data[n_train:n_train+n_steps,:]
x_inp = scaled_data[n_train:n_train+n_steps_in,:]
print(f'Initial shape of x_input {x_inp.shape}')
x_input = x_inp.reshape((1, n_steps_in, n_features))
yhat = model.predict(x_input, verbose=0)
print(f'The shape of yhat after prediction is {yhat.shape}')
yhat = yhat.reshape(n_steps_out, n_features)
print(f'The new shape of yhat  is {yhat.shape}')
inv_yhat = scaler.inverse_transform(yhat)
print(inv_yhat)

print("-------Learning Curve--------")
plt.plot(train_history.history['loss'], label='train')
# plt.plot(train_history.history['val_loss'], label='test')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

model.summary()

#save the model to disk
model.save('tank2_stuck_at.h5')
print("Model saved!")
# Out:
# The shape of the raw_data before scaling is (15001, 6)
# Epoch 1/60
# 371/371 - 24s - loss: 0.1035 - 24s/epoch - 66ms/step
# Epoch 2/60
# 371/371 - 23s - loss: 0.0526 - 23s/epoch - 63ms/step
# Epoch 3/60
# 371/371 - 22s - loss: 0.0516 - 22s/epoch - 58ms/step
# Epoch 4/60
# 371/371 - 18s - loss: 0.0511 - 18s/epoch - 49ms/step
# Epoch 5/60
# 371/371 - 18s - loss: 0.0501 - 18s/epoch - 48ms/step
# Epoch 6/60
# 371/371 - 17s - loss: 0.0473 - 17s/epoch - 45ms/step
# Epoch 7/60
# 371/371 - 17s - loss: 0.0407 - 17s/epoch - 46ms/step
# Epoch 8/60
# 371/371 - 18s - loss: 0.0180 - 18s/epoch - 48ms/step
# Epoch 9/60
# 371/371 - 17s - loss: 0.0105 - 17s/epoch - 46ms/step
# Epoch 10/60
# 371/371 - 17s - loss: 0.0084 - 17s/epoch - 45ms/step
# Epoch 11/60
# 371/371 - 17s - loss: 0.0074 - 17s/epoch - 45ms/step
# Epoch 12/60
# 371/371 - 17s - loss: 0.0067 - 17s/epoch - 45ms/step
# Epoch 13/60
# 371/371 - 17s - loss: 0.0060 - 17s/epoch - 47ms/step
# Epoch 14/60
# 371/371 - 17s - loss: 0.0061 - 17s/epoch - 46ms/step
# Epoch 15/60
# 371/371 - 17s - loss: 0.0055 - 17s/epoch - 46ms/step
# Epoch 16/60
# 371/371 - 17s - loss: 0.0053 - 17s/epoch - 45ms/step
# Epoch 17/60
# 371/371 - 17s - loss: 0.0050 - 17s/epoch - 45ms/step
# Epoch 18/60
# 371/371 - 17s - loss: 0.0049 - 17s/epoch - 46ms/step
# Epoch 19/60
# 371/371 - 18s - loss: 0.0048 - 18s/epoch - 48ms/step
# Epoch 20/60
# 371/371 - 18s - loss: 0.0044 - 18s/epoch - 48ms/step
# Epoch 21/60
# 371/371 - 17s - loss: 0.0044 - 17s/epoch - 45ms/step
# Epoch 22/60
# 371/371 - 17s - loss: 0.0043 - 17s/epoch - 47ms/step
# Epoch 23/60
# 371/371 - 17s - loss: 0.0043 - 17s/epoch - 46ms/step
# Epoch 24/60
# 371/371 - 18s - loss: 0.0044 - 18s/epoch - 49ms/step
# Epoch 25/60
# 371/371 - 17s - loss: 0.0041 - 17s/epoch - 47ms/step
# Epoch 26/60
# 371/371 - 17s - loss: 0.0042 - 17s/epoch - 45ms/step
# Epoch 27/60
# 371/371 - 17s - loss: 0.0039 - 17s/epoch - 47ms/step
# Epoch 28/60
# 371/371 - 18s - loss: 0.0039 - 18s/epoch - 47ms/step
# Epoch 29/60
# 371/371 - 17s - loss: 0.0040 - 17s/epoch - 46ms/step
# Epoch 30/60
# 371/371 - 17s - loss: 0.0037 - 17s/epoch - 46ms/step
# Epoch 31/60
# 371/371 - 17s - loss: 0.0039 - 17s/epoch - 45ms/step
# Epoch 32/60
# 371/371 - 17s - loss: 0.0039 - 17s/epoch - 46ms/step
# Epoch 33/60
# 371/371 - 17s - loss: 0.0036 - 17s/epoch - 47ms/step
# Epoch 34/60
# 371/371 - 17s - loss: 0.0038 - 17s/epoch - 46ms/step
# Epoch 35/60
# 371/371 - 17s - loss: 0.0035 - 17s/epoch - 44ms/step
# Epoch 36/60
# 371/371 - 17s - loss: 0.0035 - 17s/epoch - 47ms/step
# Epoch 37/60
# 371/371 - 18s - loss: 0.0035 - 18s/epoch - 48ms/step
# Epoch 38/60
# 371/371 - 18s - loss: 0.0034 - 18s/epoch - 48ms/step
# Epoch 39/60
# 371/371 - 17s - loss: 0.0033 - 17s/epoch - 46ms/step
# Epoch 40/60
# 371/371 - 17s - loss: 0.0033 - 17s/epoch - 46ms/step
# Epoch 41/60
# 371/371 - 17s - loss: 0.0032 - 17s/epoch - 46ms/step
# Epoch 42/60
# 371/371 - 17s - loss: 0.0031 - 17s/epoch - 46ms/step
# Epoch 43/60
# 371/371 - 17s - loss: 0.0029 - 17s/epoch - 47ms/step
# Epoch 44/60
# 371/371 - 17s - loss: 0.0034 - 17s/epoch - 45ms/step
# Epoch 45/60
# 371/371 - 17s - loss: 0.0032 - 17s/epoch - 46ms/step
# Epoch 46/60
# 371/371 - 17s - loss: 0.0032 - 17s/epoch - 45ms/step
# Epoch 47/60
# 371/371 - 17s - loss: 0.0027 - 17s/epoch - 46ms/step
# Epoch 48/60
# 371/371 - 16s - loss: 0.0033 - 16s/epoch - 44ms/step
# Epoch 49/60
# 371/371 - 17s - loss: 0.0030 - 17s/epoch - 46ms/step
# Epoch 50/60
# 371/371 - 17s - loss: 0.0028 - 17s/epoch - 46ms/step
# Epoch 51/60
# 371/371 - 17s - loss: 0.0030 - 17s/epoch - 46ms/step
# Epoch 52/60
# 371/371 - 17s - loss: 0.0031 - 17s/epoch - 45ms/step
# Epoch 53/60
# 371/371 - 17s - loss: 0.0026 - 17s/epoch - 45ms/step
# Epoch 54/60
# 371/371 - 17s - loss: 0.0033 - 17s/epoch - 46ms/step
# Epoch 55/60
# 371/371 - 17s - loss: 0.0030 - 17s/epoch - 45ms/step
# Epoch 56/60
# 371/371 - 17s - loss: 0.0029 - 17s/epoch - 46ms/step
# Epoch 57/60
# 371/371 - 17s - loss: 0.0030 - 17s/epoch - 45ms/step
# Epoch 58/60
# 371/371 - 17s - loss: 0.0029 - 17s/epoch - 45ms/step
# Epoch 59/60
# 371/371 - 17s - loss: 0.0026 - 17s/epoch - 46ms/step
# Epoch 60/60
# 371/371 - 17s - loss: 0.0029 - 17s/epoch - 45ms/step
# Initial shape of x_input (50, 6)
# The shape of yhat after prediction is (1, 100, 6)
# The new shape of yhat  is (100, 6)
# [[-1.06135376e-01  1.16965723e+00  2.26960294e-02  3.07172513e+00
#    3.01332664e+00  4.97414708e-01]
#  [-8.63272846e-02  1.09125745e+00 -6.08280376e-02  3.10162568e+00
#    3.02522898e+00  5.05735874e-01]
#  [-1.92420036e-02  1.14629316e+00 -5.51049933e-02  3.08824515e+00
#    3.00830507e+00  5.03589392e-01]
#  [ 5.42977639e-02  1.20026124e+00 -2.71213092e-02  3.06454849e+00
#    2.98333621e+00  4.99053329e-01]
#  [ 8.21614861e-02  1.24601007e+00 -9.28592309e-03  3.05659199e+00
#    2.97519541e+00  4.97396022e-01]
#  [ 6.97646812e-02  1.27844679e+00 -1.10364370e-02  3.05674171e+00
#    2.97572470e+00  4.97283548e-01]
#  [ 4.70326655e-02  1.30423892e+00 -1.48214847e-02  3.05913711e+00
#    2.97866058e+00  4.97613788e-01]
#  [ 2.71276068e-02  1.32553113e+00 -1.66207049e-02  3.06157470e+00
#    2.98162532e+00  4.97975975e-01]
#  [ 1.34133296e-02  1.34417486e+00 -1.62287969e-02  3.06399179e+00
#    2.98447847e+00  4.98363137e-01]
#  [ 5.55966888e-03  1.36077774e+00 -1.41799971e-02  3.06613588e+00
#    2.98695755e+00  4.98726219e-01]
#  [ 2.63315137e-03  1.37565935e+00 -1.08727664e-02  3.06793070e+00
#  [-2.82650795e-02  1.79008412e+00 -7.75904581e-03  3.06721878e+00
#    2.99270225e+00  4.98651385e-01]
#  [-2.27398444e-02  1.81616104e+00 -1.45454332e-03  3.06976485e+00
#    2.99565458e+00  4.99204397e-01]
#  [-1.49478428e-02  1.84229958e+00  5.86186722e-03  3.07372069e+00
#    3.00005770e+00  5.00035048e-01]
#  [-1.16123660e-02  1.86643529e+00  5.99532202e-03  3.07552814e+00
#    3.00211287e+00  5.00470042e-01]
#  [-1.80093516e-02  1.88859749e+00 -2.72424147e-03  3.07561016e+00
#    3.00209212e+00  5.00570297e-01]
#  [-2.47038156e-02  1.91043329e+00 -1.02667324e-02  3.07779789e+00
#    3.00388694e+00  5.01046181e-01]
#  [-2.32509822e-02  1.93085515e+00 -1.62676089e-02  3.08047462e+00
#    3.00571465e+00  5.01600325e-01]
#  [-1.12696970e-02  1.95017958e+00 -2.09146254e-02  3.08356619e+00
#    3.00738668e+00  5.02217531e-01]
#  [ 1.55320829e-02  1.96828675e+00 -2.32470743e-02  3.08646226e+00
#    3.00815058e+00  5.02774119e-01]
#  [ 6.73684701e-02  1.98473155e+00 -1.97518580e-02  3.08821893e+00
#    3.00685859e+00  5.03075421e-01]
#  [ 1.04103908e-01  2.01098585e+00 -4.03290503e-02  3.09518242e+00
#    3.01192212e+00  5.04310131e-01]
#  [-2.04834953e-01  2.02284527e+00  8.61359090e-02  3.06092167e+00
#    2.97850418e+00  4.97606397e-01]]
# -------Learning Curve--------
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 25)                3200
#
#  repeat_vector (RepeatVector  (None, 100, 25)          0
#  )
#
#  lstm_1 (LSTM)               (None, 100, 25)           5100
#
#  time_distributed (TimeDistr  (None, 100, 6)           156
#  ibuted)
#
# =================================================================
# Total params: 8,456
# Trainable params: 8,456
# Non-trainable params: 0
# _________________________________________________________________
# Model saved!

# %%
# attr = len(inv_yhat.T)
attr = ["Tank3OutFlow", "Tank2.level", "wt3_valve", "Tank1WaterLevel", "Tank2WaterLevel", "Tank2OutFlow"]
# attr = ["wt3_valve", "Tank1InFlow", "Tank1WaterLevel", "Tank3OutFlow", "Tank2.level"]
for i in range(len(attr)):
    title = "Prediction of "+str(attr[i])
#     actual = raw_data[9901:10000,i]
    actual = raw_data[11901:12000,i]
    pred = inv_yhat.T
    pred_df = pd.DataFrame(inv_yhat)
    # specify the range based on the length of predicted output
    index = pd.Index(list(range(100,200)))
    pred_df = pred_df.set_index(index)
    plt.title(title)
    plt.xlabel("Timestep")
    plt.ylabel("values")
#     plt.plot(pred[i], label="predicted")
#     plt.plot(actual, label="actual")
    plt.plot(pred_df[i])
    plt.plot(actual)
    plt.show()

# %% [markdown]
# ### Load the pretrained surrogate model

# %%
from keras.models import load_model

s_model = load_model('tank2_stuck_at.h5')

new_data = scaled_data[12000:14000,:]

# choose a number of time steps
n_steps_in, n_steps_out = 50, 100

# convert into input/output
test_X, test_y = split_sequences(new_data, n_steps_in, n_steps_out)
# the dataset knows the number of features, e.g. 2
n_features = X.shape[2]

score = s_model.evaluate(test_X, test_y, verbose=0)
# test_yhat = s_model.predict(test_X, verbose=0)
print("%s:  %.2f%%" % (s_model.metrics_names[0], score*100))


print("Prediction is successful!")
# Out:
# loss:  0.07%
# Prediction is successful!

# %%
print("ekekd")
# Out:
# ekekd
